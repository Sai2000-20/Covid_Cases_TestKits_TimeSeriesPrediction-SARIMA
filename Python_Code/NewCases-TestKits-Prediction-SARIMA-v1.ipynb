# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

#Loading the data from the file

#df = pd.read_csv('C:\\Users\\Saira\\Desktop\ML\\Individual_Assignment-Project\\owid-covid-data2.csv')
df = pd.read_csv('W:\\um\Machine Learning\\INdividual Assignment Part1\\owid-covid-data2.csv')

df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan   23/1/2020          NaN        0.0
# 1          AFG      Asia  Afghanistan   24/1/2020          NaN        0.0
# 2          AFG      Asia  Afghanistan   25/1/2020          NaN        0.0
# 3          AFG      Asia  Afghanistan   26/1/2020          NaN        0.0
# 4          AFG      Asia  Afghanistan   27/1/2020          NaN        0.0
# ...        ...       ...          ...         ...          ...        ...
# 60475      ZWE    Africa     Zimbabwe  29/11/2020       9822.0        0.0
# 60476      ZWE    Africa     Zimbabwe  30/11/2020       9950.0      128.0
# 60477      ZWE    Africa     Zimbabwe   1/12/2020      10129.0      179.0
# 60478      ZWE    Africa     Zimbabwe   2/12/2020      10129.0        0.0
# 60479      ZWE    Africa     Zimbabwe   3/12/2020      10424.0      295.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# 2                     NaN           NaN         0.0                  NaN  ...
# 3                     NaN           NaN         0.0                  NaN  ...
# 4                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 60475              86.000         275.0         0.0                1.000  ...
# 60476              91.714         276.0         1.0                0.429  ...
# 60477             104.429         277.0         1.0                0.429  ...
# 60478              88.714         277.0         0.0                0.429  ...
# 60479             114.429         280.0         3.0                0.857  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 60475        1899.775             21.4                307.846
# 60476        1899.775             21.4                307.846
# 60477        1899.775             21.4                307.846
# 60478        1899.775             21.4                307.846
# 60479        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 60475                 1.82             1.6          30.7
# 60476                 1.82             1.6          30.7
# 60477                 1.82             1.6          30.7
# 60478                 1.82             1.6          30.7
# 60479                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 60475                  36.791                         1.7            61.49
# 60476                  36.791                         1.7            61.49
# 60477                  36.791                         1.7            61.49
# 60478                  36.791                         1.7            61.49
# 60479                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 60475                    0.535
# 60476                    0.535
# 60477                    0.535
# 60478                    0.535
# 60479                    0.535
#
# [60480 rows x 50 columns]

# %%
df.describe
# It has 50 columns and 60480 rows- we would filter for the required columns only
# get columns 'iso_code','location','date','total_cases','new_cases','total_tests','new_tests'
# There are 60480 rows x 50 columns
# Out:
# <bound method NDFrame.describe of       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan   23/1/2020          NaN        0.0
# 1          AFG      Asia  Afghanistan   24/1/2020          NaN        0.0
# 2          AFG      Asia  Afghanistan   25/1/2020          NaN        0.0
# 3          AFG      Asia  Afghanistan   26/1/2020          NaN        0.0
# 4          AFG      Asia  Afghanistan   27/1/2020          NaN        0.0
# ...        ...       ...          ...         ...          ...        ...
# 60475      ZWE    Africa     Zimbabwe  29/11/2020       9822.0        0.0
# 60476      ZWE    Africa     Zimbabwe  30/11/2020       9950.0      128.0
# 60477      ZWE    Africa     Zimbabwe   1/12/2020      10129.0      179.0
# 60478      ZWE    Africa     Zimbabwe   2/12/2020      10129.0        0.0
# 60479      ZWE    Africa     Zimbabwe   3/12/2020      10424.0      295.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# 2                     NaN           NaN         0.0                  NaN  ...
# 3                     NaN           NaN         0.0                  NaN  ...
# 4                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 60475              86.000         275.0         0.0                1.000  ...
# 60476              91.714         276.0         1.0                0.429  ...
# 60477             104.429         277.0         1.0                0.429  ...
# 60478              88.714         277.0         0.0                0.429  ...
# 60479             114.429         280.0         3.0                0.857  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 60475        1899.775             21.4                307.846
# 60476        1899.775             21.4                307.846
# 60477        1899.775             21.4                307.846
# 60478        1899.775             21.4                307.846
# 60479        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 60475                 1.82             1.6          30.7
# 60476                 1.82             1.6          30.7
# 60477                 1.82             1.6          30.7
# 60478                 1.82             1.6          30.7
# 60479                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 60475                  36.791                         1.7            61.49
# 60476                  36.791                         1.7            61.49
# 60477                  36.791                         1.7            61.49
# 60478                  36.791                         1.7            61.49
# 60479                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 60475                    0.535
# 60476                    0.535
# 60477                    0.535
# 60478                    0.535
# 60479                    0.535
#
# [60480 rows x 50 columns]>

# %%
#extracting the required columns only
df=df[['iso_code','location','date','total_cases','new_cases','total_tests','new_tests']]
df
#60480 rows × 7 columns
#Filtered the columns required
# Out:
#       iso_code     location        date  total_cases  new_cases  total_tests  \
# 0          AFG  Afghanistan   23/1/2020          NaN        0.0          NaN
# 1          AFG  Afghanistan   24/1/2020          NaN        0.0          NaN
# 2          AFG  Afghanistan   25/1/2020          NaN        0.0          NaN
# 3          AFG  Afghanistan   26/1/2020          NaN        0.0          NaN
# 4          AFG  Afghanistan   27/1/2020          NaN        0.0          NaN
# ...        ...          ...         ...          ...        ...          ...
# 60475      ZWE     Zimbabwe  29/11/2020       9822.0        0.0     168212.0
# 60476      ZWE     Zimbabwe  30/11/2020       9950.0      128.0     169009.0
# 60477      ZWE     Zimbabwe   1/12/2020      10129.0      179.0     170038.0
# 60478      ZWE     Zimbabwe   2/12/2020      10129.0        0.0     171900.0
# 60479      ZWE     Zimbabwe   3/12/2020      10424.0      295.0          NaN
#
#        new_tests
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 60475      965.0
# 60476      797.0
# 60477     1029.0
# 60478     1862.0
# 60479        NaN
#
# [60480 rows x 7 columns]

# %%
df.info(verbose=True)
#Checking the dattypes of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60480 entries, 0 to 60479
# Data columns (total 7 columns):
# iso_code       60164 non-null object
# location       60478 non-null object
# date           60480 non-null object
# total_cases    51743 non-null float64
# new_cases      60356 non-null float64
# total_tests    24032 non-null float64
# new_tests      23861 non-null float64
# dtypes: float64(4), object(3)
# memory usage: 3.2+ MB

# %%
#chehck for null and not null values in the dataset


print('Count of Null values is {} and Not null values is {}'.format(df.isnull().sum().sum(),df.notnull().sum().sum()))
# Out:
# Count of Null values is 82246 and Not null values is 341114

# %%
#Plotting Null and Not null values
import matplotlib.pyplot as plt
counts=[df.isnull().sum().sum(),df.notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values which need to be cleaned up.
plt.title("Cumulative count of Null and Not-null values \n" + "in entire dataset(for all countries)", bbox={'facecolor':'0.9', 'pad':5})
plt.show()

# %% [markdown]
# ### Data Cleanup for country Malaysia

# %%
#'location' column has  null, and missing country name
df[df['location'].isnull()==True]
# 2 rows have Location as Null
# Out:
#       iso_code location      date  total_cases  new_cases  total_tests  \
# 32635      MYS      NaN  7/2/2020         12.0        0.0          0.0
# 32636      MYS      NaN  8/2/2020         16.0        4.0          0.0
#
#        new_tests
# 32635        0.0
# 32636        0.0

# %%
#'iso_code' column has  null, and missing country name

df[df['iso_code'].isnull()==True]
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 24403      NaN  International   23/1/2020          NaN        0.0
# 24404      NaN  International   24/1/2020          NaN        0.0
# 24405      NaN  International   25/1/2020          NaN        0.0
# 24406      NaN  International   26/1/2020          NaN        0.0
# 24407      NaN  International   27/1/2020          NaN        0.0
# ...        ...            ...         ...          ...        ...
# 24714      NaN  International  29/11/2020        721.0        0.0
# 24715      NaN  International  30/11/2020        721.0        0.0
# 24716      NaN  International   1/12/2020        721.0        0.0
# 24717      NaN  International   2/12/2020        721.0        0.0
# 24718      NaN  International   3/12/2020        721.0        0.0
#
#        total_tests  new_tests
# 24403          NaN        NaN
# 24404          NaN        NaN
# 24405          NaN        NaN
# 24406          NaN        NaN
# 24407          NaN        NaN
# ...            ...        ...
# 24714          NaN        NaN
# 24715          NaN        NaN
# 24716          NaN        NaN
# 24717          NaN        NaN
# 24718          NaN        NaN
#
# [316 rows x 7 columns]

# %%
#If iso_code and location is null then delete the record
for index, row in df.iterrows(): 
    if df.loc[index, 'location'] is None :#'location' column has  null, and missing values
        if df.loc[index, 'iso_code'] is None :#'iso_code' column has  null, and missing values
            df.drop(index)#Delete the data record
print('Dropped records where location and iso_code is null')
# Out:
# Dropped records where location and iso_code is null

# %%
#Correct invalid iso_code values for location Malaysia
for index, row in df.iterrows(): 
    if df.loc[index, 'location'] =='Malaysia' :#'location' is Malaysia
        if df.loc[index, 'iso_code']!='MYS' :#'iso_code' not equal to MYS
            df.loc[index, 'iso_code']='MYS'
print('Replaced invalid iso_code values for location Malaysia')
# Out:
# Replaced invalid iso_code values for location Malaysia

# %%
#Correct invalid location values for iso_code MYS
for index, row in df.iterrows(): 
    if df.loc[index, 'iso_code'] =='MYS' :#'iso_code' is MYS
        if df.loc[index, 'location']!='Malaysia' :#'location' not equal to Malaysia
            df.loc[index, 'location']='Malaysia'
print('Replaced invalid location values for iso_code MYS ')
# Out:
# Replaced invalid location values for iso_code MYS

# %%
#We filter records for location = Malaysia
df=df[df['iso_code']=='MYS']

df
# Out:
#       iso_code  location        date  total_cases  new_cases  total_tests  \
# 32620      MYS  Malaysia   23/1/2020          1.0        1.0          0.0
# 32621      MYS  Malaysia   24/1/2020          2.0        1.0          0.0
# 32622      MYS  Malaysia   25/1/2020          3.0        3.0          0.0
# 32623      MYS  Malaysia   26/1/2020          4.0        1.0          0.0
# 32624      MYS  Malaysia   27/1/2020          4.0        0.0          0.0
# ...        ...       ...         ...          ...        ...          ...
# 32931      MYS  Malaysia  29/11/2020      64485.0     1309.0    2650368.0
# 32932      MYS  Malaysia  30/11/2020      65697.0     1212.0    2667756.0
# 32933      MYS  Malaysia   1/12/2020      67169.0     1472.0    2686452.0
# 32934      MYS  Malaysia   2/12/2020      68020.0      851.0    2707207.0
# 32935      MYS  Malaysia   3/12/2020      69095.0     1075.0    2728936.0
#
#        new_tests
# 32620        0.0
# 32621        0.0
# 32622        0.0
# 32623        0.0
# 32624        0.0
# ...          ...
# 32931    15370.0
# 32932    17388.0
# 32933    18696.0
# 32934    20755.0
# 32935    21729.0
#
# [316 rows x 7 columns]

# %%
# Checking for NULL values in all columns for location = Malaysia
print('For Malaysia total count of null values is {} and not null values is {} '.format(df.isnull().sum().sum(),df.notnull().sum().sum()))

counts=[df.isnull().sum().sum(),df.notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Cumulative count of Null and Not-null data for \n" + "Malaysia Before Cleaning ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# For Malaysia total count of null values is 48 and not null values is 2164

# %%
#Check for null values for location=Malaysia
df.isnull().sum()

if df.isnull().sum().sum()==0:
    print('Dataset has no null values')
else:
    print('dataset has {} null values . Kindly handle it'.format(df.isnull().sum().sum()))
# Out:
# dataset has 48 null values . Kindly handle it

# %%
#Check for datatype for each of column in data 
if df.dtypes['new_tests']!= np.float64:
    print('Invalid data in columns new_tests')
else:
    print('Column new_tests datatype is fine')
    
if df.dtypes['total_cases']!= np.float64:
    print('Invalid data in columns total_cases')
else:
    print('Column total_cases datatype is fine')
    
if df.dtypes['new_cases']!= np.float64:
    print('Invalid data in columns new_cases')
else:
    print('Column new_cases datatype is fine')
    
if df.dtypes['total_tests']!= np.float64:
    print('Invalid data in columns total_tests')
else:
    print('Column total_tests datatype is fine')
    
if df.dtypes['iso_code']!= np.object:
    print('Invalid data in columns iso_code')
else:
    print('Column iso_code datatype is fine')
    
if df.dtypes['location']!= np.object:
    print('Invalid data in columns location')
else:
    print('Column location datatype is fine')
    
if df.dtypes['date']!= np.object:
    print('Invalid data in columns date')
else:
    print('Column date datatype is fine')
# Out:
# Column new_tests datatype is fine
# Column total_cases datatype is fine
# Column new_cases datatype is fine
# Column total_tests datatype is fine
# Column iso_code datatype is fine
# Column location datatype is fine
# Column date datatype is fine

# %%
# Checking if 'new_cases' column has`  null, and missing value
df_temp=df[df['new_cases'].isnull()==True]

if df['new_cases'].isnull().sum()==0:
    print('Column new_cases has no null values')
else:
    print('Column new_cases has {} null values . Kindly handle it'.format(df['new_cases'].isnull().sum()))

df_temp

#Graphical representation of checking 'if 'new_cases' column has`  null, and missing value

counts=[df['new_cases'].isnull().sum().sum(),df['new_cases'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_cases' column for \n" + "Malaysia ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Column new_cases has 1 null values . Kindly handle it

# %%
#Check and clean data for column 'new_cases' with null and missing value
import math

for index, row in df.iterrows(): 
    if np.isnan(df.loc[index, 'new_cases']):#'new_cases' column has  null, and missing values
        if np.isnan(df.loc[index, 'total_cases']):#'total_cases' column has  null, and missing values
            df.drop(index)#Delete the data record
        else:
            df.loc[index, 'new_cases'] =  df.loc[index , 'total_cases']-df.loc[(index - 1), 'total_cases']
            #Arrange df as per 'total_cases' column in ascending order new_cases' = current 'total_cases' value - previous 'total_cases' value

# %%
#Check and confirm if column 'new_cases' has no null values
if df['new_cases'].isnull().sum()==0:
    print('Column new_cases has no null values')
else:
    print('Column new_cases has {} null values . Kindly handle it'.format(df['new_cases'].isnull().sum()))
# Out:
# Column new_cases has no null values

# %%
#Graphical representation of checking 'if 'new_cases' column has`  null, and missing value   post cleaning 

counts=[df['new_cases'].isnull().sum().sum(),df['new_cases'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_cases' column   post cleaning for \n" + "Malaysia ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()

# %%
#Check if column 'new_tests' has  null values

df[df['new_tests'].isnull()==True]
if df['new_tests'].isnull().sum()==0:
    print('Column new_tests has no null values')
else:
    print('Column new_tests has {} null values . Kindly handle it'.format(df['new_tests'].isnull().sum()))

#Graphical representation of checking 'if 'new_tests' column has`  null, and missing value

counts=[df['new_tests'].isnull().sum().sum(),df['new_tests'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_tests' column for \n" + "Malaysia ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Column new_tests has 47 null values . Kindly handle it

# %%
#Clean data for column 'new_tests' with null and missing value
for index, row in df.iterrows(): 
    if np.isnan(df.loc[index, 'new_tests']):#'new_tests' column has   null, and missing values
        if np.isnan(df.loc[index, 'total_tests']) or df.loc[index, 'total_tests']==0.0:#'total_tests' column has null, and missing values
            df.drop(index)#Delete the data record
        else:
            df.loc[index, 'new_tests'] =  df.loc[index , 'total_tests']-df.loc[(index - 1), 'total_tests']
# Arrange df as per 'total_tests' column in ascending order new_tests' = current 'total_tests' value - previous 'total_tests' value

# %%
#Check if column new_tests has null values after cleaning

if df['new_tests'].isnull().sum()==0:
    print('Column new_tests has no null values')
else:
    print('Column new_tests has {} null values . Kindly handle it'.format(df['new_tests'].isnull().sum()))

#Graphical representation of checking 'if 'new_tests' column has`  null, and missing value

counts=[df['new_tests'].isnull().sum().sum(),df['new_tests'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_tests' column  post cleaning for \n" + "Malaysia", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Column new_tests has no null values

# %%
# Out:
# Dataset has no null values

# %%
#Check if dataset has null values for any of required columns

if df.isnull().sum().sum()==0:
    print('Dataset has no null values')
else:
    print('Dataset have {} null values . Kindly handle it'.format(df.isnull().sum().sum()))

#Graphical representation of checking 'if dataset has`  null, and missing value
counts=[df.isnull().sum().sum(),df.notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Cumulative count of Null and Not-null data \n" + "Malaysia after cleaning", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
#No Null records present

# %%
#Convert String data to date datatype for time series calcualtion
##converting 'date' column to type 'datetime' so that indexing can happen later

df['date'] = pd.to_datetime(df['date'],format="%d/%m/%Y")

# %% [markdown]
# ### DATA Cleaning Complete since there are no null values in required columns - iso_code, location, date, total_cases, new_cases, total_tests, new_tests

# %% [markdown]
# # Start with Model Building

# %%
#Augmented Dickey–Fuller test (adf) is used in statistics and econometrics and it tests the null hypothesis
#that a unit root is present in a time series sample
#ADF: if the p-value is less than the critical value, the series is stationary
#create Method for ADF
from statsmodels.tsa.stattools import adfuller
def print_adf_result(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
#Kwiatkowski–Phillips–Schmidt–Shin (KPSS) tests are used for testing a null hypothesis that an observable 
#time series is stationary around a deterministic trend (i.e. trend-stationary) against the alternative of a unit root
#KPSS: if the p-value is less than the critical value, the series is stationary

#define function for kpss test
from statsmodels.tsa.stattools import kpss
def print_kpss_result(timeseries):
    print ('Results of KPSS Test is as under:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
      kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
df['date'].min(),df['date'].max()
#the date range of dta would e printed
#df
# Out:
# (Timestamp('2020-01-23 00:00:00'), Timestamp('2020-12-03 00:00:00'))

# %%
#Set standard for matplot parameters
import matplotlib as mpl

def set_plot_colour(COLOR):
    mpl.rcParams['text.color'] = COLOR
    mpl.rcParams['axes.labelcolor'] = COLOR
    mpl.rcParams['xtick.color'] = COLOR
    mpl.rcParams['ytick.color'] = COLOR
    

mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
#set colour
COLOR = 'pink'
set_plot_colour(COLOR)

# %% [markdown]
# ### Objective 1:
# Considering current trend of COVID-19 cases in Malaysia, I want to determine if Malaysia could achieve 14 days average of below 100 cases/day within the next 3 months(Cumulative count of new cases over 14 consecutive days should be less than 1400).

# %%
df_cases=df[['date','new_cases']]
#set index the data frame by ‘Date 
df_cases=df_cases.set_index('date')

# %%
#aggregate the data from daily to Weekly in order to carry out the analysis
cases_ts_weekly_avg = df_cases['new_cases'].resample('W').mean()
#W : weekly frequency
#M : month end frequency
#SM : semi-month end frequency (15th and end of month)
#Q : quarter end frequency
cases_ts_weekly_avg
# Out:
# date
# 2020-01-26       1.500000
# 2020-02-02       0.571429
# 2020-02-09       1.142857
# 2020-02-16       0.857143
# 2020-02-23       0.000000
# 2020-03-01       1.000000
# 2020-03-08      10.000000
# 2020-03-15      47.000000
# 2020-03-22     125.428571
# 2020-03-29     166.285714
# 2020-04-05     170.285714
# 2020-04-12     145.857143
# 2020-04-19     100.857143
# 2020-04-26      55.857143
# 2020-05-03      74.000000
# 2020-05-10      51.142857
# 2020-05-17      34.000000
# 2020-05-24      50.142857
# 2020-05-31      82.000000
# 2020-06-07      71.857143
# 2020-06-14      18.714286
# 2020-06-21      17.000000
# 2020-06-28       8.857143
# 2020-07-05       4.142857
# 2020-07-12       7.857143
# 2020-07-19       8.714286
# 2020-07-26      16.857143
# 2020-08-02      14.571429
# 2020-08-09      12.000000
# 2020-08-16      16.714286
# 2020-08-23       9.571429
# 2020-08-30       9.571429
# 2020-09-06       9.000000
# 2020-09-13      74.000000
# 2020-09-20      43.428571
# 2020-09-27     100.000000
# 2020-10-04     208.857143
# 2020-10-11     468.000000
# 2020-10-18     691.571429
# 2020-10-25     866.714286
# 2020-11-01     848.571429
# 2020-11-08    1100.571429
# 2020-11-15    1029.714286
# 2020-11-22    1051.142857
# 2020-11-29    1387.142857
# 2020-12-06    1152.500000
# Freq: W-SUN, Name: new_cases, dtype: float64

# %%
X = cases_ts_weekly_avg
train_size = int(len(X) * 0.7)
train, test = X[0:train_size], X[train_size:len(X)]
print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
# Out:
# Observations: 46
# Training Observations: 32
# Testing Observations: 14

# %%
#Plotting the series
import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')

cases_ts_weekly_avg.plot(figsize=(15, 8))
plt.show()

# %%
#decomposed time series to get components Trend, Seasonality &  Noise
from pylab import rcParams
import statsmodels.api as sm

rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(cases_ts_weekly_avg, model='additive', extrapolate_trend='freq', period=1)
fig = decomposition.plot()
plt.show()

# %%
# Plotting the Auto Correlation Function(ACF) and Partial Auto Correlation Function(PACF) Plot of the Trend and Seasonally adjusted Time Series data
#to determine  p and seasonal P, q and seasonal Q
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#Plot the autocorrelation function

plot_acf(cases_ts_weekly_avg,use_vlines=True,adjusted=True,title='Graph of Auto corelation for new_cases', lags=45)
mpl.pyplot.show()
#The trendwas initially decreasing in initial few weeks and then it started increasing . The change in trend results in change in corelation.
#ACF plot Spikes at lag =1 means a probable Autoregressive(AR)  order of 1 and seasonal AR order of 1

#Plots lags on the horizontal and the partial correlations on vertical axis for time-series data using method='ols'.
plot_pacf(cases_ts_weekly_avg,use_vlines=True,method='ols' ,title='Graph of Partial Auto corelation for new_cases', lags=22)
mpl.pyplot.show()
#PACF plot spikes at lag=1 and then spikes at lag=10 & lag=20, which means a probable Moving Average(MA) order of 1 or 2 and seasonal MA order of 1

# %%
#apply adf test and kpss test on the series to check whether series is stationery
print(print_adf_result(cases_ts_weekly_avg))
print(print_kpss_result(cases_ts_weekly_avg))
#ADF: if the p-value is less than the critical value , the series is stationary
#P valie is 0.99 whihc is not less than critical value of 0.05 so statistically we can confirm that the series is not stationary.
#Hence, we would do first-order differencing for the trend and re-run the ADF test to check for stationarity.
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  0.709449
# p-value                         0.990025
# #Lags Used                      4.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.371216
# p-value                   0.089562
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing First Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(1)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For first oder differencing p =0.15 NOT less than 0.05 so going for second order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.363413
# p-value                         0.152330
# #Lags Used                      3.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.283138
# p-value                   0.100000
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
#Doing Second Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(2)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Second oder differencing p =0.90 NOT less than 0.05 so going for Third order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.447880
# p-value                         0.901792
# #Lags Used                      6.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.33223
# p-value                   0.10000
# Lags Used                10.00000
# Critical Value (10%)      0.34700
# Critical Value (5%)       0.46300
# Critical Value (2.5%)     0.57400
# Critical Value (1%)       0.73900
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
#Doing Third Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(3)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Second oder differencing p =0.41 NOT less than 0.05 so going for Fourth order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.741176
# p-value                         0.410032
# #Lags Used                      0.000000
# Number of Observations Used    42.000000
# Critical Value (1%)            -3.596636
# Critical Value (5%)            -2.933297
# Critical Value (10%)           -2.604991
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.322266
# p-value                   0.100000
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
#Doing fourth Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(4)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Second oder differencing p =0.73 NOT less than 0.05 so going for Fifth order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.053945
# p-value                         0.733085
# #Lags Used                      5.000000
# Number of Observations Used    36.000000
# Critical Value (1%)            -3.626652
# Critical Value (5%)            -2.945951
# Critical Value (10%)           -2.611671
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.320102
# p-value                   0.100000
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
#Doing Fifth Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(5)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Second oder differencing p =0.65 NOT less than 0.05 so going for Sixth order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.241076
# p-value                         0.655681
# #Lags Used                      0.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.327288
# p-value                   0.100000
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
#Doing Sixth Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(6)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Second oder differencing p =0.001 which is less than 0.05 so the series is now trend stationary
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.967057
# p-value                         0.001593
# #Lags Used                      3.000000
# Number of Observations Used    36.000000
# Critical Value (1%)            -3.626652
# Critical Value (5%)            -2.945951
# Critical Value (10%)           -2.611671
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.326064
# p-value                   0.100000
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
#Plotting the adjuste new_cases
ts_cases_adj.plot(figsize=(15, 8))
plt.show()

# %%
#The Adjusted New cases shows sudden drop in new_cases which is not true, rejecteing differencing
ts_cases_adj=cases_ts_weekly_avg
ts_cases_adj.plot(figsize=(15, 8))
plt.show()

# %%
import itertools
import statsmodels.api as sm
#The variables p,P,d,D,q,Q are defined as under
#p and seasonal P: indicate the number of AR terms (lags of the stationary series)
#d and seasonal D: indicate differencing that must be done to stationary series
#q and seasonal Q: indicate the number of MA terms (lags of the forecast errors)
#lag: indicates the seasonal length in the data
#setting prameters for SARIMA

p = range(0, 3)
d = range(1,2)
q = range(0, 4)

pdq = list(itertools.product(p, d, q))
print(pdq)
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
seasonal_pdq
# Out:
# [(0, 1, 0), (0, 1, 1), (0, 1, 2), (0, 1, 3), (1, 1, 0), (1, 1, 1), (1, 1, 2), (1, 1, 3), (2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 1, 3)]
# Examples of parameter combinations for Seasonal SARIMA...
# SARIMAX: (0, 1, 1) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 1) x (0, 1, 2, 12)
# SARIMAX: (0, 1, 2) x (0, 1, 3, 12)
# [(0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 2, 12),
#  (0, 1, 3, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12),
#  (1, 1, 2, 12),
#  (1, 1, 3, 12),
#  (2, 1, 0, 12),
#  (2, 1, 1, 12),
#  (2, 1, 2, 12),
#  (2, 1, 3, 12)]

# %%
#Performing a grid search with the list of possible values around our estimated parameters. We have to  pick the model with the least AIC.
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(ts_cases_adj,
                                            order=param,
                                            seasonal_order=param_seasonal,)
            results = mod.fit(method = 'powell')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
#AIC (Akaike information criterion) is an estimator of the relative quality of statistical models for a given set of data
# Out:
# Optimization terminated successfully.
#          Current function value: 4.447524
#          Iterations: 2
#          Function evaluations: 40
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:411.17224224197446
# Optimization terminated successfully.
#          Current function value: 4.447461
#          Iterations: 2
#          Function evaluations: 45
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:413.1664034249972
# Optimization terminated successfully.
#          Current function value: 4.443125
#          Iterations: 2
#          Function evaluations: 68
# ARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:414.7674856392271
# Optimization terminated successfully.
#          Current function value: 4.443231
#          Iterations: 3
#          Function evaluations: 145
# ARIMA(0, 1, 0)x(0, 1, 3, 12)12 - AIC:416.77726225783914
# Optimization terminated successfully.
#          Current function value: 4.447490
#          Iterations: 2
#          Function evaluations: 44
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:413.1690913907694
# Optimization terminated successfully.
#          Current function value: 4.447477
#          Iterations: 2
#          Function evaluations: 76
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:415.1678773833321
# Optimization terminated successfully.
#          Current function value: 4.443125
#          Iterations: 2
#          Function evaluations: 91
# ARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:416.76749996653956
# Optimization terminated successfully.
#          Current function value: 4.443273
#          Iterations: 3
#          Function evaluations: 181
# ARIMA(0, 1, 0)x(1, 1, 3, 12)12 - AIC:418.7811484670265
# Optimization terminated successfully.
#          Current function value: 4.443125
#          Iterations: 3
#          Function evaluations: 109
# ARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:414.76754511282417
# Optimization terminated successfully.
#          Current function value: 4.443126
#          Iterations: 2
#          Function evaluations: 87
# ARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:416.7675599586791
# Optimization terminated successfully.
#          Current function value: 4.443126
#          Iterations: 2
#          Function evaluations: 111
# ARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:418.76756179498483
# Optimization terminated successfully.
#          Current function value: 4.443334
#          Iterations: 2
#          Function evaluations: 134
# ARIMA(0, 1, 0)x(2, 1, 3, 12)12 - AIC:420.78669985627477
# Optimization terminated successfully.
#          Current function value: 4.446727
#          Iterations: 2
#          Function evaluations: 48
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:413.0988654528452
# Optimization terminated successfully.
#          Current function value: 4.446701
#          Iterations: 2
#          Function evaluations: 69
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:415.09649303020944
# Optimization terminated successfully.
#          Current function value: 4.442341
#          Iterations: 2
#          Function evaluations: 92
# ARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:416.69534257929763
# Optimization terminated successfully.
#          Current function value: 4.442339
#          Iterations: 2
#          Function evaluations: 114
# ARIMA(0, 1, 1)x(0, 1, 3, 12)12 - AIC:418.6952168974926
# Optimization terminated successfully.
#          Current function value: 4.446713
#          Iterations: 2
#          Function evaluations: 69
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:415.0976002324745
# Optimization terminated successfully.
#          Current function value: 4.446709
#          Iterations: 2
#          Function evaluations: 90
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:417.0972568293402
# Optimization terminated successfully.
#          Current function value: 4.442341
#          Iterations: 2
#          Function evaluations: 113
# ARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:418.69535512917605
# Optimization terminated successfully.
#          Current function value: 4.442339
#          Iterations: 2
#          Function evaluations: 135
# ARIMA(0, 1, 1)x(1, 1, 3, 12)12 - AIC:420.69522259260657
# Optimization terminated successfully.
#          Current function value: 4.442341
#          Iterations: 2
#          Function evaluations: 90
# ARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:416.69537633837444
# Optimization terminated successfully.
#          Current function value: 4.442341
#          Iterations: 2
#          Function evaluations: 112
# ARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:418.6953829751398
# Optimization terminated successfully.
#          Current function value: 4.442341
#          Iterations: 2
#          Function evaluations: 136
# ARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:420.69538258980884
# Optimization terminated successfully.
#          Current function value: 4.442339
#          Iterations: 2
#          Function evaluations: 158
# ARIMA(0, 1, 1)x(2, 1, 3, 12)12 - AIC:422.6951633863987
# Optimization terminated successfully.
#          Current function value: 4.387372
#          Iterations: 2
#          Function evaluations: 72
# ARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:409.6382686540549
# Optimization terminated successfully.
#          Current function value: 4.384343
#          Iterations: 3
#          Function evaluations: 135
# ARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:411.3595788897762
# Optimization terminated successfully.
#          Current function value: 4.379341
#          Iterations: 3
#          Function evaluations: 168
# ARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:412.8994007204799
# Optimization terminated successfully.
#          Current function value: 4.379335
#          Iterations: 3
#          Function evaluations: 202
# ARIMA(0, 1, 2)x(0, 1, 3, 12)12 - AIC:414.8987744205682
# Optimization terminated successfully.
#          Current function value: 4.385880
#          Iterations: 3
#          Function evaluations: 135
# ARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:411.5009499270163
# Optimization terminated successfully.
#          Current function value: 4.380717
#          Iterations: 6
#          Function evaluations: 353
# ARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:413.02600030313937
# Optimization terminated successfully.
#          Current function value: 4.379335
#          Iterations: 3
#          Function evaluations: 201
# ARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:414.8988177798593
# Optimization terminated successfully.
#          Current function value: 4.379332
#          Iterations: 3
#          Function evaluations: 233
# ARIMA(0, 1, 2)x(1, 1, 3, 12)12 - AIC:416.89853444727476
# Optimization terminated successfully.
#          Current function value: 4.379330
#          Iterations: 3
#          Function evaluations: 167
# ARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:412.8983339636305
# Optimization terminated successfully.
#          Current function value: 4.379330
#          Iterations: 3
#          Function evaluations: 200
# ARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:414.898326216511
# Optimization terminated successfully.
#          Current function value: 4.379330
#          Iterations: 3
#          Function evaluations: 236
# ARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:416.8983272106298
# Optimization terminated successfully.
#          Current function value: 4.379329
#          Iterations: 3
#          Function evaluations: 270
# ARIMA(0, 1, 2)x(2, 1, 3, 12)12 - AIC:418.8982308215912
# Optimization terminated successfully.
#          Current function value: 4.386269
#          Iterations: 5
#          Function evaluations: 252
# ARIMA(0, 1, 3)x(0, 1, 0, 12)12 - AIC:411.5367296583622
# Optimization terminated successfully.
#          Current function value: 4.385707
#          Iterations: 5
#          Function evaluations: 309
# ARIMA(0, 1, 3)x(0, 1, 1, 12)12 - AIC:413.48501247734407
# Optimization terminated successfully.
#          Current function value: 4.380276
#          Iterations: 5
#          Function evaluations: 368
# ARIMA(0, 1, 3)x(0, 1, 2, 12)12 - AIC:414.9853489951335
# Optimization terminated successfully.
#          Current function value: 4.380268
#          Iterations: 5
#          Function evaluations: 426
# ARIMA(0, 1, 3)x(0, 1, 3, 12)12 - AIC:416.9846158626333
# Optimization terminated successfully.
#          Current function value: 4.386022
#          Iterations: 3
#          Function evaluations: 175
# ARIMA(0, 1, 3)x(1, 1, 0, 12)12 - AIC:413.51406949036857
# Optimization terminated successfully.
#          Current function value: 4.384894
#          Iterations: 5
#          Function evaluations: 361
# ARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:415.41024906704774
# Optimization terminated successfully.
#          Current function value: 4.380272
#          Iterations: 5
#          Function evaluations: 428
# ARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:416.98505298337705
# Optimization terminated successfully.
#          Current function value: 4.380267
#          Iterations: 5
#          Function evaluations: 485
# ARIMA(0, 1, 3)x(1, 1, 3, 12)12 - AIC:418.9845967856224
# Optimization terminated successfully.
#          Current function value: 4.380269
#          Iterations: 5
#          Function evaluations: 361
# ARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:414.9847435754872
# Optimization terminated successfully.
#          Current function value: 4.380269
#          Iterations: 5
#          Function evaluations: 415
# ARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:416.9847174142365
# Optimization terminated successfully.
#          Current function value: 4.380269
#          Iterations: 5
#          Function evaluations: 476
# ARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:418.9847147973036
# Optimization terminated successfully.
#          Current function value: 4.380266
#          Iterations: 5
#          Function evaluations: 538
# ARIMA(0, 1, 3)x(2, 1, 3, 12)12 - AIC:420.9844897913503
# Optimization terminated successfully.
#          Current function value: 4.446363
#          Iterations: 1
#          Function evaluations: 21
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:413.06543188163295
# Optimization terminated successfully.
#          Current function value: 4.446350
#          Iterations: 1
#          Function evaluations: 32
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:415.0641548477056
# Optimization terminated successfully.
#          Current function value: 4.441969
#          Iterations: 2
#          Function evaluations: 98
# ARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:416.6611902340107
# Optimization terminated successfully.
#          Current function value: 4.441967
#          Iterations: 2
#          Function evaluations: 119
# ARIMA(1, 1, 0)x(0, 1, 3, 12)12 - AIC:418.660991902311
# Optimization terminated successfully.
#          Current function value: 4.446356
#          Iterations: 2
#          Function evaluations: 65
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:415.0647453840433
# Optimization terminated successfully.
#          Current function value: 4.446355
#          Iterations: 1
#          Function evaluations: 43
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:417.0646679951167
# Optimization terminated successfully.
#          Current function value: 4.441969
#          Iterations: 2
#          Function evaluations: 119
# ARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:418.66119306813545
# Optimization terminated successfully.
#          Current function value: 4.441967
#          Iterations: 2
#          Function evaluations: 141
# ARIMA(1, 1, 0)x(1, 1, 3, 12)12 - AIC:420.66100292823836
# Optimization terminated successfully.
#          Current function value: 4.441970
#          Iterations: 2
#          Function evaluations: 96
# ARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:416.6612082313758
# Optimization terminated successfully.
#          Current function value: 4.441970
#          Iterations: 2
#          Function evaluations: 119
# ARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:418.6612172090255
# Optimization terminated successfully.
#          Current function value: 4.441970
#          Iterations: 2
#          Function evaluations: 144
# ARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:420.6612171401595
# Optimization terminated successfully.
#          Current function value: 4.441967
#          Iterations: 2
#          Function evaluations: 166
# ARIMA(1, 1, 0)x(2, 1, 3, 12)12 - AIC:422.660968811491
# Optimization terminated successfully.
#          Current function value: 4.446211
#          Iterations: 2
#          Function evaluations: 70
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:415.0514428330733
# Optimization terminated successfully.
#          Current function value: 4.446203
#          Iterations: 2
#          Function evaluations: 92
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:417.05066330073765
# Optimization terminated successfully.
#          Current function value: 4.441818
#          Iterations: 2
#          Function evaluations: 115
# ARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:418.64726937748424
# Optimization terminated successfully.
#          Current function value: 4.441693
#          Iterations: 3
#          Function evaluations: 216
# ARIMA(1, 1, 1)x(0, 1, 3, 12)12 - AIC:420.63579179346607
# Optimization terminated successfully.
#          Current function value: 4.446215
#          Iterations: 2
#          Function evaluations: 92
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:417.0518071595819
# Optimization terminated successfully.
#          Current function value: 4.446205
#          Iterations: 2
#          Function evaluations: 113
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:419.0508238081467
# Optimization terminated successfully.
#          Current function value: 4.441817
#          Iterations: 2
#          Function evaluations: 137
# ARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:420.6471633811627
# Optimization terminated successfully.
#          Current function value: 4.441758
#          Iterations: 3
#          Function evaluations: 241
# ARIMA(1, 1, 1)x(1, 1, 3, 12)12 - AIC:422.6417722918461
# Optimization terminated successfully.
#          Current function value: 4.441816
#          Iterations: 2
#          Function evaluations: 112
# ARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:418.64707960282743
# Optimization terminated successfully.
#          Current function value: 4.441814
#          Iterations: 2
#          Function evaluations: 134
# ARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:420.6468694628969
# Optimization terminated successfully.
#          Current function value: 4.441814
#          Iterations: 2
#          Function evaluations: 158
# ARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:422.6468659957744
# Optimization terminated successfully.
#          Current function value: 4.441934
#          Iterations: 2
#          Function evaluations: 185
# ARIMA(1, 1, 1)x(2, 1, 3, 12)12 - AIC:424.6579065033774
# Optimization terminated successfully.
#          Current function value: 4.387216
#          Iterations: 4
#          Function evaluations: 186
# ARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:411.62385813342564
# Optimization terminated successfully.
#          Current function value: 4.384284
#          Iterations: 4
#          Function evaluations: 232
# ARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:413.35417098061214
# Optimization terminated successfully.
#          Current function value: 4.379354
#          Iterations: 4
#          Function evaluations: 282
# ARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:414.90055954284605
# Optimization terminated successfully.
#          Current function value: 4.379349
#          Iterations: 4
#          Function evaluations: 324
# ARIMA(1, 1, 2)x(0, 1, 3, 12)12 - AIC:416.90014702077315
# Optimization terminated successfully.
#          Current function value: 4.385882
#          Iterations: 4
#          Function evaluations: 230
# ARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:413.5011472586016
# Optimization terminated successfully.
#          Current function value: 4.380531
#          Iterations: 7
#          Function evaluations: 487
# ARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:415.0088667136018
# Optimization terminated successfully.
#          Current function value: 4.379343
#          Iterations: 4
#          Function evaluations: 327
# ARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:416.8996004663389
# Optimization terminated successfully.
#          Current function value: 4.379341
#          Iterations: 4
#          Function evaluations: 371
# ARIMA(1, 1, 2)x(1, 1, 3, 12)12 - AIC:418.8994079662127
# Optimization terminated successfully.
#          Current function value: 4.379339
#          Iterations: 4
#          Function evaluations: 278
# ARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:414.8991693787839
# Optimization terminated successfully.
#          Current function value: 4.379339
#          Iterations: 4
#          Function evaluations: 323
# ARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:416.89921868980366
# Optimization terminated successfully.
#          Current function value: 4.379339
#          Iterations: 4
#          Function evaluations: 371
# ARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:418.8992208651677
# Optimization terminated successfully.
#          Current function value: 4.379339
#          Iterations: 4
#          Function evaluations: 422
# ARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:420.8992002615456
# Optimization terminated successfully.
#          Current function value: 4.351646
#          Iterations: 7
#          Function evaluations: 429
# ARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:410.35147008266205
# Optimization terminated successfully.
#          Current function value: 4.350107
#          Iterations: 11
#          Function evaluations: 764
# ARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:412.2098775550713
# Optimization terminated successfully.
#          Current function value: 4.345380
#          Iterations: 6
#          Function evaluations: 513
# ARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:413.77497278761535
# Optimization terminated successfully.
#          Current function value: 4.344168
#          Iterations: 6
#          Function evaluations: 575
# ARIMA(1, 1, 3)x(0, 1, 3, 12)12 - AIC:415.6634367224939
# Optimization terminated successfully.
#          Current function value: 4.351831
#          Iterations: 6
#          Function evaluations: 423
# ARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:412.36842185076677
# Optimization terminated successfully.
#          Current function value: 4.346547
#          Iterations: 10
#          Function evaluations: 834
# ARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:413.88236034922875
# Optimization terminated successfully.
#          Current function value: 4.345262
#          Iterations: 6
#          Function evaluations: 573
# ARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:415.7640798850716
# Optimization terminated successfully.
#          Current function value: 4.344237
#          Iterations: 6
#          Function evaluations: 645
# ARIMA(1, 1, 3)x(1, 1, 3, 12)12 - AIC:417.6698134798458
# Optimization terminated successfully.
#          Current function value: 4.345215
#          Iterations: 6
#          Function evaluations: 500
# ARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:413.7597378176151
# Optimization terminated successfully.
#          Current function value: 4.345156
#          Iterations: 6
#          Function evaluations: 568
# ARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:415.7543666021442
# Optimization terminated successfully.
#          Current function value: 4.345149
#          Iterations: 6
#          Function evaluations: 639
# ARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:417.7537194236306
# Optimization terminated successfully.
#          Current function value: 4.344146
#          Iterations: 6
#          Function evaluations: 713
# ARIMA(1, 1, 3)x(2, 1, 3, 12)12 - AIC:419.66147275984235
# Optimization terminated successfully.
#          Current function value: 4.418655
#          Iterations: 2
#          Function evaluations: 70
# ARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:412.51625077821024
# Optimization terminated successfully.
#          Current function value: 4.418527
#          Iterations: 2
#          Function evaluations: 91
# ARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:414.5045224959173
# Optimization terminated successfully.
#          Current function value: 4.413525
#          Iterations: 2
#          Function evaluations: 116
# ARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:416.04431716849666
# Optimization terminated successfully.
#          Current function value: 4.413447
#          Iterations: 2
#          Function evaluations: 139
# ARIMA(2, 1, 0)x(0, 1, 3, 12)12 - AIC:418.0371041393763
# Optimization terminated successfully.
#          Current function value: 4.418589
#          Iterations: 2
#          Function evaluations: 91
# ARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:414.5102003981044
# Optimization terminated successfully.
#          Current function value: 4.418568
#          Iterations: 2
#          Function evaluations: 112
# ARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:416.5082599167947
# Optimization terminated successfully.
#          Current function value: 4.413519
#          Iterations: 2
#          Function evaluations: 137
# ARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:418.0437606476768
# Optimization terminated successfully.
#          Current function value: 4.413443
#          Iterations: 2
#          Function evaluations: 161
# ARIMA(2, 1, 0)x(1, 1, 3, 12)12 - AIC:420.0367287359132
# Optimization terminated successfully.
#          Current function value: 4.413511
#          Iterations: 2
#          Function evaluations: 113
# ARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:416.04304094970274
# Optimization terminated successfully.
#          Current function value: 4.413512
#          Iterations: 2
#          Function evaluations: 135
# ARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:418.04310143353194
# Optimization terminated successfully.
#          Current function value: 4.413512
#          Iterations: 2
#          Function evaluations: 159
# ARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:420.043102823561
# Optimization terminated successfully.
#          Current function value: 4.413403
#          Iterations: 2
#          Function evaluations: 184
# ARIMA(2, 1, 0)x(2, 1, 3, 12)12 - AIC:422.03310696267306
# Optimization terminated successfully.
#          Current function value: 4.393504
#          Iterations: 4
#          Function evaluations: 198
# ARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:412.2023866473272
# Optimization terminated successfully.
#          Current function value: 4.393499
#          Iterations: 4
#          Function evaluations: 240
# ARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:414.20191578934254
# Optimization terminated successfully.
#          Current function value: 4.389590
#          Iterations: 5
#          Function evaluations: 350
# ARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:415.8422772524184
# Optimization terminated successfully.
#          Current function value: 4.389655
#          Iterations: 5
#          Function evaluations: 411
# ARIMA(2, 1, 1)x(0, 1, 3, 12)12 - AIC:417.8482835889471
# Optimization terminated successfully.
#          Current function value: 4.393519
#          Iterations: 4
#          Function evaluations: 240
# ARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:414.2037677560855
# Optimization terminated successfully.
#          Current function value: 4.393486
#          Iterations: 4
#          Function evaluations: 286
# ARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:416.20069607038243
# Optimization terminated successfully.
#          Current function value: 4.389588
#          Iterations: 5
#          Function evaluations: 409
# ARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:417.8420607673324
# Optimization terminated successfully.
#          Current function value: 4.389708
#          Iterations: 5
#          Function evaluations: 469
# ARIMA(2, 1, 1)x(1, 1, 3, 12)12 - AIC:419.8531562211341
# Optimization terminated successfully.
#          Current function value: 4.389599
#          Iterations: 5
#          Function evaluations: 348
# ARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:415.8431282001204
# Optimization terminated successfully.
#          Current function value: 4.389595
#          Iterations: 5
#          Function evaluations: 402
# ARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:417.84274157801946
# Optimization terminated successfully.
#          Current function value: 4.389599
#          Iterations: 5
#          Function evaluations: 461
# ARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:419.8430714185139
# Optimization terminated successfully.
#          Current function value: 4.389734
#          Iterations: 5
#          Function evaluations: 530
# ARIMA(2, 1, 1)x(2, 1, 3, 12)12 - AIC:421.8554906969059
# Optimization terminated successfully.
#          Current function value: 4.410127
#          Iterations: 4
#          Function evaluations: 238
# ARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:415.7317180166204
# Optimization terminated successfully.
#          Current function value: 4.409644
#          Iterations: 5
#          Function evaluations: 355
# ARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:417.687264089389
# Optimization terminated successfully.
#          Current function value: 4.406438
#          Iterations: 5
#          Function evaluations: 415
# ARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:419.3922819458188
# Optimization terminated successfully.
#          Current function value: 4.405223
#          Iterations: 6
#          Function evaluations: 564
# ARIMA(2, 1, 2)x(0, 1, 3, 12)12 - AIC:421.2804827174626
# Optimization terminated successfully.
#          Current function value: 4.409749
#          Iterations: 5
#          Function evaluations: 360
# ARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:417.6968745868384
# Optimization terminated successfully.
#          Current function value: 4.408735
#          Iterations: 5
#          Function evaluations: 466
# ARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:419.60357963368835
# Optimization terminated successfully.
#          Current function value: 4.406409
#          Iterations: 5
#          Function evaluations: 471
# ARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:421.3896436439886
# Optimization terminated successfully.
#          Current function value: 4.404159
#          Iterations: 6
#          Function evaluations: 640
# ARIMA(2, 1, 2)x(1, 1, 3, 12)12 - AIC:423.18260548809735
# Optimization terminated successfully.
#          Current function value: 4.406466
#          Iterations: 5
#          Function evaluations: 410
# ARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:419.3948264834997
# Optimization terminated successfully.
#          Current function value: 4.406427
#          Iterations: 5
#          Function evaluations: 468
# ARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:421.3913217729643
# Optimization terminated successfully.
#          Current function value: 4.406427
#          Iterations: 5
#          Function evaluations: 528
# ARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:423.39131615470274
# Optimization terminated successfully.
#          Current function value: 4.404422
#          Iterations: 5
#          Function evaluations: 600
# ARIMA(2, 1, 2)x(2, 1, 3, 12)12 - AIC:425.2068392615521
# Optimization terminated successfully.
#          Current function value: 4.335860
#          Iterations: 6
#          Function evaluations: 491
# ARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:410.8991457330222
# Optimization terminated successfully.
#          Current function value: 4.336482
#          Iterations: 7
#          Function evaluations: 648
# ARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:412.95634525159153
# Optimization terminated successfully.
#          Current function value: 4.328567
#          Iterations: 8
#          Function evaluations: 755
# ARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:414.22816712974316
# Optimization terminated successfully.
#          Current function value: 4.329737
#          Iterations: 7
#          Function evaluations: 824
# ARIMA(2, 1, 3)x(0, 1, 3, 12)12 - AIC:416.33580552874656
# Optimization terminated successfully.
#          Current function value: 4.335921
#          Iterations: 7
#          Function evaluations: 633
# ARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:412.90474710595635
# Optimization terminated successfully.
#          Current function value: 4.334349
#          Iterations: 7
#          Function evaluations: 744
# ARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:414.7601017350793
# Optimization terminated successfully.
#          Current function value: 4.328459
#          Iterations: 8
#          Function evaluations: 860
# ARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:416.21822293051287
# Optimization terminated successfully.
#          Current function value: 4.330428
#          Iterations: 6
#          Function evaluations: 780
# ARIMA(2, 1, 3)x(1, 1, 3, 12)12 - AIC:418.3993338179991
# Optimization terminated successfully.
#          Current function value: 4.329377
#          Iterations: 7
#          Function evaluations: 721
# ARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:414.302653150663
# Optimization terminated successfully.
#          Current function value: 4.328420
#          Iterations: 8
#          Function evaluations: 841
# ARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:416.2146061274584
# Optimization terminated successfully.
#          Current function value: 4.328416
#          Iterations: 8
#          Function evaluations: 938
# ARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:418.21427228413523
# Optimization terminated successfully.
#          Current function value: 4.329736
#          Iterations: 7
#          Function evaluations: 1000
# ARIMA(2, 1, 3)x(2, 1, 3, 12)12 - AIC:420.335739708133

# %%
#getting values which has minimum AIC for the time series data
#ARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:409.6382686540549

mod = sm.tsa.statespace.SARIMAX(ts_cases_adj,
                                            order=(0, 1, 2),
                                seasonal_order=(0, 1, 0, 12))
#Fitting model using POWELL method: Powell method, is an algorithm proposed  for finding a local minimum of a function
results = mod.fit(method = 'powell')
#Print the results
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 4.387372
#          Iterations: 2
#          Function evaluations: 72
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1453      0.101     -1.441      0.150      -0.343       0.052
# ma.L2          0.5750      0.140      4.119      0.000       0.301       0.849
# sigma2      1.173e+04   2422.703      4.840      0.000    6977.213    1.65e+04
# ==============================================================================

# %%
# Plotting the ACF and PACF Plot of the Trend and Seasonally adjusted Time Series data
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_cases_adj)
mpl.pyplot.show()
plot_pacf(ts_cases_adj)
mpl.pyplot.show()

# %%
#Plotting Standard residual for the new_cases, HIstogram plot of the cases and Density plot, Normal Q-Q and corelogram
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
#Valudate the Model versus the actual data
pred = results.get_prediction(start=pd.to_datetime('2020-08-02'), dynamic=False)
#Valudate the Model versus the actual data
pred_ci = pred.conf_int()
ax = ts_cases_adj.plot(label='Observed (Actual)')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('New Cases')
plt.legend()
plt.show()

# %%
#Calculate the predicted results versus actual values
y_forecasted = pred.predicted_mean
y_truth = ts_cases_adj['2020-08-02':]
#Calculate Mean Squared Error
mse = ((y_forecasted - y_truth) ** 2).mean()
mse=round(mse, 2)
print('The Mean Squared Error is {}'.format(mse))
#Calculate Root Mean Squared Error
rmse=round(np.sqrt(mse), 2)
print('The Root Mean Squared Error is {}'.format(rmse))
#Calculate R-squared Error or Coefficient of Determination:The % variation of y on variation with x
from sklearn.metrics import r2_score 
r_squared=r2_score(y_truth, y_forecasted)
print('R-squared Error is {}'.format(r_squared))

#Since the R squared error is approximately 0.92 closer to 1 the model can predict the values of future cases with a narrow margin of error
#prediction model accuracy is 92.23% which is acceptable.
# Out:
# The Mean Squared Error is 18185.01
# The Root Mean Squared Error is 134.85
# R-squared Error is 0.9233381666117345

# %%
#Future Predict the results for next 16 weeks
pred_uc = results.get_forecast(steps=16)
pred_ci = pred_uc.conf_int()
ax = ts_cases_adj.plot(label='Observed(Actual)', figsize=(14, 6))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('New Cases')
plt.legend()




plt.show()
#Since we are preicting weekly average the value is calcualted on every Sunday . The gap in graph shows aperiod between 
#on a gap of a week 06-Dec-2020 to 13-Dec-2020 but there is NO missing values.

# %%
#viewing the predicted results
pred_ci
# Out:
#             lower new_cases  upper new_cases
# 2020-12-13       925.787884      1350.719281
# 2020-12-20       989.969838      1616.902211
# 2020-12-27       913.037135      1688.734283
# 2021-01-03      1057.560854      2062.496278
# 2021-01-10      1188.183262      2379.016728
# 2021-01-17      1283.044420      2634.441284
# 2021-01-24      1193.194044      2688.005946
# 2021-01-31      1379.788245      3005.411744
# 2021-02-07      1248.410026      2995.075678
# 2021-02-14      1213.248034      3073.094812
# 2021-02-21      1495.909101      3462.433746
# 2021-02-28      1210.675540      3278.381592
# 2021-03-07      1067.619388      3392.944910
# 2021-03-14      1109.306745      3681.622436
# 2021-03-21       994.938146      3790.890404
# 2021-03-28      1115.005930      4189.108334

# %%
list(pred_ci.columns.values)
# Out:
# ['lower new_cases', 'upper new_cases']

# %%
#red_ci[['lower new_cases', 'upper new_cases']]
pred_ci['lower new_cases']
# Out:
# 2020-12-13    1115.368592
# 2020-12-20     988.867255
# 2020-12-27     964.582257
# 2021-01-03    1124.111500
# 2021-01-10    1264.516021
# 2021-01-17    1366.767287
# 2021-01-24    1282.939194
# 2021-01-31    1474.669717
# 2021-02-07    1347.806010
# 2021-02-14    1316.696949
# 2021-02-21    1603.053848
# 2021-02-28    1321.230957
# 2021-03-07    1371.131864
# 2021-03-14    1211.524586
# 2021-03-21    1178.259221
# 2021-03-28    1308.726534
# Freq: W-SUN, Name: lower new_cases, dtype: float64

# %%
pred_ci.filter('')
df_result=pred_ci[(pred_ci['lower new_cases'] <=100.0) | (pred_ci['upper new_cases'] <=100.0)]
df_result
# Out:
# Empty DataFrame
# Columns: [lower new_cases, upper new_cases]
# Index: []

# %%
#check average for 2 consecutive weeks and say if Malaysia could achieve Objective of 100 cases/day in next three months
biweekly_day_average_meet=False
for index, row in pred_ci.iterrows():
    if ((pred_ci.loc[index,'lower new_cases']+pred_ci.loc[index,'upper new_cases'])/2) <=100:
        if ((pred_ci.loc[(index-1),'lower new_cases']+pred_ci.loc[(index-1),'upper new_cases'])/2) <=100:
            biweekly_day_average_meet=True
            print("Malaysia could achieve 14 days average of below 100 cases per day within the next 3 months for weeks ",pred_ci.loc[index],pred_ci.loc[(index - 1)])
if(biweekly_day_average_meet==False):
    print("Based on current trend of data it seems difficult that Malaysia would achieve trend on 100 cases per week in next three months")
# Out:
# Based on current trend of data it seems difficult that Malaysia would achieve trend on 100 cases per week in next three months

# %% [markdown]
# ### there is not even a single week where average is less than 100 cases /day
# ## Based on current trend of data it seems difficult that Malaysia would achieve trend on 100 cases per week in next three months

# %% [markdown]
# # Time series analysis for COVID19 Test Kit prediction

# %%
#Filterout columns 'date','new_tests'
df_new_test=df[['date','new_tests']]
df_new_test
# Out:
#             date  new_tests
# 32620 2020-01-23        0.0
# 32621 2020-01-24        0.0
# 32622 2020-01-25        0.0
# 32623 2020-01-26        0.0
# 32624 2020-01-27        0.0
# ...          ...        ...
# 32931 2020-11-29    15370.0
# 32932 2020-11-30    17388.0
# 32933 2020-12-01    18696.0
# 32934 2020-12-02    20755.0
# 32935 2020-12-03    21729.0
#
# [316 rows x 2 columns]

# %%
#set index the data frame by ‘Date 
df_new_test=df_new_test.set_index('date')
df_new_test
# Out:
#             new_tests
# date
# 2020-01-23        0.0
# 2020-01-24        0.0
# 2020-01-25        0.0
# 2020-01-26        0.0
# 2020-01-27        0.0
# ...               ...
# 2020-11-29    15370.0
# 2020-11-30    17388.0
# 2020-12-01    18696.0
# 2020-12-02    20755.0
# 2020-12-03    21729.0
#
# [316 rows x 1 columns]

# %%
#aggregate the data from daily to Weekly in order to carry out the analysis
tests_ts_weekly_avg = df_new_test['new_tests'].resample('W').mean()
#W : weekly frequency
#M : month end frequency
#SM : semi-month end frequency (15th and end of month)
#Q : quarter end frequency
tests_ts_weekly_avg
# Out:
# date
# 2020-01-26        0.000000
# 2020-02-02        0.000000
# 2020-02-09        0.000000
# 2020-02-16       93.714286
# 2020-02-23       53.142857
# 2020-03-01       88.571429
# 2020-03-08       47.857143
# 2020-03-15      416.571429
# 2020-03-22      910.857143
# 2020-03-29     2722.714286
# 2020-04-05     1886.428571
# 2020-04-12     4850.285714
# 2020-04-19    16226.285714
# 2020-04-26     3942.714286
# 2020-05-03     9191.714286
# 2020-05-10    44198.142857
# 2020-05-17    26618.000000
# 2020-05-24     9202.714286
# 2020-05-31     6500.142857
# 2020-06-07     7666.285714
# 2020-06-14     6356.714286
# 2020-06-21     4660.571429
# 2020-06-28     9426.000000
# 2020-07-05     7795.428571
# 2020-07-12     6141.714286
# 2020-07-19     6033.428571
# 2020-07-26     6843.000000
# 2020-08-02     5933.285714
# 2020-08-09     9542.571429
# 2020-08-16     9752.857143
# 2020-08-23     8881.428571
# 2020-08-30     9589.142857
# 2020-09-06     9130.571429
# 2020-09-13     9242.857143
# 2020-09-20    10361.714286
# 2020-09-27     9386.285714
# 2020-10-04    14950.142857
# 2020-10-11    17689.571429
# 2020-10-18    20997.000000
# 2020-10-25    17267.000000
# 2020-11-01    18705.857143
# 2020-11-08    19653.857143
# 2020-11-15    17972.714286
# 2020-11-22    18159.285714
# 2020-11-29    17458.571429
# 2020-12-06    19642.000000
# Freq: W-SUN, Name: new_tests, dtype: float64

# %%
#Plotting the series
import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')

tests_ts_weekly_avg.plot(figsize=(15, 8))
plt.show()

# %%
#decomposed time series to get components Trend, Seasonality &  Noise
from pylab import rcParams
import statsmodels.api as sm

rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(tests_ts_weekly_avg, model='additive', extrapolate_trend='freq', period=1)
fig = decomposition.plot()
plt.show()

# %%
# Plotting the Auto Correlation Function(ACF) and Partial Auto Correlation Function(PACF) Plot of the Trend and Seasonally adjusted Time Series data
#to determine  p and seasonal P, q and seasonal Q
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#Plot the autocorrelation function

plot_acf(tests_ts_weekly_avg,use_vlines=True,adjusted=True,title='Graph of Auto corelation for new_tests', lags=45)
mpl.pyplot.show()
#The trendwas initially decreasing in initial few weeks and then it started increasing . The change in trend results in change in corelation.
#ACF plot Spikes at lag =1 means a probable Autoregressive(AR)  order of 1 and seasonal AR order of 1

#Plots lags on the horizontal and the partial correlations on vertical axis for time-series data using method='ols'.
plot_pacf(tests_ts_weekly_avg,use_vlines=True,method='ols' ,title='Graph of Partial Auto corelation for new_tests', lags=22)
mpl.pyplot.show()
#PACF plot spikes at lag=1 and lag=4 and then spikes at lag=21, which means a probable Moving Average(MA) order of 1 or 2 and seasonal MA order of 1

# %%
#apply adf test and kpss test on the series to check whether series is stationery
print(print_adf_result(tests_ts_weekly_avg))
print(print_kpss_result(tests_ts_weekly_avg))
#ADF: if the p-value is less than the critical value , the series is stationary
#P valie is 0.08 whihc is not less than critical value of 0.05 so statistically we can confirm that the series is not stationary.
#Hence, we would do first-order differencing for the trend and re-run the ADF test to check for stationarity.
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.771391
# p-value                         0.394755
# #Lags Used                      2.000000
# Number of Observations Used    43.000000
# Critical Value (1%)            -3.592504
# Critical Value (5%)            -2.931550
# Critical Value (10%)           -2.604066
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.391765
# p-value                   0.080705
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing First Order differencing
ts_tests_adj = tests_ts_weekly_avg - tests_ts_weekly_avg.shift(1)
#ts_cases_adj =cases_ts_weekly_avg
ts_tests_adj = ts_tests_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_tests_adj))
print(print_kpss_result(ts_tests_adj))
#For first oder differencing p =6.271783e-13  less than 0.05 so ploting the graph
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.225249e+00
# p-value                        6.271783e-13
# #Lags Used                     1.000000e+00
# Number of Observations Used    4.300000e+01
# Critical Value (1%)           -3.592504e+00
# Critical Value (5%)           -2.931550e+00
# Critical Value (10%)          -2.604066e+00
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.10516
# p-value                   0.10000
# Lags Used                10.00000
# Critical Value (10%)      0.34700
# Critical Value (5%)       0.46300
# Critical Value (2.5%)     0.57400
# Critical Value (1%)       0.73900
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
#Plotting the series with ts_tests_adj

ts_tests_adj.plot(figsize=(15, 8))
plt.show()
#the differencing gives a non zero value for second half of May 2020 so rejecting the differentiating

# %%
#Plotting the series with ts_tests_adj
ts_tests_adj=tests_ts_weekly_avg
ts_tests_adj.plot(figsize=(15, 8))
plt.show()

# %%
import itertools
import statsmodels.api as sm
#The variables p,P,d,D,q,Q are defined as under
#p and seasonal P: indicate the number of AR terms (lags of the stationary series)
#d and seasonal D: indicate differencing that must be done to stationary series
#q and seasonal Q: indicate the number of MA terms (lags of the forecast errors)
#lag: indicates the seasonal length in the data
#setting prameters for SARIMA

p = range(0, 3)
d = range(1,2)
q = range(0, 4)

pdq = list(itertools.product(p, d, q))
print(pdq)
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
seasonal_pdq
# Out:
# [(0, 1, 0), (0, 1, 1), (0, 1, 2), (0, 1, 3), (1, 1, 0), (1, 1, 1), (1, 1, 2), (1, 1, 3), (2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 1, 3)]
# Examples of parameter combinations for Seasonal SARIMA...
# SARIMAX: (0, 1, 1) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 1) x (0, 1, 2, 12)
# SARIMAX: (0, 1, 2) x (0, 1, 3, 12)
# [(0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 2, 12),
#  (0, 1, 3, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12),
#  (1, 1, 2, 12),
#  (1, 1, 3, 12),
#  (2, 1, 0, 12),
#  (2, 1, 1, 12),
#  (2, 1, 2, 12),
#  (2, 1, 3, 12)]

# %%
#Performing a grid search with the list of possible values around our estimated parameters. We have to  pick the model with the least AIC.
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(ts_tests_adj,
                                            order=param,
                                            seasonal_order=param_seasonal,)
            results = mod.fit(method = 'powell')
            print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
#AIC (Akaike information criterion) is an estimator of the relative quality of statistical models for a given set of data
# Out:
# Optimization terminated successfully.
#          Current function value: 7.742832
#          Iterations: 2
#          Function evaluations: 34
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:714.3405424334624
# Optimization terminated successfully.
#          Current function value: 7.526263
#          Iterations: 3
#          Function evaluations: 83
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:696.4161590734557
# Optimization terminated successfully.
#          Current function value: 7.453077
#          Iterations: 4
#          Function evaluations: 161
# SARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:691.6830970887746
# Optimization terminated successfully.
#          Current function value: 7.449697
#          Iterations: 4
#          Function evaluations: 202
# SARIMA(0, 1, 0)x(0, 1, 3, 12)12 - AIC:693.372163579749
# Optimization terminated successfully.
#          Current function value: 7.638214
#          Iterations: 2
#          Function evaluations: 59
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:706.7156720997903
# Optimization terminated successfully.
#          Current function value: 7.507752
#          Iterations: 4
#          Function evaluations: 157
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:696.7131763865225
# Optimization terminated successfully.
#          Current function value: 7.461407
#          Iterations: 6
#          Function evaluations: 296
# SARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:694.4494450556473
# Optimization terminated successfully.
#          Current function value: 7.404816
#          Iterations: 6
#          Function evaluations: 386
# SARIMA(0, 1, 0)x(1, 1, 3, 12)12 - AIC:691.2430935377629
# Optimization terminated successfully.
#          Current function value: 6.950845
#          Iterations: 3
#          Function evaluations: 120
# SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:645.4777029543509
# Optimization terminated successfully.
#          Current function value: 6.947460
#          Iterations: 8
#          Function evaluations: 411
# SARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:647.166297812792
# Optimization terminated successfully.
#          Current function value: 6.947638
#          Iterations: 7
#          Function evaluations: 442
# SARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:649.1827206558361
# Optimization terminated successfully.
#          Current function value: 6.947505
#          Iterations: 7
#          Function evaluations: 524
# SARIMA(0, 1, 0)x(2, 1, 3, 12)12 - AIC:651.1704731227966
# Optimization terminated successfully.
#          Current function value: 7.707049
#          Iterations: 2
#          Function evaluations: 46
# SARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:713.0485341988768
# Optimization terminated successfully.
#          Current function value: 7.480424
#          Iterations: 4
#          Function evaluations: 160
# SARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:694.1990510588909
# Optimization terminated successfully.
#          Current function value: 7.397952
#          Iterations: 4
#          Function evaluations: 205
# SARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:688.6116042053703
# Optimization terminated successfully.
#          Current function value: 7.390054
#          Iterations: 6
#          Function evaluations: 379
# SARIMA(0, 1, 1)x(0, 1, 3, 12)12 - AIC:689.8849789303068
# Optimization terminated successfully.
#          Current function value: 7.584647
#          Iterations: 2
#          Function evaluations: 80
# SARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:703.7875630706102
# Optimization terminated successfully.
#          Current function value: 7.453567
#          Iterations: 5
#          Function evaluations: 243
# SARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:693.7281662966312
# Optimization terminated successfully.
#          Current function value: 7.396305
#          Iterations: 5
#          Function evaluations: 370
# SARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:690.4600496577816
# Optimization terminated successfully.
#          Current function value: 7.362022
#          Iterations: 6
#          Function evaluations: 453
# SARIMA(0, 1, 1)x(1, 1, 3, 12)12 - AIC:689.3060298871183
# Optimization terminated successfully.
#          Current function value: 6.946546
#          Iterations: 7
#          Function evaluations: 345
# SARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:647.0822719654121
# Optimization terminated successfully.
#          Current function value: 6.945580
#          Iterations: 10
#          Function evaluations: 608
# SARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:648.993383989394
# Optimization terminated successfully.
#          Current function value: 6.946428
#          Iterations: 7
#          Function evaluations: 511
# SARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:651.0713876898398
# Optimization terminated successfully.
#          Current function value: 6.947144
#          Iterations: 7
#          Function evaluations: 578
# SARIMA(0, 1, 1)x(2, 1, 3, 12)12 - AIC:653.1372041877362
# Optimization terminated successfully.
#          Current function value: 7.601286
#          Iterations: 4
#          Function evaluations: 203
# SARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:705.3183317156013
# Optimization terminated successfully.
#          Current function value: 7.381833
#          Iterations: 5
#          Function evaluations: 255
# SARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:687.1286788092389
# Optimization terminated successfully.
#          Current function value: 7.303567
#          Iterations: 5
#          Function evaluations: 351
# SARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:681.9281961579026
# Optimization terminated successfully.
#          Current function value: 7.298599
#          Iterations: 7
#          Function evaluations: 564
# SARIMA(0, 1, 2)x(0, 1, 3, 12)12 - AIC:683.4710824878712
# Optimization terminated successfully.
#          Current function value: 7.468027
#          Iterations: 3
#          Function evaluations: 154
# SARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:695.0584848778409
# Optimization terminated successfully.
#          Current function value: 7.352770
#          Iterations: 4
#          Function evaluations: 302
# SARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:686.4548429452707
# Optimization terminated successfully.
#          Current function value: 7.302721
#          Iterations: 7
#          Function evaluations: 517
# SARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:683.850300769369
# Optimization terminated successfully.
#          Current function value: 7.278761
#          Iterations: 6
#          Function evaluations: 530
# SARIMA(0, 1, 2)x(1, 1, 3, 12)12 - AIC:683.6460205716486
# Optimization terminated successfully.
#          Current function value: 6.938933
#          Iterations: 7
#          Function evaluations: 443
# SARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:648.3818126579914
# Optimization terminated successfully.
#          Current function value: 6.936877
#          Iterations: 10
#          Function evaluations: 740
# SARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:650.1926621533512
# Optimization terminated successfully.
#          Current function value: 6.939146
#          Iterations: 8
#          Function evaluations: 679
# SARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:652.4014504497096
# Optimization terminated successfully.
#          Current function value: 6.936932
#          Iterations: 8
#          Function evaluations: 765
# SARIMA(0, 1, 2)x(2, 1, 3, 12)12 - AIC:654.1977522634045
# Optimization terminated successfully.
#          Current function value: 7.599580
#          Iterations: 2
#          Function evaluations: 91
# SARIMA(0, 1, 3)x(0, 1, 0, 12)12 - AIC:707.1613241704498
# Optimization terminated successfully.
#          Current function value: 7.381199
#          Iterations: 5
#          Function evaluations: 323
# SARIMA(0, 1, 3)x(0, 1, 1, 12)12 - AIC:689.070292519411
# Optimization terminated successfully.
#          Current function value: 7.302165
#          Iterations: 4
#          Function evaluations: 299
# SARIMA(0, 1, 3)x(0, 1, 2, 12)12 - AIC:683.7991907635694
# Optimization terminated successfully.
#          Current function value: 7.295755
#          Iterations: 7
#          Function evaluations: 638
# SARIMA(0, 1, 3)x(0, 1, 3, 12)12 - AIC:685.2095020151457
# Optimization terminated successfully.
#          Current function value: 7.464634
#          Iterations: 4
#          Function evaluations: 250
# SARIMA(0, 1, 3)x(1, 1, 0, 12)12 - AIC:696.74628493998
# Optimization terminated successfully.
#          Current function value: 7.350360
#          Iterations: 5
#          Function evaluations: 363
# SARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:688.2331021358434
# Optimization terminated successfully.
#          Current function value: 7.300474
#          Iterations: 7
#          Function evaluations: 597
# SARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:685.6436126625567
# Optimization terminated successfully.
#          Current function value: 7.272620
#          Iterations: 5
#          Function evaluations: 492
# SARIMA(0, 1, 3)x(1, 1, 3, 12)12 - AIC:685.0810822139543
# Optimization terminated successfully.
#          Current function value: 6.936454
#          Iterations: 7
#          Function evaluations: 520
# SARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:650.1537415568041
# Optimization terminated successfully.
#          Current function value: 6.935414
#          Iterations: 8
#          Function evaluations: 680
# SARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:652.0581055257164
# Optimization terminated successfully.
#          Current function value: 6.935698
#          Iterations: 8
#          Function evaluations: 768
# SARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:654.0842403065446
# Optimization terminated successfully.
#          Current function value: 6.936844
#          Iterations: 7
#          Function evaluations: 747
# SARIMA(0, 1, 3)x(2, 1, 3, 12)12 - AIC:656.1896301422266
# Optimization terminated successfully.
#          Current function value: 7.735715
#          Iterations: 1
#          Function evaluations: 22
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:715.6857563632309
# Optimization terminated successfully.
#          Current function value: 7.518377
#          Iterations: 3
#          Function evaluations: 116
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:697.6906974865897
# Optimization terminated successfully.
#          Current function value: 7.444261
#          Iterations: 4
#          Function evaluations: 204
# SARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:692.8719931371469
# Optimization terminated successfully.
#          Current function value: 7.440696
#          Iterations: 5
#          Function evaluations: 313
# SARIMA(1, 1, 0)x(0, 1, 3, 12)12 - AIC:694.5440590471424
# Optimization terminated successfully.
#          Current function value: 7.630297
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:707.9873187595105
# Optimization terminated successfully.
#          Current function value: 7.499515
#          Iterations: 4
#          Function evaluations: 203
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:697.955385988461
# Optimization terminated successfully.
#          Current function value: 7.452434
#          Iterations: 6
#          Function evaluations: 366
# SARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:695.6239732671463
# Optimization terminated successfully.
#          Current function value: 7.397717
#          Iterations: 5
#          Function evaluations: 373
# SARIMA(1, 1, 0)x(1, 1, 3, 12)12 - AIC:692.5899874723447
# Optimization terminated successfully.
#          Current function value: 6.947397
#          Iterations: 7
#          Function evaluations: 367
# SARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:647.1605447955288
# Optimization terminated successfully.
#          Current function value: 6.946159
#          Iterations: 8
#          Function evaluations: 501
# SARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:649.0465870910798
# Optimization terminated successfully.
#          Current function value: 6.946288
#          Iterations: 7
#          Function evaluations: 520
# SARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:651.0584589258017
# Optimization terminated successfully.
#          Current function value: 6.946216
#          Iterations: 7
#          Function evaluations: 604
# SARIMA(1, 1, 0)x(2, 1, 3, 12)12 - AIC:653.0518891337967
# Optimization terminated successfully.
#          Current function value: 7.662037
#          Iterations: 4
#          Function evaluations: 161
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:710.907447824415
# Optimization terminated successfully.
#          Current function value: 7.441976
#          Iterations: 6
#          Function evaluations: 363
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:692.6618116025465
# Optimization terminated successfully.
#          Current function value: 7.359033
#          Iterations: 5
#          Function evaluations: 310
# SARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:687.0310752344751
# Optimization terminated successfully.
#          Current function value: 7.350133
#          Iterations: 7
#          Function evaluations: 520
# SARIMA(1, 1, 1)x(0, 1, 3, 12)12 - AIC:688.2122548731138
# Optimization terminated successfully.
#          Current function value: 7.535286
#          Iterations: 5
#          Function evaluations: 267
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:701.2463346212363
# Optimization terminated successfully.
#          Current function value: 7.412681
#          Iterations: 5
#          Function evaluations: 307
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:691.9666337970638
# Optimization terminated successfully.
#          Current function value: 7.359595
#          Iterations: 6
#          Function evaluations: 454
# SARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:689.082713778685
# Optimization terminated successfully.
#          Current function value: 7.329419
#          Iterations: 7
#          Function evaluations: 608
# SARIMA(1, 1, 1)x(1, 1, 3, 12)12 - AIC:688.3065099211744
# Optimization terminated successfully.
#          Current function value: 6.943998
#          Iterations: 7
#          Function evaluations: 445
# SARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:648.8478370367703
# Optimization terminated successfully.
#          Current function value: 6.942717
#          Iterations: 8
#          Function evaluations: 595
# SARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:650.7299745633829
# Optimization terminated successfully.
#          Current function value: 6.942393
#          Iterations: 8
#          Function evaluations: 679
# SARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:652.7001197525166
# Optimization terminated successfully.
#          Current function value: 6.942790
#          Iterations: 7
#          Function evaluations: 684
# SARIMA(1, 1, 1)x(2, 1, 3, 12)12 - AIC:654.7366912942215
# Optimization terminated successfully.
#          Current function value: 7.600934
#          Iterations: 2
#          Function evaluations: 102
# SARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:707.2859693524675
# Optimization terminated successfully.
#          Current function value: 7.381980
#          Iterations: 4
#          Function evaluations: 263
# SARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:689.1421722225163
# Optimization terminated successfully.
#          Current function value: 7.302710
#          Iterations: 5
#          Function evaluations: 375
# SARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:683.8492742516722
# Optimization terminated successfully.
#          Current function value: 7.293689
#          Iterations: 8
#          Function evaluations: 692
# SARIMA(1, 1, 2)x(0, 1, 3, 12)12 - AIC:685.0194124323214
# Optimization terminated successfully.
#          Current function value: 7.464805
#          Iterations: 5
#          Function evaluations: 323
# SARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:696.7620641643101
# Optimization terminated successfully.
#          Current function value: 7.350698
#          Iterations: 5
#          Function evaluations: 364
# SARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:688.2641951592778
# Optimization terminated successfully.
#          Current function value: 7.300116
#          Iterations: 7
#          Function evaluations: 735
# SARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:685.6106486246551
# Optimization terminated successfully.
#          Current function value: 7.274249
#          Iterations: 5
#          Function evaluations: 502
# SARIMA(1, 1, 2)x(1, 1, 3, 12)12 - AIC:685.2309436881244
# Optimization terminated successfully.
#          Current function value: 6.937504
#          Iterations: 8
#          Function evaluations: 611
# SARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:650.2503494309108
# Optimization terminated successfully.
#          Current function value: 6.936067
#          Iterations: 8
#          Function evaluations: 696
# SARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:652.1181946078118
# Optimization terminated successfully.
#          Current function value: 6.937049
#          Iterations: 7
#          Function evaluations: 687
# SARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:654.2084683182444
# Optimization terminated successfully.
#          Current function value: 6.937067
#          Iterations: 7
#          Function evaluations: 773
# SARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:656.2101372337223
# Optimization terminated successfully.
#          Current function value: 7.600143
#          Iterations: 2
#          Function evaluations: 123
# SARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:709.2131591182344
# Optimization terminated successfully.
#          Current function value: 7.382418
#          Iterations: 5
#          Function evaluations: 374
# SARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:691.1824722715542
# Optimization terminated successfully.
#          Current function value: 7.302964
#          Iterations: 4
#          Function evaluations: 349
# SARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:685.8726963670399
# Optimization terminated successfully.
#          Current function value: 7.297304
#          Iterations: 6
#          Function evaluations: 597
# SARIMA(1, 1, 3)x(0, 1, 3, 12)12 - AIC:687.3519226642488
# Optimization terminated successfully.
#          Current function value: 7.465921
#          Iterations: 4
#          Function evaluations: 289
# SARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:698.8647569736792
# Optimization terminated successfully.
#          Current function value: 7.350741
#          Iterations: 5
#          Function evaluations: 430
# SARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:690.268213477983
# Optimization terminated successfully.
#          Current function value: 7.301192
#          Iterations: 7
#          Function evaluations: 748
# SARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:687.709670843908
# Optimization terminated successfully.
#          Current function value: 7.271023
#          Iterations: 7
#          Function evaluations: 781
# SARIMA(1, 1, 3)x(1, 1, 3, 12)12 - AIC:686.9341039955666
# Optimization terminated successfully.
#          Current function value: 6.936478
#          Iterations: 8
#          Function evaluations: 688
# SARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:652.1559819887459
# Optimization terminated successfully.
#          Current function value: 6.935715
#          Iterations: 9
#          Function evaluations: 879
# SARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:654.0857440758955
# Optimization terminated successfully.
#          Current function value: 6.935873
#          Iterations: 8
#          Function evaluations: 875
# SARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:656.1003508641433
# Optimization terminated successfully.
#          Current function value: 6.936404
#          Iterations: 8
#          Function evaluations: 966
# SARIMA(1, 1, 3)x(2, 1, 3, 12)12 - AIC:658.1492056765643
# Optimization terminated successfully.
#          Current function value: 7.621739
#          Iterations: 2
#          Function evaluations: 70
# SARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:707.1999432474651
# Optimization terminated successfully.
#          Current function value: 7.396159
#          Iterations: 3
#          Function evaluations: 154
# SARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:688.4466213048493
# Optimization terminated successfully.
#          Current function value: 7.317448
#          Iterations: 6
#          Function evaluations: 379
# SARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:683.2052589243106
# Optimization terminated successfully.
#          Current function value: 7.317306
#          Iterations: 5
#          Function evaluations: 377
# SARIMA(2, 1, 0)x(0, 1, 3, 12)12 - AIC:685.192188303526
# Optimization terminated successfully.
#          Current function value: 7.500207
#          Iterations: 2
#          Function evaluations: 96
# SARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:698.0190730845413
# Optimization terminated successfully.
#          Current function value: 7.371742
#          Iterations: 4
#          Function evaluations: 253
# SARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:688.2002210138148
# Optimization terminated successfully.
#          Current function value: 7.321064
#          Iterations: 4
#          Function evaluations: 301
# SARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:685.5379316054124
# Optimization terminated successfully.
#          Current function value: 7.281976
#          Iterations: 5
#          Function evaluations: 431
# SARIMA(2, 1, 0)x(1, 1, 3, 12)12 - AIC:683.9417549435624
# Optimization terminated successfully.
#          Current function value: 6.936792
#          Iterations: 7
#          Function evaluations: 444
# SARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:648.1848415561958
# Optimization terminated successfully.
#          Current function value: 6.935966
#          Iterations: 9
#          Function evaluations: 676
# SARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:650.1088302180373
# Optimization terminated successfully.
#          Current function value: 6.936273
#          Iterations: 8
#          Function evaluations: 692
# SARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:652.1371325294873
# Optimization terminated successfully.
#          Current function value: 6.937308
#          Iterations: 7
#          Function evaluations: 690
# SARIMA(2, 1, 0)x(2, 1, 3, 12)12 - AIC:654.2323107314987
# Optimization terminated successfully.
#          Current function value: 7.608181
#          Iterations: 4
#          Function evaluations: 196
# SARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:707.9526402141639
# Optimization terminated successfully.
#          Current function value: 7.392091
#          Iterations: 4
#          Function evaluations: 249
# SARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:690.072414625781
# Optimization terminated successfully.
#          Current function value: 7.319001
#          Iterations: 4
#          Function evaluations: 293
# SARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:685.3481287240731
# Optimization terminated successfully.
#          Current function value: 7.317202
#          Iterations: 4
#          Function evaluations: 344
# SARIMA(2, 1, 1)x(0, 1, 3, 12)12 - AIC:687.1825652409436
# Optimization terminated successfully.
#          Current function value: 7.498650
#          Iterations: 2
#          Function evaluations: 118
# SARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:699.8758428198474
# Optimization terminated successfully.
#          Current function value: 7.370564
#          Iterations: 4
#          Function evaluations: 288
# SARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:690.0919130004175
# Optimization terminated successfully.
#          Current function value: 7.325079
#          Iterations: 6
#          Function evaluations: 504
# SARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:687.9072288543242
# Optimization terminated successfully.
#          Current function value: 7.278321
#          Iterations: 6
#          Function evaluations: 591
# SARIMA(2, 1, 1)x(1, 1, 3, 12)12 - AIC:685.6055129729621
# Optimization terminated successfully.
#          Current function value: 6.936103
#          Iterations: 7
#          Function evaluations: 514
# SARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:650.1215082070055
# Optimization terminated successfully.
#          Current function value: 6.935034
#          Iterations: 8
#          Function evaluations: 683
# SARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:652.023173754224
# Optimization terminated successfully.
#          Current function value: 6.935862
#          Iterations: 7
#          Function evaluations: 667
# SARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:654.0993286582834
# Optimization terminated successfully.
#          Current function value: 6.935443
#          Iterations: 7
#          Function evaluations: 764
# SARIMA(2, 1, 1)x(2, 1, 3, 12)12 - AIC:656.0607479548918
# Optimization terminated successfully.
#          Current function value: 7.597201
#          Iterations: 2
#          Function evaluations: 119
# SARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:708.9424570679622
# Optimization terminated successfully.
#          Current function value: 7.377420
#          Iterations: 4
#          Function evaluations: 305
# SARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:690.7226323841458
# Optimization terminated successfully.
#          Current function value: 7.301103
#          Iterations: 5
#          Function evaluations: 431
# SARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:685.7014998877403
# Optimization terminated successfully.
#          Current function value: 7.299954
#          Iterations: 6
#          Function evaluations: 576
# SARIMA(2, 1, 2)x(0, 1, 3, 12)12 - AIC:687.5957802359645
# Optimization terminated successfully.
#          Current function value: 7.466496
#          Iterations: 5
#          Function evaluations: 372
# SARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:698.9176455939311
# Optimization terminated successfully.
#          Current function value: 7.350741
#          Iterations: 5
#          Function evaluations: 435
# SARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:690.2681419127632
# Optimization terminated successfully.
#          Current function value: 7.299659
#          Iterations: 7
#          Function evaluations: 771
# SARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:687.5686194344999
# Optimization terminated successfully.
#          Current function value: 7.270459
#          Iterations: 5
#          Function evaluations: 564
# SARIMA(2, 1, 2)x(1, 1, 3, 12)12 - AIC:686.882266066521
# Optimization terminated successfully.
#          Current function value: 6.936945
#          Iterations: 7
#          Function evaluations: 617
# SARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:652.1989270380687
# Optimization terminated successfully.
#          Current function value: 6.934673
#          Iterations: 9
#          Function evaluations: 874
# SARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:653.9898882276233
# Optimization terminated successfully.
#          Current function value: 6.936708
#          Iterations: 7
#          Function evaluations: 768
# SARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:656.1771341841679
# Optimization terminated successfully.
#          Current function value: 6.936825
#          Iterations: 7
#          Function evaluations: 853
# SARIMA(2, 1, 2)x(2, 1, 3, 12)12 - AIC:658.1879135002072
# Optimization terminated successfully.
#          Current function value: 7.596792
#          Iterations: 3
#          Function evaluations: 219
# SARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:710.9048244019729
# Optimization terminated successfully.
#          Current function value: 7.378021
#          Iterations: 4
#          Function evaluations: 347
# SARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:692.7779016615498
# Optimization terminated successfully.
#          Current function value: 7.299822
#          Iterations: 5
#          Function evaluations: 491
# SARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:687.5835781687633
# Optimization terminated successfully.
#          Current function value: 7.298416
#          Iterations: 6
#          Function evaluations: 649
# SARIMA(2, 1, 3)x(0, 1, 3, 12)12 - AIC:689.4542640170624
# Optimization terminated successfully.
#          Current function value: 7.463229
#          Iterations: 7
#          Function evaluations: 595
# SARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:700.6171083791643
# Optimization terminated successfully.
#          Current function value: 7.349675
#          Iterations: 5
#          Function evaluations: 485
# SARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:692.1700582886426
# Optimization terminated successfully.
#          Current function value: 7.298700
#          Iterations: 7
#          Function evaluations: 828
# SARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:689.4804144091664
# Optimization terminated successfully.
#          Current function value: 7.268142
#          Iterations: 5
#          Function evaluations: 613
# SARIMA(2, 1, 3)x(1, 1, 3, 12)12 - AIC:688.6690466307878
# Optimization terminated successfully.
#          Current function value: 6.936560
#          Iterations: 8
#          Function evaluations: 779
# SARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:654.1634814650511
# Optimization terminated successfully.
#          Current function value: 6.936085
#          Iterations: 9
#          Function evaluations: 978
# SARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:656.1197741988348
# Optimization terminated successfully.
#          Current function value: 6.935666
#          Iterations: 8
#          Function evaluations: 956
# SARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:658.0812456923989
# Optimization terminated successfully.
#          Current function value: 6.937003
#          Iterations: 7
#          Function evaluations: 924
# SARIMA(2, 1, 3)x(2, 1, 3, 12)12 - AIC:660.2042405931368

# %%
#getting values which has minimum AIC for the time series data
#SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:645.4777029543509


mod = sm.tsa.statespace.SARIMAX(ts_tests_adj,
                                            order=(0, 1, 2),
                                seasonal_order=(2, 1, 0, 12))
#Fitting model using POWELL method: Powell method, is an algorithm proposed  for finding a local minimum of a function
results = mod.fit(method = 'powell')
#Print the results
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 6.938933
#          Iterations: 7
#          Function evaluations: 443
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1051      0.158     -0.665      0.506      -0.415       0.205
# ma.L2         -0.1909      0.169     -1.132      0.258      -0.522       0.140
# ar.S.L12      -0.9920      0.031    -32.350      0.000      -1.052      -0.932
# ar.S.L24      -0.9878      0.004   -239.720      0.000      -0.996      -0.980
# sigma2      3.872e+06   8.07e-09    4.8e+14      0.000    3.87e+06    3.87e+06
# ==============================================================================

# %%
#Valudate the Model versus the actual data

pred = results.get_prediction(start=pd.to_datetime('2020-08-02'), dynamic=False)
pred_ci = pred.conf_int()
ax = ts_tests_adj.plot(label='Observed(new_tests)')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('New tests')
plt.legend()
plt.show()

# %%
#Calculate the predicted results versus actual values
y_forecasted = pred.predicted_mean
y_truth = ts_tests_adj['2020-08-02':]
#Calculate Mean Squared Error
mse = ((y_forecasted - y_truth) ** 2).mean()
mse=round(mse, 2)
print('The Mean Squared Error is {}'.format(mse))
#Calculate Root Mean Squared Error
rmse=round(np.sqrt(mse), 2)
print('The Root Mean Squared Error is {}'.format(rmse))
#Calculate R-squared Error or Coefficient of Determination:The % variation of y on variation with x
from sklearn.metrics import r2_score 
r_squared=r2_score(y_truth, y_forecasted)
print('R-squared Error is {}'.format(r_squared))

#Since the R squared error is approximately 0.78 closer to 1 the model can predict the values of future cases with a narrow margin of error
#prediction model accuracy is 77.98% which is acceptable.
# Out:
# The Mean Squared Error is 5035568.2
# The Root Mean Squared Error is 2244.01
# R-squared Error is 0.7797946843203576

# %%
#Future Predict the results of new Tests for next 16 weeks

pred_uc = results.get_forecast(steps=16)
pred_ci = pred_uc.conf_int()
ax = ts_tests_adj.plot(label='observed', figsize=(14, 6))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('New Tests')
plt.legend()
plt.show()
#Since we are preicting weekly average the value is calcualted on every Sunday . The gap in graph shows aperiod between 
#on a gap of a week 06-Dec-2020 to 13-Dec-2020 but there is NO missing values.

# %%
#Use mean of Max and minimum values to calculate number of kits required for next 16 weeks
pred_ci['kits_required']=pred_ci.mean(axis=1)
pred_ci
kits_required=pred_ci['kits_required']

# %% [markdown]
# ## Kits required for next 12 weeks

# %% [markdown]
# ## Kits required for next 3 months are as under

# %%
cumulative_sum=0
sum=kits_required[0:3].sum()
cumulative_sum+=sum
print('Number of kits required for next month is {} '.format(sum))
sum=kits_required[4:7].sum()
cumulative_sum+=sum
print('Number of kits required for second month is {} '.format(sum))
sum=kits_required[8:11].sum()
cumulative_sum+=sum
print('Number of kits required for third month is {} '.format(sum))

print('Cumulative test cases for next three months is {}'.format(cumulative_sum))
# Out:
# Number of kits required for next month is 74300.03363642962
# Number of kits required for second month is 130781.82361499764
# Number of kits required for third month is 72017.65445259465
# Cumulative test cases for next three months is 277099.5117040219
