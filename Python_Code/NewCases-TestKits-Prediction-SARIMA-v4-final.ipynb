# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

#Loading the data from the file

#url = 'https://raw.githubusercontent.com/Sai2000-20/Covid_Cases_TestKits_TimeSeriesPrediction-SARIMA/main/Data/owid-covid-data.csv'
#df = pd.read_csv(url)


#df = pd.read_csv('C:\\Users\\Desktop\\ML\\Individual_Assignment-Project\\Data\\owid-covid-data.csv')

df = pd.read_csv('W:\\um\\Machine Learning\\INdividual Assignment Part1\\owid-covid-data.csv')

df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan   24/2/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan   25/2/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan   26/2/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan   27/2/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan   28/2/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 57799      ZWE    Africa     Zimbabwe  29/12/2020      13325.0      177.0
# 57800      ZWE    Africa     Zimbabwe  30/12/2020      13625.0      300.0
# 57801      ZWE    Africa     Zimbabwe  31/12/2020      13867.0      242.0
# 57802      ZWE    Africa     Zimbabwe    1/1/2021      14084.0      217.0
# 57803      ZWE    Africa     Zimbabwe    2/1/2021      14491.0      407.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 57799             111.571         359.0         5.0                4.714  ...
# 57800             138.429         360.0         1.0                4.286  ...
# 57801             154.429         363.0         3.0                3.429  ...
# 57802             172.000         369.0         6.0                4.000  ...
# 57803             218.286         377.0         8.0                5.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 57799        1899.775             21.4                307.846
# 57800        1899.775             21.4                307.846
# 57801        1899.775             21.4                307.846
# 57802        1899.775             21.4                307.846
# 57803        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 57799                 1.82             1.6          30.7
# 57800                 1.82             1.6          30.7
# 57801                 1.82             1.6          30.7
# 57802                 1.82             1.6          30.7
# 57803                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 57799                  36.791                         1.7            61.49
# 57800                  36.791                         1.7            61.49
# 57801                  36.791                         1.7            61.49
# 57802                  36.791                         1.7            61.49
# 57803                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 57799                    0.535
# 57800                    0.535
# 57801                    0.535
# 57802                    0.535
# 57803                    0.535
#
# [57804 rows x 52 columns]

# %%
# Describing the data.
df.describe
# It has 52 columns and 57804 rows. I will filter for the required 7 columns only that help achive my 2 objectives.
# Out:
# <bound method NDFrame.describe of       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan   24/2/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan   25/2/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan   26/2/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan   27/2/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan   28/2/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 57799      ZWE    Africa     Zimbabwe  29/12/2020      13325.0      177.0
# 57800      ZWE    Africa     Zimbabwe  30/12/2020      13625.0      300.0
# 57801      ZWE    Africa     Zimbabwe  31/12/2020      13867.0      242.0
# 57802      ZWE    Africa     Zimbabwe    1/1/2021      14084.0      217.0
# 57803      ZWE    Africa     Zimbabwe    2/1/2021      14491.0      407.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 57799             111.571         359.0         5.0                4.714  ...
# 57800             138.429         360.0         1.0                4.286  ...
# 57801             154.429         363.0         3.0                3.429  ...
# 57802             172.000         369.0         6.0                4.000  ...
# 57803             218.286         377.0         8.0                5.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 57799        1899.775             21.4                307.846
# 57800        1899.775             21.4                307.846
# 57801        1899.775             21.4                307.846
# 57802        1899.775             21.4                307.846
# 57803        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 57799                 1.82             1.6          30.7
# 57800                 1.82             1.6          30.7
# 57801                 1.82             1.6          30.7
# 57802                 1.82             1.6          30.7
# 57803                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 57799                  36.791                         1.7            61.49
# 57800                  36.791                         1.7            61.49
# 57801                  36.791                         1.7            61.49
# 57802                  36.791                         1.7            61.49
# 57803                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 57799                    0.535
# 57800                    0.535
# 57801                    0.535
# 57802                    0.535
# 57803                    0.535
#
# [57804 rows x 52 columns]>

# %%
#extracting the required 7 columns - 'iso_code','location','date','total_cases','new_cases','total_tests','new_tests'
df=df[['iso_code','location','date','total_cases','new_cases','total_tests','new_tests']]
df
#57804 rows × 7 columns
# Out:
#       iso_code     location        date  total_cases  new_cases  total_tests  \
# 0          AFG  Afghanistan   24/2/2020          1.0        1.0          NaN
# 1          AFG  Afghanistan   25/2/2020          1.0        0.0          NaN
# 2          AFG  Afghanistan   26/2/2020          1.0        0.0          NaN
# 3          AFG  Afghanistan   27/2/2020          1.0        0.0          NaN
# 4          AFG  Afghanistan   28/2/2020          1.0        0.0          NaN
# ...        ...          ...         ...          ...        ...          ...
# 57799      ZWE     Zimbabwe  29/12/2020      13325.0      177.0     212115.0
# 57800      ZWE     Zimbabwe  30/12/2020      13625.0      300.0     214577.0
# 57801      ZWE     Zimbabwe  31/12/2020      13867.0      242.0          NaN
# 57802      ZWE     Zimbabwe    1/1/2021      14084.0      217.0          NaN
# 57803      ZWE     Zimbabwe    2/1/2021      14491.0      407.0          NaN
#
#        new_tests
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 57799     2373.0
# 57800     2462.0
# 57801        NaN
# 57802        NaN
# 57803        NaN
#
# [57804 rows x 7 columns]

# %%
#Checking the datatypes of the columns 
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57804 entries, 0 to 57803
# Data columns (total 7 columns):
# iso_code       57473 non-null object
# location       57802 non-null object
# date           57804 non-null object
# total_cases    57244 non-null float64
# new_cases      57236 non-null float64
# total_tests    26706 non-null float64
# new_tests      26742 non-null float64
# dtypes: float64(4), object(3)
# memory usage: 3.1+ MB

# %%
#Check for null and not null values in the dataset

print('Count of Null values is {} and Not null values is {}'.format(df.isnull().sum().sum(),df.notnull().sum().sum()))

#Plotting Null and Not null values
import matplotlib.pyplot as plt
counts=[df.isnull().sum().sum(),df.notnull().sum().sum()]
labels=['Null Count','Not-Null Count']

#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values which need to be cleaned up.
plt.title("Cumulative count of Null and Not-null values \n" + "in entire dataset(for all countries)", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Count of Null values is 63621 and Not null values is 341007

# %% [markdown]
# ## Data Cleanup for location = Malaysia

# %%
# Checking 'location' column has  null, and missing country name
df[df['location'].isnull()==True]
# Out:
#       iso_code location      date  total_cases  new_cases  total_tests  \
# 31645      MYS      NaN  7/2/2020         12.0        0.0          0.0
# 31646      MYS      NaN  8/2/2020         16.0        4.0          0.0
#
#        new_tests
# 31645        0.0
# 31646        0.0

# %%
#'iso_code' column has  null, and missing country name

df[df['iso_code'].isnull()==True]
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 23980      NaN  International    7/2/2020         61.0       61.0
# 23981      NaN  International    8/2/2020         61.0        0.0
# 23982      NaN  International    9/2/2020         64.0        3.0
# 23983      NaN  International   10/2/2020        135.0       71.0
# 23984      NaN  International   11/2/2020        135.0        0.0
# ...        ...            ...         ...          ...        ...
# 24306      NaN  International  29/12/2020        721.0        0.0
# 24307      NaN  International  30/12/2020        721.0        0.0
# 24308      NaN  International  31/12/2020        721.0        0.0
# 24309      NaN  International    1/1/2021        721.0        0.0
# 24310      NaN  International    2/1/2021        721.0        0.0
#
#        total_tests  new_tests
# 23980          NaN        NaN
# 23981          NaN        NaN
# 23982          NaN        NaN
# 23983          NaN        NaN
# 23984          NaN        NaN
# ...            ...        ...
# 24306          NaN        NaN
# 24307          NaN        NaN
# 24308          NaN        NaN
# 24309          NaN        NaN
# 24310          NaN        NaN
#
# [331 rows x 7 columns]

# %%
#If iso_code and location is null then drop the record
for index, row in df.iterrows(): 
    if df.loc[index, 'location'] is None :    
        if df.loc[index, 'iso_code'] is None :
            df.drop(index)
print('Dropped records where location and iso_code is null')
# Out:
# Dropped records where location and iso_code is null

# %%
#Correct invalid iso_code values for location Malaysia
for index, row in df.iterrows(): 
    if df.loc[index, 'location'] =='Malaysia' :
        if df.loc[index, 'iso_code']!='MYS' :
            df.loc[index, 'iso_code']='MYS'
print('Replaced invalid iso_code values for location Malaysia')
# Out:
# Replaced invalid iso_code values for location Malaysia

# %%
#Correct invalid location values for iso_code MYS
for index, row in df.iterrows(): 
    if df.loc[index, 'iso_code'] =='MYS' :
        if df.loc[index, 'location']!='Malaysia' :
            df.loc[index, 'location']='Malaysia'
print('Replaced invalid location values for iso_code MYS ')
# Out:
# Replaced invalid location values for iso_code MYS

# %%
#We filter records for iso_code = MYS. This gives all records for Malaysia.
df=df[df['iso_code']=='MYS']
df
# I get 344 rows x 7 columns
# Out:
#       iso_code  location        date  total_cases  new_cases  total_tests  \
# 31632      MYS  Malaysia   25/1/2020          3.0        3.0          0.0
# 31633      MYS  Malaysia   26/1/2020          4.0        1.0          0.0
# 31634      MYS  Malaysia   27/1/2020          4.0        0.0          0.0
# 31635      MYS  Malaysia   28/1/2020          4.0        0.0          0.0
# 31636      MYS  Malaysia   29/1/2020          7.0        3.0          0.0
# ...        ...       ...         ...          ...        ...          ...
# 31971      MYS  Malaysia  29/12/2020     108615.0     1925.0    3291834.0
# 31972      MYS  Malaysia  30/12/2020     110485.0     1870.0    3317646.0
# 31973      MYS  Malaysia  31/12/2020     113010.0     2525.0    3343458.0
# 31974      MYS  Malaysia    1/1/2021     115078.0     2068.0    3369270.0
# 31975      MYS  Malaysia    2/1/2021     117373.0     2295.0    3395082.0
#
#        new_tests
# 31632        0.0
# 31633        0.0
# 31634        0.0
# 31635        0.0
# 31636        0.0
# ...          ...
# 31971    19954.0
# 31972    25812.0
# 31973        NaN
# 31974        NaN
# 31975        NaN
#
# [344 rows x 7 columns]

# %%
#Check for missing date values
from datetime import datetime as dt


df_cases_my=df.sort_values(by=['total_cases'])

print('Null date count is {}'.format(df_cases_my['date'].isnull().sum()))

for index, row in df_cases_my.iterrows():
    if df_cases_my.loc[index, 'date'].isspace() :
        if pd.isnull(df_cases_my.loc[index, 'total_cases']):
            df_cases_my.drop(index)#drop these rows
        else:
            
            missing_date=(pd.to_datetime(df_cases.loc[(index-1), 'date'],format="%Y-%m-%d")+ datetime.timedelta(days=1)).strftime("%Y-%m-%d")
            
            df_cases_my.loc[index,'date']=missing_date
# Out:
# Null date count is 0

# %%
# Checking for NULL values in all columns for location = Malaysia
print('For Malaysia total count of null values is {} and not null values is {} '.format(df.isnull().sum().sum(),df.notnull().sum().sum()))

counts=[df.isnull().sum().sum(),df.notnull().sum().sum()]
labels=['Null Count','Not-Null Count']

patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")

#There are a few null values which need to be cleaned up.
plt.title("Cumulative count of Null and Not-null data for \n" + "Malaysia Before Cleaning ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# For Malaysia total count of null values is 53 and not null values is 2355

# %%
#Check for datatype for each value in the columns in data 
if df.dtypes['new_tests']!= np.float64:
    print('Invalid data in columns new_tests')
else:
    print('Column new_tests datatype is fine')
    
if df.dtypes['total_cases']!= np.float64:
    print('Invalid data in columns total_cases')
else:
    print('Column total_cases datatype is fine')
    
if df.dtypes['new_cases']!= np.float64:
    print('Invalid data in columns new_cases')
else:
    print('Column new_cases datatype is fine')
    
if df.dtypes['total_tests']!= np.float64:
    print('Invalid data in columns total_tests')
else:
    print('Column total_tests datatype is fine')
    
if df.dtypes['iso_code']!= np.object:
    print('Invalid data in columns iso_code')
else:
    print('Column iso_code datatype is fine')
    
if df.dtypes['location']!= np.object:
    print('Invalid data in columns location')
else:
    print('Column location datatype is fine')
    
if df.dtypes['date']!= np.object:
    print('Invalid data in columns date')
else:
    print('Column date datatype is fine')
# Out:
# Column new_tests datatype is fine
# Column total_cases datatype is fine
# Column new_cases datatype is fine
# Column total_tests datatype is fine
# Column iso_code datatype is fine
# Column location datatype is fine
# Column date datatype is fine

# %%
# Checking if 'new_cases' column has null, and missing value
df_temp=df[df['new_cases'].isnull()==True]

if df['new_cases'].isnull().sum()==0:
    print('Column new_cases has no null values')
else:
    print('Column new_cases has {} null values . Kindly handle it'.format(df['new_cases'].isnull().sum()))

df_temp

#Graphical representation of checking 'if 'new_cases' column has`  null, and missing value

counts=[df['new_cases'].isnull().sum().sum(),df['new_cases'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_cases' column for \n" + "Malaysia ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Column new_cases has 1 null values . Kindly handle it

# %%
# Clean data for column 'new_cases' with null and missing value
import math

for index, row in df.iterrows(): 
    if np.isnan(df.loc[index, 'new_cases']):#check is 'new_cases' column has  null, and missing values
        if np.isnan(df.loc[index, 'total_cases']):# check if 'total_cases' column has  null, and missing values
            df.drop(index)#Delete the data record
        else:
            df.loc[index, 'new_cases'] =  df.loc[index , 'total_cases']-df.loc[(index - 1), 'total_cases']
            #Arrange df as per 'total_cases' column in ascending order new_cases' = current 'total_cases' value - previous 'total_cases' value

# %%
#Graphical representation of 'new_cases' column having no null and missing value post cleaning 
if df['new_cases'].isnull().sum()==0:
    print('Column new_cases has no null values')
else:
    print('Column new_cases has {} null values . Kindly handle it'.format(df['new_cases'].isnull().sum()))

counts=[df['new_cases'].isnull().sum().sum(),df['new_cases'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values which need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_cases' column post cleaning for \n" + "Malaysia ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Column new_cases has no null values

# %%
#Check if column 'new_tests' has  null values

df[df['new_tests'].isnull()==True]
if df['new_tests'].isnull().sum()==0:
    print('Column new_tests has no null values')
else:
    print('Column new_tests has {} null values . Kindly handle it'.format(df['new_tests'].isnull().sum()))

#Graphical representation of checking 'if 'new_tests' column has null, and missing value

counts=[df['new_tests'].isnull().sum().sum(),df['new_tests'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_tests' column for \n" + "Malaysia ", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Column new_tests has 52 null values . Kindly handle it

# %%
# Clean data for column 'new_tests' with null and missing value
import math
print(df['new_tests'].isnull().sum())
for index, row in df.iterrows(): 
    if np.isnan(df.loc[index, 'new_tests']):#'new_tests' column has null and missing values
        if np.isnan(df.loc[index, 'total_tests']) or df.loc[index, 'total_tests']==0.0:#'total_tests' column has null and missing values
            #print(df.loc[index])
            df.drop(index)#Delete the data record
        else:
            df.loc[index, 'new_tests'] =  df.loc[index , 'total_tests']-df.loc[(index - 1), 'total_tests']
            #print(df['new_tests'].isnull().sum())
df[df['new_tests'].isnull()]
   # Arrange df as per 'total_tests' column in ascending order new_tests' = current 'total_tests' value - previous 'total_tests' value
# Out:
# 52
# Empty DataFrame
# Columns: [iso_code, location, date, total_cases, new_cases, total_tests, new_tests]
# Index: []

# %%
#Check if column new_tests has null values after cleaning

if df['new_tests'].isnull().sum()==0.0:
    print('Column new_tests has no null values')
else:
    print('Column new_tests has {} null values . Kindly handle it'.format(df['new_tests'].isnull().sum()))

#Graphical representation of checking 'if 'new_tests' column has null, and missing value

counts=[df['new_tests'].isnull().sum().sum(),df['new_tests'].notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Count of Null and Not-null values for 'new_tests' column  post cleaning for \n" + "Malaysia", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
# Out:
# Column new_tests has no null values

# %%
#Check if dataset has null values for any of required columns

if df.isnull().sum().sum()==0:
    print('Dataset has no null values')
else:
    print('Dataset have {} null values . Kindly handle it'.format(df.isnull().sum().sum()))

#Graphical representation of checking 'if dataset has`  null, and missing value
counts=[df.isnull().sum().sum(),df.notnull().sum().sum()]
labels=['Null Count','Not-Null Count']
#colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
#patches, texts = plt.pie(counts, colors=colors, startangle=90)
patches, texts, junk  = plt.pie(counts, autopct='%1.1f%%',labels=labels,startangle=90)
plt.legend(patches, labels, loc="upper right")
#There are a few null values whihc need to be cleaned up.
plt.title("Cumulative count of Null and Not-null data \n" + "Malaysia after cleaning", bbox={'facecolor':'0.9', 'pad':5})
plt.show()
#No Null records present
# Out:
# Dataset has no null values

# %%
#Printing the final preprocessed data
df
# Out:
#       iso_code  location        date  total_cases  new_cases  total_tests  \
# 31632      MYS  Malaysia   25/1/2020          3.0        3.0          0.0
# 31633      MYS  Malaysia   26/1/2020          4.0        1.0          0.0
# 31634      MYS  Malaysia   27/1/2020          4.0        0.0          0.0
# 31635      MYS  Malaysia   28/1/2020          4.0        0.0          0.0
# 31636      MYS  Malaysia   29/1/2020          7.0        3.0          0.0
# ...        ...       ...         ...          ...        ...          ...
# 31971      MYS  Malaysia  29/12/2020     108615.0     1925.0    3291834.0
# 31972      MYS  Malaysia  30/12/2020     110485.0     1870.0    3317646.0
# 31973      MYS  Malaysia  31/12/2020     113010.0     2525.0    3343458.0
# 31974      MYS  Malaysia    1/1/2021     115078.0     2068.0    3369270.0
# 31975      MYS  Malaysia    2/1/2021     117373.0     2295.0    3395082.0
#
#        new_tests
# 31632        0.0
# 31633        0.0
# 31634        0.0
# 31635        0.0
# 31636        0.0
# ...          ...
# 31971    19954.0
# 31972    25812.0
# 31973    25812.0
# 31974    25812.0
# 31975    25812.0
#
# [344 rows x 7 columns]

# %%
#Convert String data to date datatype for time series calcualtion
##converting 'date' column to type 'datetime' so that indexing can happen later

df['date'] = pd.to_datetime(df['date'],format="%d/%m/%Y")

# %% [markdown]
# ### DATA Cleaning Complete since there are no null and invalid values in required columns - iso_code, location, date, total_cases, new_cases, total_tests, new_tests

# %% [markdown]
# # Start with Model Building

# %%
#Augmented Dickey–Fuller test (adf) is used in statistics and econometrics and it tests the null hypothesis
#that a unit root is present in a time series sample
#ADF: if the p-value is less than the critical value, the series is stationary
#create Method for ADF
from statsmodels.tsa.stattools import adfuller
def print_adf_result(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
#Kwiatkowski–Phillips–Schmidt–Shin (KPSS) tests are used for testing a null hypothesis that an observable 
#time series is stationary around a deterministic trend (i.e. trend-stationary) against the alternative of a unit root
#KPSS: if the p-value is less than the critical value, the series is stationary

#define function for kpss test
from statsmodels.tsa.stattools import kpss
def print_kpss_result(timeseries):
    print ('Results of KPSS Test is as under:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
      kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
df['date'].min(),df['date'].max()
#the date range of dta would e printed
#df
# Out:
# (Timestamp('2020-01-25 00:00:00'), Timestamp('2021-01-02 00:00:00'))

# %%
#Set standard for matplot parameters
import matplotlib as mpl

def set_plot_colour(COLOR):
    mpl.rcParams['text.color'] = COLOR
    mpl.rcParams['axes.labelcolor'] = COLOR
    mpl.rcParams['xtick.color'] = COLOR
    mpl.rcParams['ytick.color'] = COLOR
    

mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
#set colour
COLOR = 'blue'
set_plot_colour(COLOR)

# %% [markdown]
# # Objective 1:
# ### Considering current trend of COVID-19 cases in Malaysia, I want to determine if Malaysia could achieve 14 days average of below 1000 cases/day within the next 3 months(Cumulative count of new cases over 14 consecutive days should be less than 14000).

# %%
df_cases=df[['date','new_cases']]
#set index the data frame by ‘Date 
df_cases=df_cases.set_index('date')

# %%
# Getting Weekly Average. Aggregate the data from daily to Weekly in order to carry out the analysis
cases_ts_weekly_avg = df_cases['new_cases'].resample('W').mean()
#W : weekly frequency
#M : month end frequency
#SM : semi-month end frequency (15th and end of month)
#Q : quarter end frequency
cases_ts_weekly_avg
# Out:
# date
# 2020-01-26       2.000000
# 2020-02-02       0.571429
# 2020-02-09       1.142857
# 2020-02-16       0.857143
# 2020-02-23       0.000000
# 2020-03-01       1.000000
# 2020-03-08      10.000000
# 2020-03-15      47.000000
# 2020-03-22     125.428571
# 2020-03-29     166.285714
# 2020-04-05     170.285714
# 2020-04-12     145.857143
# 2020-04-19     100.857143
# 2020-04-26      55.857143
# 2020-05-03      74.000000
# 2020-05-10      51.142857
# 2020-05-17      34.000000
# 2020-05-24      50.142857
# 2020-05-31      82.000000
# 2020-06-07      71.857143
# 2020-06-14      18.714286
# 2020-06-21      17.000000
# 2020-06-28       8.857143
# 2020-07-05       4.142857
# 2020-07-12       7.857143
# 2020-07-19       8.714286
# 2020-07-26      16.857143
# 2020-08-02      14.571429
# 2020-08-09      12.000000
# 2020-08-16      16.714286
# 2020-08-23       9.571429
# 2020-08-30       9.571429
# 2020-09-06       9.000000
# 2020-09-13      74.000000
# 2020-09-20      43.428571
# 2020-09-27     100.000000
# 2020-10-04     208.857143
# 2020-10-11     468.000000
# 2020-10-18     691.571429
# 2020-10-25     866.714286
# 2020-11-01     848.571429
# 2020-11-08    1100.571429
# 2020-11-15    1029.714286
# 2020-11-22    1051.142857
# 2020-11-29    1387.142857
# 2020-12-06    1172.714286
# 2020-12-13    1540.142857
# 2020-12-20    1404.857143
# 2020-12-27    1683.857143
# 2021-01-03    2046.166667
# Freq: W-SUN, Name: new_cases, dtype: float64

# %% [markdown]
# X = cases_ts_weekly_avg
# train_size = int(len(X) * 0.7)
# train, test = X[0:train_size], X[train_size:len(X)]
# print('Observations: %d' % (len(X)))
# print('Training Observations: %d' % (len(train)))
# print('Testing Observations: %d' % (len(test)))

# %%
#Plotting the series for weekly average of new cases
import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')

ax=cases_ts_weekly_avg.plot(label='Actual New Cases',figsize=(15, 8))
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Cases')
ax.set_title('Weekly Average of Actual New Cases')
plt.show()

# %%
#decomposed time series to get components Trend, Seasonality &  Noise
from pylab import rcParams
import statsmodels.api as sm

rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(cases_ts_weekly_avg, model='additive', extrapolate_trend='freq', period=1)
fig = decomposition.plot()
plt.show()

# %%
# Plotting the Auto Correlation Function(ACF) and Partial Auto Correlation Function(PACF) Plot of the Trend and Seasonally adjusted Time Series data
#to determine  p and seasonal P, q and seasonal Q
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#Plot the autocorrelation function

plot_acf(cases_ts_weekly_avg,use_vlines=True,title='Graph of Auto corelation for new_cases', lags=45)
mpl.pyplot.show()
#The trendwas initially decreasing in initial few weeks and then it started increasing . The change in trend results in change in corelation.
#ACF plot Spikes at lag =1 means a probable Autoregressive(AR)  order of 1 and seasonal AR order of 1

#Plots lags on the horizontal and the partial correlations on vertical axis for time-series data using method='ols'.
plot_pacf(cases_ts_weekly_avg,use_vlines=True,method='ols' ,title='Graph of Partial Auto corelation for new_cases', lags=22)
mpl.pyplot.show()
#PACF plot spikes at lag=1 and then spikes at lag=10 & lag=20, which means a probable Moving Average(MA) order of 1 or 2 and seasonal MA order of 1

# %%
#apply adf test and kpss test on the series to check whether series is stationery
print(print_adf_result(cases_ts_weekly_avg))
print(print_kpss_result(cases_ts_weekly_avg))
#ADF: if the p-value is less than the critical value , the series is stationary
#P valie is 0.99 whihc is not less than critical value of 0.05 so statistically we can confirm that the series is not stationary.
#Hence, we would do first-order differencing for the trend and re-run the ADF test to check for stationarity.
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  2.527069
# p-value                         0.999058
# #Lags Used                      4.000000
# Number of Observations Used    45.000000
# Critical Value (1%)            -3.584829
# Critical Value (5%)            -2.928299
# Critical Value (10%)           -2.602344
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.405789
# p-value                   0.074660
# Lags Used                11.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing First Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(1)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For first oder differencing p =0.99 NOT less than 0.05 so going for second order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  0.864603
# p-value                         0.992611
# #Lags Used                     10.000000
# Number of Observations Used    38.000000
# Critical Value (1%)            -3.615509
# Critical Value (5%)            -2.941262
# Critical Value (10%)           -2.609200
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.433610
# p-value                   0.062668
# Lags Used                11.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing Second Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(2)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Second oder differencing p =0.93 NOT less than 0.05 so going for Third order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.239447
# p-value                         0.933653
# #Lags Used                      8.000000
# Number of Observations Used    39.000000
# Critical Value (1%)            -3.610400
# Critical Value (5%)            -2.939109
# Critical Value (10%)           -2.608063
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.434182
# p-value                   0.062421
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing Third Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(3)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Third oder differencing p =0.99 NOT less than 0.05 so going for Fourth order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  0.829517
# p-value                         0.992098
# #Lags Used                      9.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.402184
# p-value                   0.076214
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing fourth Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(4)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Fourth order differencing p =0.91 NOT less than 0.05 so going for Fifth order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.343366
# p-value                         0.919134
# #Lags Used                      4.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.397748
# p-value                   0.078126
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing Fifth Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(5)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Fifth oder differencing p =0.91 NOT less than 0.05 so going for Sixth order differencing
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.373013
# p-value                         0.914508
# #Lags Used                      7.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.378264
# p-value                   0.086524
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing Sixth Order differencing
ts_cases_adj = cases_ts_weekly_avg - cases_ts_weekly_avg.shift(6)
#ts_cases_adj =cases_ts_weekly_avg
ts_cases_adj = ts_cases_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_cases_adj))
print(print_kpss_result(ts_cases_adj))
#For Sixth oder differencing p =0.99 which is not less than 0.05 so the series is not trend stationary
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  1.167763
# p-value                         0.995755
# #Lags Used                      6.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.378179
# p-value                   0.086561
# Lags Used                10.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
# Plotting the adjusted new_cases with shift of 6 weeks
ax=ts_cases_adj.plot(figsize=(15, 8))
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Cases')
ax.set_title('Weekly Average of Adjusted New Cases WITH shift of 6 weeks')
plt.show()

# %%
# Plotting the adjusted new_cases without shift of 6 weeks.
# In the above graph I tried using differencing to test the shifting values.
#But as you can see it shows drop in the cases in later months which is not the case. Thus discarding the differencing values
# I consider only the average value and it gives the accurate picture.
ts_cases_adj=cases_ts_weekly_avg
ax=ts_cases_adj.plot(figsize=(15, 8))
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Cases')
ax.set_title('Weekly Average of Adjusted New Cases WITHOUT shift of 6 weeks')
plt.show()

# %%
import itertools
import statsmodels.api as sm
#The variables p,P,d,D,q,Q are defined as under
#p and seasonal P: indicate the number of AR terms (lags of the stationary series)
#d and seasonal D: indicate differencing that must be done to stationary series
#q and seasonal Q: indicate the number of MA terms (lags of the forecast errors)
#lag: indicates the seasonal length in the data
#setting prameters for SARIMA

p = range(0, 3)
d = range(1,2)
q = range(0, 4)

pdq = list(itertools.product(p, d, q))
print(pdq)
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
seasonal_pdq
# Out:
# [(0, 1, 0), (0, 1, 1), (0, 1, 2), (0, 1, 3), (1, 1, 0), (1, 1, 1), (1, 1, 2), (1, 1, 3), (2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 1, 3)]
# Examples of parameter combinations for Seasonal SARIMA...
# SARIMAX: (0, 1, 1) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 1) x (0, 1, 2, 12)
# SARIMAX: (0, 1, 2) x (0, 1, 3, 12)
# [(0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 2, 12),
#  (0, 1, 3, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12),
#  (1, 1, 2, 12),
#  (1, 1, 3, 12),
#  (2, 1, 0, 12),
#  (2, 1, 1, 12),
#  (2, 1, 2, 12),
#  (2, 1, 3, 12)]

# %%
#Performing a grid search with the list of possible values around our estimated parameters. We have to  pick the model with the least AIC.
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod_cases = sm.tsa.statespace.SARIMAX(ts_cases_adj,
                                            order=param,
                                            seasonal_order=param_seasonal,)
            results = mod_cases.fit(method = 'powell')
            print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
#AIC (Akaike information criterion) is an estimator of the relative quality of statistical models for a given set of data
# Out:
# Optimization terminated successfully.
#          Current function value: 4.689378
#          Iterations: 2
#          Function evaluations: 43
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:470.93783816438486
# Optimization terminated successfully.
#          Current function value: 4.687607
#          Iterations: 2
#          Function evaluations: 45
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:472.76068052338474
# Optimization terminated successfully.
#          Current function value: 4.685895
#          Iterations: 2
#          Function evaluations: 68
# SARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:474.589541128883
# Optimization terminated successfully.
#          Current function value: 4.686115
#          Iterations: 3
#          Function evaluations: 137
# SARIMA(0, 1, 0)x(0, 1, 3, 12)12 - AIC:476.61152972779513
# Optimization terminated successfully.
#          Current function value: 4.688043
#          Iterations: 2
#          Function evaluations: 44
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:472.8042656344723
# Optimization terminated successfully.
#          Current function value: 4.687906
#          Iterations: 2
#          Function evaluations: 74
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:474.79055755790415
# Optimization terminated successfully.
#          Current function value: 4.685880
#          Iterations: 2
#          Function evaluations: 89
# SARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:476.5880063409753
# Optimization terminated successfully.
#          Current function value: 4.684986
#          Iterations: 3
#          Function evaluations: 167
# SARIMA(0, 1, 0)x(1, 1, 3, 12)12 - AIC:478.49863799822435
# Optimization terminated successfully.
#          Current function value: 4.685860
#          Iterations: 3
#          Function evaluations: 100
# SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:474.58604999657405
# Optimization terminated successfully.
#          Current function value: 4.685863
#          Iterations: 2
#          Function evaluations: 87
# SARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:476.58628515309005
# Optimization terminated successfully.
#          Current function value: 4.685862
#          Iterations: 2
#          Function evaluations: 113
# SARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:478.5861551105394
# Optimization terminated successfully.
#          Current function value: 4.684766
#          Iterations: 3
#          Function evaluations: 199
# SARIMA(0, 1, 0)x(2, 1, 3, 12)12 - AIC:480.476618310709
# Optimization terminated successfully.
#          Current function value: 4.677730
#          Iterations: 2
#          Function evaluations: 44
# SARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:471.7730470155446
# Optimization terminated successfully.
#          Current function value: 4.672678
#          Iterations: 2
#          Function evaluations: 65
# SARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:473.26783420871146
# Optimization terminated successfully.
#          Current function value: 4.670939
#          Iterations: 2
#          Function evaluations: 89
# SARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:475.0938792671406
# Optimization terminated successfully.
#          Current function value: 4.670887
#          Iterations: 2
#          Function evaluations: 110
# SARIMA(0, 1, 1)x(0, 1, 3, 12)12 - AIC:477.08871631644666
# Optimization terminated successfully.
#          Current function value: 4.674021
#          Iterations: 2
#          Function evaluations: 64
# SARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:473.4021002739741
# Optimization terminated successfully.
#          Current function value: 4.673468
#          Iterations: 3
#          Function evaluations: 129
# SARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:475.3467672587437
# Optimization terminated successfully.
#          Current function value: 4.670921
#          Iterations: 2
#          Function evaluations: 109
# SARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:477.09209826136447
# Optimization terminated successfully.
#          Current function value: 4.670834
#          Iterations: 2
#          Function evaluations: 133
# SARIMA(0, 1, 1)x(1, 1, 3, 12)12 - AIC:479.0834399818715
# Optimization terminated successfully.
#          Current function value: 4.670893
#          Iterations: 2
#          Function evaluations: 85
# SARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:475.08931659598176
# Optimization terminated successfully.
#          Current function value: 4.670889
#          Iterations: 2
#          Function evaluations: 108
# SARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:477.0888959175201
# Optimization terminated successfully.
#          Current function value: 4.670891
#          Iterations: 2
#          Function evaluations: 130
# SARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:479.08911866607923
# Optimization terminated successfully.
#          Current function value: 4.670784
#          Iterations: 2
#          Function evaluations: 156
# SARIMA(0, 1, 1)x(2, 1, 3, 12)12 - AIC:481.07842924627425
# Optimization terminated successfully.
#          Current function value: 4.531971
#          Iterations: 3
#          Function evaluations: 111
# SARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:459.1970854624666
# Optimization terminated successfully.
#          Current function value: 4.530669
#          Iterations: 3
#          Function evaluations: 144
# SARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:461.0669349702579
# Optimization terminated successfully.
#          Current function value: 4.528586
#          Iterations: 3
#          Function evaluations: 172
# SARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:462.8585966482205
# Optimization terminated successfully.
#          Current function value: 4.528021
#          Iterations: 3
#          Function evaluations: 209
# SARIMA(0, 1, 2)x(0, 1, 3, 12)12 - AIC:464.80212388576814
# Optimization terminated successfully.
#          Current function value: 4.530922
#          Iterations: 3
#          Function evaluations: 147
# SARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:461.09215249168415
# Optimization terminated successfully.
#          Current function value: 4.530848
#          Iterations: 3
#          Function evaluations: 184
# SARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:463.0847516406198
# Optimization terminated successfully.
#          Current function value: 4.528561
#          Iterations: 3
#          Function evaluations: 206
# SARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:464.85605139636544
# Optimization terminated successfully.
#          Current function value: 4.527911
#          Iterations: 3
#          Function evaluations: 241
# SARIMA(0, 1, 2)x(1, 1, 3, 12)12 - AIC:466.79108545095386
# Optimization terminated successfully.
#          Current function value: 4.528535
#          Iterations: 3
#          Function evaluations: 170
# SARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:462.8534512117774
# Optimization terminated successfully.
#          Current function value: 4.528534
#          Iterations: 3
#          Function evaluations: 213
# SARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:464.85342167412404
# Optimization terminated successfully.
#          Current function value: 4.528535
#          Iterations: 3
#          Function evaluations: 238
# SARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:466.8535119472873
# Optimization terminated successfully.
#          Current function value: 4.527783
#          Iterations: 3
#          Function evaluations: 278
# SARIMA(0, 1, 2)x(2, 1, 3, 12)12 - AIC:468.778314929353
# Optimization terminated successfully.
#          Current function value: 4.525380
#          Iterations: 2
#          Function evaluations: 92
# SARIMA(0, 1, 3)x(0, 1, 0, 12)12 - AIC:460.5380035304879
# Optimization terminated successfully.
#          Current function value: 4.517790
#          Iterations: 4
#          Function evaluations: 232
# SARIMA(0, 1, 3)x(0, 1, 1, 12)12 - AIC:461.7790155354298
# Optimization terminated successfully.
#          Current function value: 4.516119
#          Iterations: 4
#          Function evaluations: 278
# SARIMA(0, 1, 3)x(0, 1, 2, 12)12 - AIC:463.6118845691473
# Optimization terminated successfully.
#          Current function value: 4.516032
#          Iterations: 4
#          Function evaluations: 321
# SARIMA(0, 1, 3)x(0, 1, 3, 12)12 - AIC:465.6031678472979
# Optimization terminated successfully.
#          Current function value: 4.519617
#          Iterations: 3
#          Function evaluations: 169
# SARIMA(0, 1, 3)x(1, 1, 0, 12)12 - AIC:461.9617160267843
# Optimization terminated successfully.
#          Current function value: 4.518644
#          Iterations: 4
#          Function evaluations: 273
# SARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:463.8644080878219
# Optimization terminated successfully.
#          Current function value: 4.516173
#          Iterations: 4
#          Function evaluations: 324
# SARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:465.6172739405976
# Optimization terminated successfully.
#          Current function value: 4.515950
#          Iterations: 4
#          Function evaluations: 365
# SARIMA(0, 1, 3)x(1, 1, 3, 12)12 - AIC:467.59497291367717
# Optimization terminated successfully.
#          Current function value: 4.516415
#          Iterations: 3
#          Function evaluations: 199
# SARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:463.64146196005464
# Optimization terminated successfully.
#          Current function value: 4.516254
#          Iterations: 3
#          Function evaluations: 232
# SARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:465.625432140199
# Optimization terminated successfully.
#          Current function value: 4.516410
#          Iterations: 3
#          Function evaluations: 267
# SARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:467.6409736505418
# Optimization terminated successfully.
#          Current function value: 4.515763
#          Iterations: 4
#          Function evaluations: 408
# SARIMA(0, 1, 3)x(2, 1, 3, 12)12 - AIC:469.57631410770585
# Optimization terminated successfully.
#          Current function value: 4.666080
#          Iterations: 1
#          Function evaluations: 21
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:470.6079939616386
# Optimization terminated successfully.
#          Current function value: 4.655875
#          Iterations: 3
#          Function evaluations: 110
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:471.58745179731454
# Optimization terminated successfully.
#          Current function value: 4.654220
#          Iterations: 3
#          Function evaluations: 149
# SARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:473.42197712022636
# Optimization terminated successfully.
#          Current function value: 4.654197
#          Iterations: 3
#          Function evaluations: 178
# SARIMA(1, 1, 0)x(0, 1, 3, 12)12 - AIC:475.4197386800899
# Optimization terminated successfully.
#          Current function value: 4.658768
#          Iterations: 2
#          Function evaluations: 68
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:471.87677221557703
# Optimization terminated successfully.
#          Current function value: 4.656394
#          Iterations: 4
#          Function evaluations: 182
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:473.6393711803296
# Optimization terminated successfully.
#          Current function value: 4.654215
#          Iterations: 3
#          Function evaluations: 175
# SARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:475.4214919318997
# Optimization terminated successfully.
#          Current function value: 4.654190
#          Iterations: 3
#          Function evaluations: 208
# SARIMA(1, 1, 0)x(1, 1, 3, 12)12 - AIC:477.4189922791456
# Optimization terminated successfully.
#          Current function value: 4.654197
#          Iterations: 3
#          Function evaluations: 141
# SARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:473.4196958547094
# Optimization terminated successfully.
#          Current function value: 4.654201
#          Iterations: 2
#          Function evaluations: 112
# SARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:475.4201307229319
# Optimization terminated successfully.
#          Current function value: 4.654198
#          Iterations: 3
#          Function evaluations: 210
# SARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:477.4197751464104
# Optimization terminated successfully.
#          Current function value: 4.654157
#          Iterations: 3
#          Function evaluations: 244
# SARIMA(1, 1, 0)x(2, 1, 3, 12)12 - AIC:479.41574028819286
# Optimization terminated successfully.
#          Current function value: 4.665535
#          Iterations: 4
#          Function evaluations: 164
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:472.55350351335267
# Optimization terminated successfully.
#          Current function value: 4.686036
#          Iterations: 2
#          Function evaluations: 97
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:476.60362406561023
# Optimization terminated successfully.
#          Current function value: 4.684438
#          Iterations: 2
#          Function evaluations: 120
# SARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:478.44383126403045
# Optimization terminated successfully.
#          Current function value: 4.684426
#          Iterations: 2
#          Function evaluations: 146
# SARIMA(1, 1, 1)x(0, 1, 3, 12)12 - AIC:480.4425813453723
# Optimization terminated successfully.
#          Current function value: 4.686557
#          Iterations: 2
#          Function evaluations: 94
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:476.65569295707223
# Optimization terminated successfully.
#          Current function value: 4.686911
#          Iterations: 2
#          Function evaluations: 121
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:478.6910586707356
# Optimization terminated successfully.
#          Current function value: 4.684419
#          Iterations: 2
#          Function evaluations: 153
# SARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:480.4419056662972
# Optimization terminated successfully.
#          Current function value: 4.684340
#          Iterations: 2
#          Function evaluations: 171
# SARIMA(1, 1, 1)x(1, 1, 3, 12)12 - AIC:482.4339793221298
# Optimization terminated successfully.
#          Current function value: 4.684399
#          Iterations: 2
#          Function evaluations: 119
# SARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:478.43988220300315
# Optimization terminated successfully.
#          Current function value: 4.685263
#          Iterations: 2
#          Function evaluations: 142
# SARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:480.52631761913506
# Optimization terminated successfully.
#          Current function value: 4.684416
#          Iterations: 2
#          Function evaluations: 166
# SARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:482.44163236289376
# Optimization terminated successfully.
#          Current function value: 4.684263
#          Iterations: 2
#          Function evaluations: 195
# SARIMA(1, 1, 1)x(2, 1, 3, 12)12 - AIC:484.42632600177393
# Optimization terminated successfully.
#          Current function value: 4.521755
#          Iterations: 4
#          Function evaluations: 188
# SARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:460.1755148686563
# Optimization terminated successfully.
#          Current function value: 4.513159
#          Iterations: 4
#          Function evaluations: 236
# SARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:461.31591909168935
# Optimization terminated successfully.
#          Current function value: 4.511074
#          Iterations: 4
#          Function evaluations: 283
# SARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:463.1073977290241
# Optimization terminated successfully.
#          Current function value: 4.511106
#          Iterations: 4
#          Function evaluations: 322
# SARIMA(1, 1, 2)x(0, 1, 3, 12)12 - AIC:465.11057001060215
# Optimization terminated successfully.
#          Current function value: 4.515132
#          Iterations: 4
#          Function evaluations: 231
# SARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:461.5131838454594
# Optimization terminated successfully.
#          Current function value: 4.514366
#          Iterations: 4
#          Function evaluations: 275
# SARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:463.43662277678357
# Optimization terminated successfully.
#          Current function value: 4.511165
#          Iterations: 4
#          Function evaluations: 325
# SARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:465.11646004443526
# Optimization terminated successfully.
#          Current function value: 4.511023
#          Iterations: 4
#          Function evaluations: 364
# SARIMA(1, 1, 2)x(1, 1, 3, 12)12 - AIC:467.102289510788
# Optimization terminated successfully.
#          Current function value: 4.511277
#          Iterations: 4
#          Function evaluations: 275
# SARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:463.12773078074343
# Optimization terminated successfully.
#          Current function value: 4.511299
#          Iterations: 4
#          Function evaluations: 319
# SARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:465.12985710005546
# Optimization terminated successfully.
#          Current function value: 4.511275
#          Iterations: 4
#          Function evaluations: 366
# SARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:467.12754943148866
# Optimization terminated successfully.
#          Current function value: 4.510796
#          Iterations: 4
#          Function evaluations: 413
# SARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:469.07960761304156
# Optimization terminated successfully.
#          Current function value: 4.521746
#          Iterations: 5
#          Function evaluations: 301
# SARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:462.17456608413625
# Optimization terminated successfully.
#          Current function value: 4.512702
#          Iterations: 6
#          Function evaluations: 415
# SARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:463.27021022985696
# Optimization terminated successfully.
#          Current function value: 4.510719
#          Iterations: 6
#          Function evaluations: 479
# SARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:465.07193582140565
# Optimization terminated successfully.
#          Current function value: 4.509668
#          Iterations: 6
#          Function evaluations: 546
# SARIMA(1, 1, 3)x(0, 1, 3, 12)12 - AIC:466.9668359840713
# Optimization terminated successfully.
#          Current function value: 4.514790
#          Iterations: 5
#          Function evaluations: 352
# SARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:463.4789594303925
# Optimization terminated successfully.
#          Current function value: 4.512067
#          Iterations: 6
#          Function evaluations: 481
# SARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:465.2066741179164
# Optimization terminated successfully.
#          Current function value: 4.510824
#          Iterations: 6
#          Function evaluations: 551
# SARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:467.08240612275506
# Optimization terminated successfully.
#          Current function value: 4.509133
#          Iterations: 6
#          Function evaluations: 615
# SARIMA(1, 1, 3)x(1, 1, 3, 12)12 - AIC:468.9132938866418
# Optimization terminated successfully.
#          Current function value: 4.511176
#          Iterations: 6
#          Function evaluations: 484
# SARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:465.1176321713992
# Optimization terminated successfully.
#          Current function value: 4.510687
#          Iterations: 6
#          Function evaluations: 537
# SARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:467.0687303349174
# Optimization terminated successfully.
#          Current function value: 4.511197
#          Iterations: 6
#          Function evaluations: 619
# SARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:469.1196955597883
# Optimization terminated successfully.
#          Current function value: 4.508083
#          Iterations: 7
#          Function evaluations: 813
# SARIMA(1, 1, 3)x(2, 1, 3, 12)12 - AIC:470.8083004107869
# Optimization terminated successfully.
#          Current function value: 4.580685
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:464.06845728355944
# Optimization terminated successfully.
#          Current function value: 4.575554
#          Iterations: 3
#          Function evaluations: 141
# SARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:465.55539974204817
# Optimization terminated successfully.
#          Current function value: 4.574124
#          Iterations: 3
#          Function evaluations: 175
# SARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:467.4124408673154
# Optimization terminated successfully.
#          Current function value: 4.574099
#          Iterations: 3
#          Function evaluations: 207
# SARIMA(2, 1, 0)x(0, 1, 3, 12)12 - AIC:469.4098901900658
# Optimization terminated successfully.
#          Current function value: 4.576767
#          Iterations: 2
#          Function evaluations: 92
# SARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:465.67665733106134
# Optimization terminated successfully.
#          Current function value: 4.576331
#          Iterations: 3
#          Function evaluations: 173
# SARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:467.63307964482465
# Optimization terminated successfully.
#          Current function value: 4.574149
#          Iterations: 3
#          Function evaluations: 207
# SARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:469.414883535538
# Optimization terminated successfully.
#          Current function value: 4.574093
#          Iterations: 3
#          Function evaluations: 236
# SARIMA(2, 1, 0)x(1, 1, 3, 12)12 - AIC:471.4092959810145
# Optimization terminated successfully.
#          Current function value: 4.574182
#          Iterations: 3
#          Function evaluations: 173
# SARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:467.4181939471511
# Optimization terminated successfully.
#          Current function value: 4.574179
#          Iterations: 2
#          Function evaluations: 139
# SARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:469.4178658091213
# Optimization terminated successfully.
#          Current function value: 4.574189
#          Iterations: 2
#          Function evaluations: 160
# SARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:471.41893140085006
# Optimization terminated successfully.
#          Current function value: 4.574061
#          Iterations: 3
#          Function evaluations: 274
# SARIMA(2, 1, 0)x(2, 1, 3, 12)12 - AIC:473.40613203400954
# Optimization terminated successfully.
#          Current function value: 4.531977
#          Iterations: 5
#          Function evaluations: 240
# SARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:461.19774657710735
# Optimization terminated successfully.
#          Current function value: 4.527087
#          Iterations: 4
#          Function evaluations: 239
# SARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:462.7087207899938
# Optimization terminated successfully.
#          Current function value: 4.525874
#          Iterations: 4
#          Function evaluations: 286
# SARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:464.5874083676698
# Optimization terminated successfully.
#          Current function value: 4.525908
#          Iterations: 4
#          Function evaluations: 329
# SARIMA(2, 1, 1)x(0, 1, 3, 12)12 - AIC:466.5907870771794
# Optimization terminated successfully.
#          Current function value: 4.527811
#          Iterations: 5
#          Function evaluations: 293
# SARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:462.781117634485
# Optimization terminated successfully.
#          Current function value: 4.526589
#          Iterations: 5
#          Function evaluations: 353
# SARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:464.6588932402464
# Optimization terminated successfully.
#          Current function value: 4.525833
#          Iterations: 4
#          Function evaluations: 328
# SARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:466.58333244151027
# Optimization terminated successfully.
#          Current function value: 4.525888
#          Iterations: 4
#          Function evaluations: 377
# SARIMA(2, 1, 1)x(1, 1, 3, 12)12 - AIC:468.58881625304065
# Optimization terminated successfully.
#          Current function value: 4.525810
#          Iterations: 4
#          Function evaluations: 280
# SARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:464.58100032049026
# Optimization terminated successfully.
#          Current function value: 4.525623
#          Iterations: 5
#          Function evaluations: 401
# SARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:466.5623380417315
# Optimization terminated successfully.
#          Current function value: 4.525806
#          Iterations: 4
#          Function evaluations: 376
# SARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:468.58060750103675
# Optimization terminated successfully.
#          Current function value: 4.525139
#          Iterations: 5
#          Function evaluations: 527
# SARIMA(2, 1, 1)x(2, 1, 3, 12)12 - AIC:470.5139310934933
# Optimization terminated successfully.
#          Current function value: 4.524435
#          Iterations: 2
#          Function evaluations: 115
# SARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:462.4435128252581
# Optimization terminated successfully.
#          Current function value: 4.500178
#          Iterations: 13
#          Function evaluations: 903
# SARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:462.0177922287211
# Optimization terminated successfully.
#          Current function value: 4.519831
#          Iterations: 3
#          Function evaluations: 242
# SARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:465.9831300339593
# Optimization terminated successfully.
#          Current function value: 4.519715
#          Iterations: 3
#          Function evaluations: 277
# SARIMA(2, 1, 2)x(0, 1, 3, 12)12 - AIC:467.97154845323854
# Optimization terminated successfully.
#          Current function value: 4.522835
#          Iterations: 3
#          Function evaluations: 207
# SARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:464.28354835664277
# Optimization terminated successfully.
#          Current function value: 4.522567
#          Iterations: 3
#          Function evaluations: 240
# SARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:466.25672563823366
# Optimization terminated successfully.
#          Current function value: 4.519820
#          Iterations: 3
#          Function evaluations: 275
# SARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:467.98195345661566
# Optimization terminated successfully.
#          Current function value: 4.519667
#          Iterations: 3
#          Function evaluations: 310
# SARIMA(2, 1, 2)x(1, 1, 3, 12)12 - AIC:469.96669361437097
# Optimization terminated successfully.
#          Current function value: 4.519805
#          Iterations: 3
#          Function evaluations: 240
# SARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:465.9804817424394
# Optimization terminated successfully.
#          Current function value: 4.519548
#          Iterations: 3
#          Function evaluations: 273
# SARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:467.95478587351863
# Optimization terminated successfully.
#          Current function value: 4.519797
#          Iterations: 3
#          Function evaluations: 310
# SARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:469.97967663038764
# Optimization terminated successfully.
#          Current function value: 4.519575
#          Iterations: 3
#          Function evaluations: 346
# SARIMA(2, 1, 2)x(2, 1, 3, 12)12 - AIC:471.9574529980847
# Optimization terminated successfully.
#          Current function value: 4.490208
#          Iterations: 7
#          Function evaluations: 493
# SARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:461.02078988573334
# Optimization terminated successfully.
#          Current function value: 4.489415
#          Iterations: 7
#          Function evaluations: 581
# SARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:462.94147871681514
# Optimization terminated successfully.
#          Current function value: 4.490446
#          Iterations: 7
#          Function evaluations: 649
# SARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:465.0446170004399
# Optimization terminated successfully.
#          Current function value: 4.487125
#          Iterations: 7
#          Function evaluations: 737
# SARIMA(2, 1, 3)x(0, 1, 3, 12)12 - AIC:466.71247049350626
# Optimization terminated successfully.
#          Current function value: 4.489302
#          Iterations: 7
#          Function evaluations: 572
# SARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:462.930167329763
# Optimization terminated successfully.
#          Current function value: 4.488224
#          Iterations: 7
#          Function evaluations: 651
# SARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:464.8224352386494
# Optimization terminated successfully.
#          Current function value: 4.490679
#          Iterations: 7
#          Function evaluations: 724
# SARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:467.0679242454712
# Optimization terminated successfully.
#          Current function value: 4.487123
#          Iterations: 7
#          Function evaluations: 805
# SARIMA(2, 1, 3)x(1, 1, 3, 12)12 - AIC:468.7122740218312
# Optimization terminated successfully.
#          Current function value: 4.486855
#          Iterations: 7
#          Function evaluations: 646
# SARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:464.68548546151567
# Optimization terminated successfully.
#          Current function value: 4.485899
#          Iterations: 8
#          Function evaluations: 819
# SARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:466.58991252899546
# Optimization terminated successfully.
#          Current function value: 4.490754
#          Iterations: 7
#          Function evaluations: 798
# SARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:469.07537736429776
# Optimization terminated successfully.
#          Current function value: 4.487004
#          Iterations: 7
#          Function evaluations: 886
# SARIMA(2, 1, 3)x(2, 1, 3, 12)12 - AIC:470.70039810501174

# %%
#getting values which has minimum AIC for the time series data
#SARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:459.1970854624666

mod_cases = sm.tsa.statespace.SARIMAX(ts_cases_adj,
                                            order=(0, 1, 2),
                                seasonal_order=(0, 1, 0, 12))
#Fitting model using POWELL method: Powell method, is an algorithm proposed  for finding a local minimum of a function
results_cases = mod_cases.fit(method = 'powell')
#Print the results
print(results_cases.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 4.531971
#          Iterations: 3
#          Function evaluations: 111
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1408      0.095     -1.486      0.137      -0.327       0.045
# ma.L2          0.6227      0.119      5.218      0.000       0.389       0.857
# sigma2       1.19e+04   2429.748      4.898      0.000    7139.719    1.67e+04
# ==============================================================================

# %%
# Plotting the ACF and PACF Plot of the Trend and Seasonally adjusted Time Series data
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_cases_adj)
mpl.pyplot.show()
plot_pacf(ts_cases_adj)
mpl.pyplot.show()

# %%
#Plotting Standard residual for the new_cases, HIstogram plot of the cases and Density plot, Normal Q-Q and corelogram
results_cases.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
#Training the Model and testing against the actual data
pred_cases = results_cases.get_prediction(start=pd.to_datetime('2020-08-02'), dynamic=False)
#Valudate the Model versus the actual data
pred_ci_cases = pred_cases.conf_int()
#fig, ax = plt.subplots()


ax = ts_cases_adj.plot(label='Observed (Actual)')
pred_cases.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci_cases.index,
                pred_ci_cases.iloc[:, 0],
                pred_ci_cases.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Cases')
ax.set_title('Training and Testing model for Weekly Average of Actual New Cases')

#ax.hlines(y=1000, xmin=4, xmax=1000, linewidth=2, color='r')


plt.legend()
plt.show()

# %%
pred_ci_cases
# Out:
#             lower new_cases  upper new_cases
# date
# 2020-08-02      -209.527578       218.226466
# 2020-08-09      -224.785746       202.904052
# 2020-08-16      -182.570368       245.119135
# 2020-08-23      -148.929273       278.735466
# 2020-08-30      -215.675954       211.988102
# 2020-09-06      -293.456549       134.198555
# 2020-09-13      -211.914876       215.739392
# 2020-09-20      -102.935418       324.715828
# 2020-09-27      -120.726118       306.924475
# 2020-10-04      -153.087398       274.562253
# 2020-10-11       -20.671660       406.977584
# 2020-10-18       315.842655       743.491633
# 2020-10-25       623.797724      1051.446482
# 2020-11-01       747.032856      1174.681549
# 2020-11-08       673.387897      1101.036482
# 2020-11-15       779.643523      1207.292095
# 2020-11-22       943.636003      1371.284528
# 2020-11-29       874.287880      1301.936402
# 2020-12-06      1130.009866      1557.658368
# 2020-12-13      1138.609896      1566.258398
# 2020-12-20      1249.907669      1677.556163
# 2020-12-27      1425.059386      1852.707880
# 2021-01-03      1686.183679      2113.832171

# %%
#Calculate the predicted results versus actual values
y_forecasted_cases = pred_cases.predicted_mean
y_truth_cases = ts_cases_adj['2020-08-02':]
#Calculate Mean Squared Error
mse = ((y_forecasted_cases - y_truth_cases) ** 2).mean()
mse=round(mse, 2)
print('The Mean Squared Error is {}'.format(mse))
#Calculate Root Mean Squared Error
rmse=round(np.sqrt(mse), 2)
print('The Root Mean Squared Error is {}'.format(rmse))
#Calculate R-squared Error or Coefficient of Determination:The % variation of y on variation with x
from sklearn.metrics import r2_score 
r_squared=r2_score(y_truth_cases, y_forecasted_cases)
print('R-squared Error is {}'.format(r_squared))

#Since the R squared error is approximately 0.92 closer to 1 the model can predict the values of future cases with a narrow margin of error
#prediction model accuracy is 92.23% which is acceptable.
# Out:
# The Mean Squared Error is 17293.89
# The Root Mean Squared Error is 131.51
# R-squared Error is 0.9578445270007325

# %%
 # decide on a cutoff limit
cutoff1 = 50
cutoff2 = 100
cutoff3 = 200
cutoff4 = 500
cutoff5 = 1000
#cutoff6 = 2000
y_truth_cases_classes = np.zeros_like(y_truth_cases)    # initialise a matrix full with zeros
#print(y_truth_cases)
#print(y_forecasted_cases)
y_truth_cases_classes[(0 <= y_truth_cases) & (y_truth_cases<= cutoff1)] = 0#"Below 50"#1
y_truth_cases_classes[(cutoff1 < y_truth_cases) & (y_truth_cases<= cutoff2)] = 1#"50-100"#2
y_truth_cases_classes[(cutoff2 < y_truth_cases) & (y_truth_cases<= cutoff3)] = 2#"100-200"#3
y_truth_cases_classes[(cutoff3 < y_truth_cases) & (y_truth_cases<= cutoff4)] = 3#"200-500"#3
y_truth_cases_classes[(cutoff4 < y_truth_cases) & (y_truth_cases<= cutoff5)] =4#"200-500"#3
y_truth_cases_classes[(cutoff5 < y_truth_cases)] = 5#">1000"5
#y_truth_cases_classes[cutoff6 < y_truth_cases] = 6
#print(y_truth_cases_classes)

###
y_forecasted_cases_classes = np.zeros_like(y_forecasted_cases)    # initialise a matrix full with zeros
y_forecasted_cases_classes[(0 <= y_forecasted_cases) & (y_forecasted_cases<= cutoff1)] = 0#"Below 50"#1
y_forecasted_cases_classes[(cutoff1 < y_forecasted_cases) & (y_forecasted_cases<= cutoff2)] = 1#"50-100"#2
y_forecasted_cases_classes[(cutoff2 < y_forecasted_cases) & (y_forecasted_cases<= cutoff3)] = 2#"100-200"#3
y_forecasted_cases_classes[(cutoff3 < y_forecasted_cases) & (y_forecasted_cases<= cutoff4)] = 3#"200-500"#3
y_forecasted_cases_classes[(cutoff4 < y_forecasted_cases) & (y_forecasted_cases<= cutoff5)] = 4#"200-500"#3
y_forecasted_cases_classes[(cutoff5 < y_forecasted_cases) ] = 5#">1000"5
#y_forecasted_cases_classes[cutoff6 < y_truth_cases] = 6
#print(y_forecasted_cases_classes)

import seaborn as sn
import matplotlib.pyplot as plt

# %%
# Constructing the confusion matrix.
from sklearn.metrics import confusion_matrix
confusion_matrix=confusion_matrix(y_truth_cases_classes, y_forecasted_cases_classes)
#print(matrix)
plt.figure(figsize=(14,6))
#sn.heatmap(confusion_matrix, annot=True, vmin=0, vmax=10, cmap="YlGnBu", center=0)
#plt.show()

ax = sn.heatmap(confusion_matrix, annot=True, vmin=0, vmax=10, cmap="YlGnBu", center=0) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_xlabel('Predicted Range of Cases');
ax.set_ylabel('Actual Range of Cases'); 
ax.set_title('Confusion Matrix for COVID-19 Cases'); 
#ax.xaxis.set_ticklabels(['Below 50' ,'50-100' ,'100-200' ,'200-500' ,'500-1000' ,'>1000']);
xlabels=['Below 50' ,'50-100' ,'100-200' ,'200-500' ,'500-1000' ,'>1000']
#ax.yaxis.set_ticklabels(['>1000','500-1000','200-500','100-200','50-100','Below 50']);
ylabels=['>1000','500-1000','200-500','100-200','50-100','Below 50']
#ax.xticks( rotation=45)
ax.set_xticklabels(xlabels, fontdict=None, minor=False,rotation=70)
ax.set_yticklabels(ylabels, fontdict=None, minor=False,rotation=0)

ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
#Confusion Matrix Classification Report
from sklearn.metrics import classification_report

print("classification report for the model for COVID-19 Cases is as Under :-")
print(classification_report(y_truth_cases_classes, y_forecasted_cases_classes))
# Out:
# classification report for the model for COVID-19 Cases is as Under :-
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.71      0.77         7
#          1.0       0.33      0.50      0.40         2
#          2.0       0.00      0.00      0.00         0
#          3.0       0.00      0.00      0.00         2
#          4.0       0.60      1.00      0.75         3
#          5.0       1.00      0.78      0.88         9
#
#     accuracy                           0.70        23
#    macro avg       0.46      0.50      0.47        23
# weighted avg       0.75      0.70      0.71        23

# %%
# Finding precision and recall
from sklearn.metrics import precision_score, recall_score,f1_score
print("Precision Score for thePrediction is :",precision_score(y_truth_cases_classes, y_forecasted_cases_classes, 
                                           #pos_label='positive',
                                           average='micro'))
print("Recall Score for thePrediction is :",recall_score(y_truth_cases_classes, y_forecasted_cases_classes, 
                                           #pos_label='positive',
                                           average='micro'))
# To compute the F1 score, simply call the f1_score() function:
print("F1 Score for the Prediction is :",f1_score(y_truth_cases_classes, y_forecasted_cases_classes, 
                                           #pos_label='positive',
                                           average='micro'))
# Out:
# Precision Score for thePrediction is : 0.6956521739130435
# Recall Score for thePrediction is : 0.6956521739130435
# F1 Score for the Prediction is : 0.6956521739130435

# %%
# Displaying Historic and Future Predict results for next 3 months.
pred_uc_cases = results_cases.get_forecast(steps=13)
pred_ci_cases = pred_uc_cases.conf_int(0.5)
ax = ts_cases_adj.plot(label='Observed(Actual)', figsize=(14, 6))
pred_uc_cases.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci_cases.index,
                pred_ci_cases.iloc[:, 0],
                pred_ci_cases.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Cases')
ax.set_title('Historic and next 3 months Future Predicted New Cases')
plt.legend()

ax.hlines(y=1000, xmin=pd.to_datetime('2020-01-02'), xmax=pd.to_datetime('2021-04-02'), linewidth=1, color='r')

plt.show()
#Since we are preicting weekly average the value is calcualted weekly . The gap in graph shows a period between 
# week 03-Jan-2021 to 09-Jan-2021 but there are NO missing values.

# %%
#pred_ci[['lower new_cases', 'upper new_cases']]
pred_ci_cases['mean new_cases']=pred_ci_cases.mean(axis=1)
pred_ci_cases.round()
# Out:
#             lower new_cases  upper new_cases  mean new_cases
# 2021-01-10           2063.0           2491.0          2277.0
# 2021-01-17           2261.0           2825.0          2543.0
# 2021-01-24           2101.0           2949.0          2525.0
# 2021-01-31           2248.0           3307.0          2777.0
# 2021-02-07           2089.0           3323.0          2706.0
# 2021-02-14           2034.0           3421.0          2728.0
# 2021-02-21           2301.0           3826.0          3064.0
# 2021-02-28           2024.0           3675.0          2849.0
# 2021-03-07           2332.0           4101.0          3217.0
# 2021-03-14           2142.0           4021.0          3081.0
# 2021-03-21           2369.0           4352.0          3360.0
# 2021-03-28           2682.0           4764.0          3723.0
# 2021-04-04           2785.0           5122.0          3954.0

# %%
# 3 months Future Predicted results of New Cases

ax = pred_ci_cases.plot(label='Observed(Actual)', figsize=(14, 6))
pred_uc_cases.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci_cases.index,
                pred_ci_cases.iloc[:, 0],
                pred_ci_cases.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Cases')
ax.set_title('Weekly Average of 3 months Predicted New Cases')
plt.legend()

ax.hlines(y=1000, xmin=pd.to_datetime('2020-01-02'), xmax=pd.to_datetime('2021-04-02'), linewidth=1, color='r')

plt.show()
#Since we are preicting weekly average the value is calcualted weekly

# %%
pred_ci_cases.filter('')
df_result_cases=pred_ci_cases[(pred_ci_cases['lower new_cases'] <=1000.0) | (pred_ci_cases['upper new_cases'] <=1000.0)]
#df_result = pred_ci[(pred_ci['mean new_cases'] <=1000.0)]

print("Weeks where the number of new Cases are less than or equal to 1000 per day")
df_result_cases
# Out:
# Weeks where the number of new Cases are less than or equal to 1000 per day
# Empty DataFrame
# Columns: [lower new_cases, upper new_cases, mean new_cases]
# Index: []

# %%
#check average for 2 consecutive weeks and say if Malaysia could achieve Objective of 1000 cases/day in next 3 months
biweekly_day_average_meet=False
for index, row in pred_ci_cases.iterrows():
    if ((pred_ci_cases.loc[index,'lower new_cases']+pred_ci_cases.loc[index,'upper new_cases'])/2) <=1000:
        if ((pred_ci_cases.loc[(index-1),'lower new_cases']+pred_ci_cases.loc[(index-1),'upper new_cases'])/2) <=1000:
            biweekly_day_average_meet=True
            print("Malaysia could achieve 14 days average of below 100 cases per day within the next 3 months for weeks ",pred_ci_cases.loc[index],pred_ci_cases.loc[(index - 1)])
if(biweekly_day_average_meet==False):
    print("Based on current trend of data it seems difficult that Malaysia would achieve trend on 1000 cases per day in next 3 months")
# Out:
# Based on current trend of data it seems difficult that Malaysia would achieve trend on 1000 cases per day in next 3 months

# %% [markdown]
# ### There is not even a single week where average is less than 1000 cases /day
# ### Based on current trend of data it seems difficult that Malaysia would achieve trend on 1000 cases per day in next three months

# %% [markdown]
# # Objective-2
#
# ## Considering current trend of COVID-19 tests in Malaysia, I want to determine the number of COVID-19 test kits that would be required each week in Malaysia, over next 3 months

# %%
#Filterout columns 'date','new_tests'
df_new_test=df[['date','new_tests']]
df_new_test
# Out:
#             date  new_tests
# 31632 2020-01-25        0.0
# 31633 2020-01-26        0.0
# 31634 2020-01-27        0.0
# 31635 2020-01-28        0.0
# 31636 2020-01-29        0.0
# ...          ...        ...
# 31971 2020-12-29    19954.0
# 31972 2020-12-30    25812.0
# 31973 2020-12-31    25812.0
# 31974 2021-01-01    25812.0
# 31975 2021-01-02    25812.0
#
# [344 rows x 2 columns]

# %%
#set index the data frame by ‘Date 
df_new_test=df_new_test.set_index('date')
df_new_test
# Out:
#             new_tests
# date
# 2020-01-25        0.0
# 2020-01-26        0.0
# 2020-01-27        0.0
# 2020-01-28        0.0
# 2020-01-29        0.0
# ...               ...
# 2020-12-29    19954.0
# 2020-12-30    25812.0
# 2020-12-31    25812.0
# 2021-01-01    25812.0
# 2021-01-02    25812.0
#
# [344 rows x 1 columns]

# %%
#aggregate the data from daily to Weekly in order to carry out the analysis
tests_ts_weekly_avg = df_new_test['new_tests'].resample('W').mean()
#W : weekly frequency
#M : month end frequency
#SM : semi-month end frequency (15th and end of month)
#Q : quarter end frequency
tests_ts_weekly_avg
# Out:
# date
# 2020-01-26        0.000000
# 2020-02-02        0.000000
# 2020-02-09        0.000000
# 2020-02-16       93.714286
# 2020-02-23       53.142857
# 2020-03-01       94.857143
# 2020-03-08       91.857143
# 2020-03-15      505.142857
# 2020-03-22      772.000000
# 2020-03-29     2722.714286
# 2020-04-05     1886.428571
# 2020-04-12     4850.285714
# 2020-04-19     3771.571429
# 2020-04-26     3942.714286
# 2020-05-03     9191.714286
# 2020-05-10     8729.142857
# 2020-05-17    26618.000000
# 2020-05-24     9202.714286
# 2020-05-31     6500.142857
# 2020-06-07     7666.285714
# 2020-06-14     6356.714286
# 2020-06-21     4660.571429
# 2020-06-28     9426.000000
# 2020-07-05     7795.428571
# 2020-07-12     6141.714286
# 2020-07-19     6033.428571
# 2020-07-26     6843.000000
# 2020-08-02     5933.285714
# 2020-08-09     9542.571429
# 2020-08-16     9752.857143
# 2020-08-23     8881.428571
# 2020-08-30     9589.142857
# 2020-09-06     9130.571429
# 2020-09-13     9242.857143
# 2020-09-20    10361.714286
# 2020-09-27     9386.285714
# 2020-10-04    14950.142857
# 2020-10-11    17689.571429
# 2020-10-18    20997.000000
# 2020-10-25    17267.000000
# 2020-11-01    18705.857143
# 2020-11-08    19653.857143
# 2020-11-15    17972.714286
# 2020-11-22    18159.285714
# 2020-11-29    17458.571429
# 2020-12-06    19533.428571
# 2020-12-13    21954.285714
# 2020-12-20    23013.714286
# 2020-12-27    22232.142857
# 2021-01-03    22929.833333
# Freq: W-SUN, Name: new_tests, dtype: float64

# %%
#Plotting the series
import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')

ax=tests_ts_weekly_avg.plot(figsize=(15, 8))
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Tests')
ax.set_title('Weekly Average of Actual New Tests')
plt.show()

# %%
#decomposed time series to get components Trend, Seasonality &  Noise
from pylab import rcParams
import statsmodels.api as sm

rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(tests_ts_weekly_avg, model='additive', extrapolate_trend='freq', period=1)
fig = decomposition.plot()
plt.show()

# %%
# Plotting the Auto Correlation Function(ACF) and Partial Auto Correlation Function(PACF) Plot of the Trend and Seasonally adjusted Time Series data
#to determine  p and seasonal P, q and seasonal Q
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#Plot the autocorrelation function

plot_acf(tests_ts_weekly_avg,use_vlines=True,title='Graph of Auto corelation for new_tests', lags=45)
mpl.pyplot.show()
#The trendwas initially decreasing in initial few weeks and then it started increasing . The change in trend results in change in corelation.
#ACF plot Spikes at lag =1 means a probable Autoregressive(AR)  order of 1 and seasonal AR order of 1

#Plots lags on the horizontal and the partial correlations on vertical axis for time-series data using method='ols'.
plot_pacf(tests_ts_weekly_avg,use_vlines=True,method='ols' ,title='Graph of Partial Auto corelation for new_tests', lags=22)
mpl.pyplot.show()
#PACF plot spikes at lag=1 and lag=4 and then spikes at lag=21, which means a probable Moving Average(MA) order of 1 or 2 and seasonal MA order of 1

# %%
#apply adf test and kpss test on the series to check whether series is stationery
print(print_adf_result(tests_ts_weekly_avg))
print(print_kpss_result(tests_ts_weekly_avg))
#ADF: if the p-value is less than the critical value , the series is stationary
#P value is 0.08 whihc is not less than critical value of 0.05 so statistically we can confirm that the series is not stationary.
#Hence, we would do first-order differencing for the trend and re-run the ADF test to check for stationarity.
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.058050
# p-value                         0.731508
# #Lags Used                      1.000000
# Number of Observations Used    48.000000
# Critical Value (1%)            -3.574589
# Critical Value (5%)            -2.923954
# Critical Value (10%)           -2.600039
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.511405
# p-value                   0.039098
# Lags Used                11.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None

# %%
#Doing First Order differencing
ts_tests_adj = tests_ts_weekly_avg - tests_ts_weekly_avg.shift(1)
#ts_cases_adj =cases_ts_weekly_avg
ts_tests_adj = ts_tests_adj.dropna()
#ts_cases_adj.plot()
print(print_adf_result(ts_tests_adj))
print(print_kpss_result(ts_tests_adj))
#For first oder differencing p =6.271783e-13  less than 0.05 so ploting the graph
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.019022e+01
# p-value                        6.351149e-18
# #Lags Used                     0.000000e+00
# Number of Observations Used    4.800000e+01
# Critical Value (1%)           -3.574589e+00
# Critical Value (5%)           -2.923954e+00
# Critical Value (10%)          -2.600039e+00
# dtype: float64
# None
# Results of KPSS Test is as under:
# Test Statistic            0.127339
# p-value                   0.100000
# Lags Used                11.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# None
# C:\Users\rupes\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\stattools.py:1886: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warn_msg.format(direction="greater"), InterpolationWarning

# %%
# Plotting the adjusted New Tests with shift of 6 weeks


ax=ts_tests_adj.plot(figsize=(15, 8))
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Tests')
ax.set_title('Weekly Average of Adjusted New Tests WITH shift of 6 weeks')
plt.show()

# %%
# Plotting the adjusted New Tests WITHOUT shift of 6 weeks.
# In the above graph I tried using differencing to test the shifting values.
#But as you can see the differencing gives a non zero value for second half of May 2020 which is not the case.
# Thus discarding the differencing values. I consider only the average value and it gives the accurate picture.


ts_tests_adj=tests_ts_weekly_avg
ax=ts_tests_adj.plot(figsize=(15, 8))
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Tests')
ax.set_title('Weekly Average of Adjusted New Tests WITHOUT shift of 6 weeks')
plt.show()

# %%
import itertools
import statsmodels.api as sm
#The variables p,P,d,D,q,Q are defined as under
#p and seasonal P: indicate the number of AR terms (lags of the stationary series)
#d and seasonal D: indicate differencing that must be done to stationary series
#q and seasonal Q: indicate the number of MA terms (lags of the forecast errors)
#lag: indicates the seasonal length in the data
#setting prameters for SARIMA

p = range(0, 3)
d = range(1,2)
q = range(0, 4)

pdq = list(itertools.product(p, d, q))
print(pdq)
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
seasonal_pdq
# Out:
# [(0, 1, 0), (0, 1, 1), (0, 1, 2), (0, 1, 3), (1, 1, 0), (1, 1, 1), (1, 1, 2), (1, 1, 3), (2, 1, 0), (2, 1, 1), (2, 1, 2), (2, 1, 3)]
# Examples of parameter combinations for Seasonal SARIMA...
# SARIMAX: (0, 1, 1) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 1) x (0, 1, 2, 12)
# SARIMAX: (0, 1, 2) x (0, 1, 3, 12)
# [(0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 2, 12),
#  (0, 1, 3, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12),
#  (1, 1, 2, 12),
#  (1, 1, 3, 12),
#  (2, 1, 0, 12),
#  (2, 1, 1, 12),
#  (2, 1, 2, 12),
#  (2, 1, 3, 12)]

# %%
# Performing a grid search with the list of possible values around our estimated parameters.
# We have to  pick the model with the least AIC.
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(ts_tests_adj,
                                            order=param,
                                            seasonal_order=param_seasonal,)
            results = mod.fit(method = 'powell')
            print('SARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
#AIC (Akaike information criterion) is an estimator of the relative quality of statistical models for a given set of data
# Out:
# Optimization terminated successfully.
#          Current function value: 7.511627
#          Iterations: 2
#          Function evaluations: 34
# SARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:753.16272350895
# Optimization terminated successfully.
#          Current function value: 7.302060
#          Iterations: 3
#          Function evaluations: 84
# SARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:734.2059718066247
# Optimization terminated successfully.
#          Current function value: 7.246738
#          Iterations: 4
#          Function evaluations: 158
# SARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:730.6738351254795
# Optimization terminated successfully.
#          Current function value: 7.233447
#          Iterations: 4
#          Function evaluations: 200
# SARIMA(0, 1, 0)x(0, 1, 3, 12)12 - AIC:731.344738843409
# Optimization terminated successfully.
#          Current function value: 7.411918
#          Iterations: 2
#          Function evaluations: 60
# SARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:745.1917781908456
# Optimization terminated successfully.
#          Current function value: 7.287782
#          Iterations: 4
#          Function evaluations: 157
# SARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:734.7781961380036
# Optimization terminated successfully.
#          Current function value: 7.250082
#          Iterations: 7
#          Function evaluations: 350
# SARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:733.0081622834919
# Optimization terminated successfully.
#          Current function value: 7.192676
#          Iterations: 6
#          Function evaluations: 391
# SARIMA(0, 1, 0)x(1, 1, 3, 12)12 - AIC:729.2675553212558
# Optimization terminated successfully.
#          Current function value: 6.974222
#          Iterations: 3
#          Function evaluations: 118
# SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:703.4221970711299
# Optimization terminated successfully.
#          Current function value: 6.969865
#          Iterations: 6
#          Function evaluations: 299
# SARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:704.9865221862467
# Optimization terminated successfully.
#          Current function value: 6.970498
#          Iterations: 6
#          Function evaluations: 369
# SARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:707.0497631831532
# Optimization terminated successfully.
#          Current function value: 6.969939
#          Iterations: 6
#          Function evaluations: 439
# SARIMA(0, 1, 0)x(2, 1, 3, 12)12 - AIC:708.9939191755982
# Optimization terminated successfully.
#          Current function value: 7.450836
#          Iterations: 2
#          Function evaluations: 58
# SARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:749.0836170806082
# Optimization terminated successfully.
#          Current function value: 7.233834
#          Iterations: 4
#          Function evaluations: 159
# SARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:729.3833942716949
# Optimization terminated successfully.
#          Current function value: 7.176172
#          Iterations: 4
#          Function evaluations: 202
# SARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:725.6171606934383
# Optimization terminated successfully.
#          Current function value: 7.170211
#          Iterations: 4
#          Function evaluations: 246
# SARIMA(0, 1, 1)x(0, 1, 3, 12)12 - AIC:727.0210789832132
# Optimization terminated successfully.
#          Current function value: 7.328444
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:738.8443982491959
# Optimization terminated successfully.
#          Current function value: 7.212642
#          Iterations: 5
#          Function evaluations: 254
# SARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:729.2642149800644
# Optimization terminated successfully.
#          Current function value: 7.179628
#          Iterations: 7
#          Function evaluations: 432
# SARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:727.9628378837353
# Optimization terminated successfully.
#          Current function value: 7.136207
#          Iterations: 6
#          Function evaluations: 450
# SARIMA(0, 1, 1)x(1, 1, 3, 12)12 - AIC:725.6206823936574
# Optimization terminated successfully.
#          Current function value: 6.958771
#          Iterations: 6
#          Function evaluations: 305
# SARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:703.8770774484541
# Optimization terminated successfully.
#          Current function value: 6.957061
#          Iterations: 7
#          Function evaluations: 427
# SARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:705.7060660567745
# Optimization terminated successfully.
#          Current function value: 6.956092
#          Iterations: 6
#          Function evaluations: 436
# SARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:707.6092195880077
# Optimization terminated successfully.
#          Current function value: 6.956464
#          Iterations: 6
#          Function evaluations: 504
# SARIMA(0, 1, 1)x(2, 1, 3, 12)12 - AIC:709.6463764908568
# Optimization terminated successfully.
#          Current function value: 7.449571
#          Iterations: 2
#          Function evaluations: 67
# SARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:750.9570628246372
# Optimization terminated successfully.
#          Current function value: 7.232572
#          Iterations: 3
#          Function evaluations: 144
# SARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:731.257200145731
# Optimization terminated successfully.
#          Current function value: 7.172192
#          Iterations: 4
#          Function evaluations: 246
# SARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:727.2191873814395
# Optimization terminated successfully.
#          Current function value: 7.167481
#          Iterations: 4
#          Function evaluations: 296
# SARIMA(0, 1, 2)x(0, 1, 3, 12)12 - AIC:728.7480878749122
# Optimization terminated successfully.
#          Current function value: 7.322148
#          Iterations: 2
#          Function evaluations: 101
# SARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:740.2147700700269
# Optimization terminated successfully.
#          Current function value: 7.208244
#          Iterations: 5
#          Function evaluations: 308
# SARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:730.8244041916751
# Optimization terminated successfully.
#          Current function value: 7.175809
#          Iterations: 7
#          Function evaluations: 507
# SARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:729.5808534089153
# Optimization terminated successfully.
#          Current function value: 7.134391
#          Iterations: 6
#          Function evaluations: 518
# SARIMA(0, 1, 2)x(1, 1, 3, 12)12 - AIC:727.4391219296588
# Optimization terminated successfully.
#          Current function value: 6.958823
#          Iterations: 6
#          Function evaluations: 362
# SARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:705.8823123311761
# Optimization terminated successfully.
#          Current function value: 6.957122
#          Iterations: 6
#          Function evaluations: 431
# SARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:707.7122484187001
# Optimization terminated successfully.
#          Current function value: 6.956138
#          Iterations: 6
#          Function evaluations: 499
# SARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:709.6137748047296
# Optimization terminated successfully.
#          Current function value: 6.957039
#          Iterations: 6
#          Function evaluations: 561
# SARIMA(0, 1, 2)x(2, 1, 3, 12)12 - AIC:711.7039100823671
# Optimization terminated successfully.
#          Current function value: 7.446439
#          Iterations: 2
#          Function evaluations: 90
# SARIMA(0, 1, 3)x(0, 1, 0, 12)12 - AIC:752.6439345680308
# Optimization terminated successfully.
#          Current function value: 7.228221
#          Iterations: 4
#          Function evaluations: 241
# SARIMA(0, 1, 3)x(0, 1, 1, 12)12 - AIC:732.8221120435206
# Optimization terminated successfully.
#          Current function value: 7.170488
#          Iterations: 4
#          Function evaluations: 288
# SARIMA(0, 1, 3)x(0, 1, 2, 12)12 - AIC:729.0488386261627
# Optimization terminated successfully.
#          Current function value: 7.165198
#          Iterations: 4
#          Function evaluations: 331
# SARIMA(0, 1, 3)x(0, 1, 3, 12)12 - AIC:730.519768781603
# Optimization terminated successfully.
#          Current function value: 7.318457
#          Iterations: 2
#          Function evaluations: 126
# SARIMA(0, 1, 3)x(1, 1, 0, 12)12 - AIC:741.8457286883616
# Optimization terminated successfully.
#          Current function value: 7.206118
#          Iterations: 5
#          Function evaluations: 365
# SARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:732.6118010200487
# Optimization terminated successfully.
#          Current function value: 7.174239
#          Iterations: 7
#          Function evaluations: 583
# SARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:731.4238818522766
# Optimization terminated successfully.
#          Current function value: 7.132849
#          Iterations: 6
#          Function evaluations: 581
# SARIMA(0, 1, 3)x(1, 1, 3, 12)12 - AIC:729.2849390818477
# Optimization terminated successfully.
#          Current function value: 6.958534
#          Iterations: 6
#          Function evaluations: 430
# SARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:707.8534291728496
# Optimization terminated successfully.
#          Current function value: 6.956241
#          Iterations: 7
#          Function evaluations: 578
# SARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:709.624106443006
# Optimization terminated successfully.
#          Current function value: 6.955678
#          Iterations: 6
#          Function evaluations: 567
# SARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:711.5678463492669
# Optimization terminated successfully.
#          Current function value: 6.956065
#          Iterations: 6
#          Function evaluations: 637
# SARIMA(0, 1, 3)x(2, 1, 3, 12)12 - AIC:713.606477504312
# Optimization terminated successfully.
#          Current function value: 7.462079
#          Iterations: 1
#          Function evaluations: 25
# SARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:750.2079154887049
# Optimization terminated successfully.
#          Current function value: 7.252660
#          Iterations: 3
#          Function evaluations: 119
# SARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:731.2660188729286
# Optimization terminated successfully.
#          Current function value: 7.198847
#          Iterations: 4
#          Function evaluations: 206
# SARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:727.884738920507
# Optimization terminated successfully.
#          Current function value: 7.186332
#          Iterations: 5
#          Function evaluations: 304
# SARIMA(1, 1, 0)x(0, 1, 3, 12)12 - AIC:728.6331651722923
# Optimization terminated successfully.
#          Current function value: 7.358652
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:741.8652493193314
# Optimization terminated successfully.
#          Current function value: 7.237162
#          Iterations: 4
#          Function evaluations: 204
# SARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:731.7161587776183
# Optimization terminated successfully.
#          Current function value: 7.201142
#          Iterations: 7
#          Function evaluations: 434
# SARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:730.1141590162177
# Optimization terminated successfully.
#          Current function value: 7.149328
#          Iterations: 5
#          Function evaluations: 372
# SARIMA(1, 1, 0)x(1, 1, 3, 12)12 - AIC:726.9327849030819
# Optimization terminated successfully.
#          Current function value: 6.959366
#          Iterations: 6
#          Function evaluations: 313
# SARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:703.9366191991684
# Optimization terminated successfully.
#          Current function value: 6.957889
#          Iterations: 6
#          Function evaluations: 376
# SARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:705.7889414776964
# Optimization terminated successfully.
#          Current function value: 6.958205
#          Iterations: 5
#          Function evaluations: 361
# SARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:707.8205456027213
# Optimization terminated successfully.
#          Current function value: 6.958211
#          Iterations: 5
#          Function evaluations: 419
# SARIMA(1, 1, 0)x(2, 1, 3, 12)12 - AIC:709.8210992620144
# Optimization terminated successfully.
#          Current function value: 7.450601
#          Iterations: 2
#          Function evaluations: 81
# SARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:751.0601409865094
# Optimization terminated successfully.
#          Current function value: 7.230729
#          Iterations: 4
#          Function evaluations: 199
# SARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:731.0728802631241
# Optimization terminated successfully.
#          Current function value: 7.170869
#          Iterations: 4
#          Function evaluations: 249
# SARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:727.0869158661225
# Optimization terminated successfully.
#          Current function value: 7.165945
#          Iterations: 5
#          Function evaluations: 355
# SARIMA(1, 1, 1)x(0, 1, 3, 12)12 - AIC:728.594478416587
# Optimization terminated successfully.
#          Current function value: 7.319929
#          Iterations: 4
#          Function evaluations: 199
# SARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:739.9928848096181
# Optimization terminated successfully.
#          Current function value: 7.207224
#          Iterations: 5
#          Function evaluations: 304
# SARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:730.7224440988589
# Optimization terminated successfully.
#          Current function value: 7.171231
#          Iterations: 8
#          Function evaluations: 604
# SARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:729.123133077785
# Optimization terminated successfully.
#          Current function value: 7.134921
#          Iterations: 6
#          Function evaluations: 531
# SARIMA(1, 1, 1)x(1, 1, 3, 12)12 - AIC:727.4921390759819
# Optimization terminated successfully.
#          Current function value: 6.959207
#          Iterations: 6
#          Function evaluations: 377
# SARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:705.9207283943633
# Optimization terminated successfully.
#          Current function value: 6.956721
#          Iterations: 6
#          Function evaluations: 449
# SARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:707.6720824815793
# Optimization terminated successfully.
#          Current function value: 6.956121
#          Iterations: 6
#          Function evaluations: 508
# SARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:709.6121232990047
# Optimization terminated successfully.
#          Current function value: 6.956501
#          Iterations: 6
#          Function evaluations: 579
# SARIMA(1, 1, 1)x(2, 1, 3, 12)12 - AIC:711.6501023746553
# Optimization terminated successfully.
#          Current function value: 7.448739
#          Iterations: 2
#          Function evaluations: 93
# SARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:752.8738722663378
# Optimization terminated successfully.
#          Current function value: 7.232053
#          Iterations: 3
#          Function evaluations: 179
# SARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:733.2052845062319
# Optimization terminated successfully.
#          Current function value: 7.171576
#          Iterations: 4
#          Function evaluations: 290
# SARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:729.1575709534201
# Optimization terminated successfully.
#          Current function value: 7.166556
#          Iterations: 4
#          Function evaluations: 342
# SARIMA(1, 1, 2)x(0, 1, 3, 12)12 - AIC:730.6555722530337
# Optimization terminated successfully.
#          Current function value: 7.321155
#          Iterations: 3
#          Function evaluations: 171
# SARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:742.1154514633591
# Optimization terminated successfully.
#          Current function value: 7.207218
#          Iterations: 5
#          Function evaluations: 366
# SARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:732.7217625867819
# Optimization terminated successfully.
#          Current function value: 7.174865
#          Iterations: 7
#          Function evaluations: 588
# SARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:731.4865318095017
# Optimization terminated successfully.
#          Current function value: 7.133471
#          Iterations: 6
#          Function evaluations: 588
# SARIMA(1, 1, 2)x(1, 1, 3, 12)12 - AIC:729.3471412988183
# Optimization terminated successfully.
#          Current function value: 6.958516
#          Iterations: 6
#          Function evaluations: 442
# SARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:707.8516038507964
# Optimization terminated successfully.
#          Current function value: 6.956353
#          Iterations: 6
#          Function evaluations: 503
# SARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:709.6353061048763
# Optimization terminated successfully.
#          Current function value: 6.955733
#          Iterations: 6
#          Function evaluations: 574
# SARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:711.5732882817805
# Optimization terminated successfully.
#          Current function value: 6.956072
#          Iterations: 6
#          Function evaluations: 644
# SARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:713.6072205775218
# Optimization terminated successfully.
#          Current function value: 7.446738
#          Iterations: 2
#          Function evaluations: 110
# SARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:754.6737822764723
# Optimization terminated successfully.
#          Current function value: 7.228783
#          Iterations: 4
#          Function evaluations: 286
# SARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:734.8782886038348
# Optimization terminated successfully.
#          Current function value: 7.170618
#          Iterations: 4
#          Function evaluations: 332
# SARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:731.0618396132703
# Optimization terminated successfully.
#          Current function value: 7.165296
#          Iterations: 4
#          Function evaluations: 380
# SARIMA(1, 1, 3)x(0, 1, 3, 12)12 - AIC:732.5296373627617
# Optimization terminated successfully.
#          Current function value: 7.319062
#          Iterations: 3
#          Function evaluations: 202
# SARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:743.9062287014985
# Optimization terminated successfully.
#          Current function value: 7.206230
#          Iterations: 5
#          Function evaluations: 416
# SARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:734.6230356612637
# Optimization terminated successfully.
#          Current function value: 7.174471
#          Iterations: 7
#          Function evaluations: 662
# SARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:733.4470611282195
# Optimization terminated successfully.
#          Current function value: 7.133006
#          Iterations: 6
#          Function evaluations: 643
# SARIMA(1, 1, 3)x(1, 1, 3, 12)12 - AIC:731.3006026247846
# Optimization terminated successfully.
#          Current function value: 6.958415
#          Iterations: 6
#          Function evaluations: 492
# SARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:709.8414800912927
# Optimization terminated successfully.
#          Current function value: 6.956064
#          Iterations: 6
#          Function evaluations: 572
# SARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:711.6064490367368
# Optimization terminated successfully.
#          Current function value: 6.955517
#          Iterations: 6
#          Function evaluations: 636
# SARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:713.5516816531995
# Optimization terminated successfully.
#          Current function value: 6.956475
#          Iterations: 6
#          Function evaluations: 693
# SARIMA(1, 1, 3)x(2, 1, 3, 12)12 - AIC:715.6474822415634
# Optimization terminated successfully.
#          Current function value: 7.456693
#          Iterations: 1
#          Function evaluations: 36
# SARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:751.6692800747011
# Optimization terminated successfully.
#          Current function value: 7.244189
#          Iterations: 3
#          Function evaluations: 154
# SARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:732.4188522411629
# Optimization terminated successfully.
#          Current function value: 7.187926
#          Iterations: 5
#          Function evaluations: 306
# SARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:728.7926120528688
# Optimization terminated successfully.
#          Current function value: 7.178501
#          Iterations: 5
#          Function evaluations: 362
# SARIMA(2, 1, 0)x(0, 1, 3, 12)12 - AIC:729.8501491095337
# Optimization terminated successfully.
#          Current function value: 7.346400
#          Iterations: 2
#          Function evaluations: 92
# SARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:742.6399655608752
# Optimization terminated successfully.
#          Current function value: 7.226243
#          Iterations: 4
#          Function evaluations: 256
# SARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:732.624253308647
# Optimization terminated successfully.
#          Current function value: 7.189683
#          Iterations: 6
#          Function evaluations: 445
# SARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:730.9682795488458
# Optimization terminated successfully.
#          Current function value: 7.143189
#          Iterations: 5
#          Function evaluations: 428
# SARIMA(2, 1, 0)x(1, 1, 3, 12)12 - AIC:728.318872520564
# Optimization terminated successfully.
#          Current function value: 6.958817
#          Iterations: 6
#          Function evaluations: 381
# SARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:705.8817005488789
# Optimization terminated successfully.
#          Current function value: 6.957312
#          Iterations: 6
#          Function evaluations: 445
# SARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:707.7311929690743
# Optimization terminated successfully.
#          Current function value: 6.957274
#          Iterations: 6
#          Function evaluations: 500
# SARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:709.7274011575008
# Optimization terminated successfully.
#          Current function value: 6.957317
#          Iterations: 6
#          Function evaluations: 583
# SARIMA(2, 1, 0)x(2, 1, 3, 12)12 - AIC:711.7316811167991
# Optimization terminated successfully.
#          Current function value: 7.428568
#          Iterations: 3
#          Function evaluations: 208
# SARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:750.8568097499467
# Optimization terminated successfully.
#          Current function value: 7.226796
#          Iterations: 4
#          Function evaluations: 321
# SARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:732.6795643120461
# Optimization terminated successfully.
#          Current function value: 7.175317
#          Iterations: 4
#          Function evaluations: 366
# SARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:729.5317196316437
# Optimization terminated successfully.
#          Current function value: 7.167863
#          Iterations: 4
#          Function evaluations: 406
# SARIMA(2, 1, 1)x(0, 1, 3, 12)12 - AIC:730.7862519113636
# Optimization terminated successfully.
#          Current function value: 7.316491
#          Iterations: 2
#          Function evaluations: 121
# SARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:741.6491118409843
# Optimization terminated successfully.
#          Current function value: 7.206706
#          Iterations: 5
#          Function evaluations: 373
# SARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:732.670552038234
# Optimization terminated successfully.
#          Current function value: 7.178200
#          Iterations: 7
#          Function evaluations: 683
# SARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:731.8199592570351
# Optimization terminated successfully.
#          Current function value: 7.136429
#          Iterations: 6
#          Function evaluations: 669
# SARIMA(2, 1, 1)x(1, 1, 3, 12)12 - AIC:729.6429099185151
# Optimization terminated successfully.
#          Current function value: 6.958734
#          Iterations: 6
#          Function evaluations: 455
# SARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:707.8733618503636
# Optimization terminated successfully.
#          Current function value: 6.957022
#          Iterations: 6
#          Function evaluations: 520
# SARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:709.7022201564808
# Optimization terminated successfully.
#          Current function value: 6.956604
#          Iterations: 6
#          Function evaluations: 684
# SARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:711.6603752016266
# Optimization terminated successfully.
#          Current function value: 6.957112
#          Iterations: 6
#          Function evaluations: 749
# SARIMA(2, 1, 1)x(2, 1, 3, 12)12 - AIC:713.7112290525823
# Optimization terminated successfully.
#          Current function value: 7.447755
#          Iterations: 2
#          Function evaluations: 121
# SARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:754.7754709196806
# Optimization terminated successfully.
#          Current function value: 7.228932
#          Iterations: 4
#          Function evaluations: 289
# SARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:734.8932072344237
# Optimization terminated successfully.
#          Current function value: 7.170763
#          Iterations: 4
#          Function evaluations: 338
# SARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:731.0763196583284
# Optimization terminated successfully.
#          Current function value: 7.165695
#          Iterations: 4
#          Function evaluations: 380
# SARIMA(2, 1, 2)x(0, 1, 3, 12)12 - AIC:732.5694841509359
# Optimization terminated successfully.
#          Current function value: 7.317847
#          Iterations: 4
#          Function evaluations: 294
# SARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:743.7846767512484
# Optimization terminated successfully.
#          Current function value: 7.206360
#          Iterations: 5
#          Function evaluations: 422
# SARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:734.6359550300235
# Optimization terminated successfully.
#          Current function value: 7.174430
#          Iterations: 7
#          Function evaluations: 678
# SARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:733.4429989340484
# Optimization terminated successfully.
#          Current function value: 7.133505
#          Iterations: 6
#          Function evaluations: 654
# SARIMA(2, 1, 2)x(1, 1, 3, 12)12 - AIC:731.3505144594388
# Optimization terminated successfully.
#          Current function value: 6.958489
#          Iterations: 6
#          Function evaluations: 503
# SARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:709.8489180084209
# Optimization terminated successfully.
#          Current function value: 6.956147
#          Iterations: 6
#          Function evaluations: 577
# SARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:711.614721399111
# Optimization terminated successfully.
#          Current function value: 6.955718
#          Iterations: 6
#          Function evaluations: 641
# SARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:713.5717536279635
# Optimization terminated successfully.
#          Current function value: 6.955978
#          Iterations: 6
#          Function evaluations: 711
# SARIMA(2, 1, 2)x(2, 1, 3, 12)12 - AIC:715.5977909285714
# Optimization terminated successfully.
#          Current function value: 7.428331
#          Iterations: 3
#          Function evaluations: 217
# SARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:754.833078323801
# Optimization terminated successfully.
#          Current function value: 7.226889
#          Iterations: 4
#          Function evaluations: 335
# SARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:736.6888658632342
# Optimization terminated successfully.
#          Current function value: 7.172653
#          Iterations: 5
#          Function evaluations: 487
# SARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:733.265253033779
# Optimization terminated successfully.
#          Current function value: 7.165936
#          Iterations: 5
#          Function evaluations: 553
# SARIMA(2, 1, 3)x(0, 1, 3, 12)12 - AIC:734.593649248074
# Optimization terminated successfully.
#          Current function value: 7.313484
#          Iterations: 3
#          Function evaluations: 261
# SARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:745.3484248600962
# Optimization terminated successfully.
#          Current function value: 7.207184
#          Iterations: 5
#          Function evaluations: 494
# SARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:736.7183568940695
# Optimization terminated successfully.
#          Current function value: 7.176553
#          Iterations: 7
#          Function evaluations: 755
# SARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:735.6552782937365
# Optimization terminated successfully.
#          Current function value: 7.133666
#          Iterations: 5
#          Function evaluations: 607
# SARIMA(2, 1, 3)x(1, 1, 3, 12)12 - AIC:733.3666152620989
# Optimization terminated successfully.
#          Current function value: 6.949558
#          Iterations: 6
#          Function evaluations: 592
# SARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:710.9558256475857
# Optimization terminated successfully.
#          Current function value: 6.945892
#          Iterations: 6
#          Function evaluations: 712
# SARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:712.589219970695
# Optimization terminated successfully.
#          Current function value: 6.943092
#          Iterations: 6
#          Function evaluations: 811
# SARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:714.3091997332822
# Optimization terminated successfully.
#          Current function value: 6.943392
#          Iterations: 7
#          Function evaluations: 1023
# SARIMA(2, 1, 3)x(2, 1, 3, 12)12 - AIC:716.3392404061412

# %%
#getting values which has minimum AIC for the time series data
#SARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:703.4221970711299



mod = sm.tsa.statespace.SARIMAX(ts_tests_adj,
                                            order=(0, 1, 2),
                                seasonal_order=(2, 1, 0, 12))
#Fitting model using POWELL method: Powell method, is an algorithm proposed  for finding a local minimum of a function
results = mod.fit(method = 'powell')
#Print the results
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 6.958823
#          Iterations: 6
#          Function evaluations: 362
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.2217      0.136     -1.630      0.103      -0.488       0.045
# ma.L2          0.0003      0.191      0.002      0.999      -0.374       0.375
# ar.S.L12      -0.9635      0.076    -12.731      0.000      -1.112      -0.815
# ar.S.L24      -0.9611      0.013    -76.286      0.000      -0.986      -0.936
# sigma2      3.671e+06   2.51e-09   1.46e+15      0.000    3.67e+06    3.67e+06
# ==============================================================================

# %%
#Plotting Standard residual for the new_cases, HIstogram plot of the cases and Density plot, Normal Q-Q and corelogram
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
#Valudate the Model versus the actual data

pred = results.get_prediction(start=pd.to_datetime('2020-08-02'), dynamic=False)
pred_ci = pred.conf_int()
ax = ts_tests_adj.plot(label='Observed(new_tests)')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New tests')
ax.set_title('Training and Testing model for Weekly Average of Actual New Tests')
plt.legend()
plt.show()

# %%
#Calculate the predicted results versus actual values
y_forecasted = pred.predicted_mean
y_truth = ts_tests_adj['2020-08-02':]
#Calculate Mean Squared Error
mse = ((y_forecasted - y_truth) ** 2).mean()
mse=round(mse, 2)
print('The Mean Squared Error is {}'.format(mse))
#Calculate Root Mean Squared Error
rmse=round(np.sqrt(mse), 2)
print('The Root Mean Squared Error is {}'.format(rmse))
#Calculate R-squared Error or Coefficient of Determination:The % variation of y on variation with x
from sklearn.metrics import r2_score 
r_squared=r2_score(y_truth, y_forecasted)
print('R-squared Error is {}'.format(r_squared))

#Since the R squared error is approximately 0.78 closer to 1 the model can predict the values of future cases with a narrow margin of error
#prediction model accuracy is 77.98% which is acceptable.
# Out:
# The Mean Squared Error is 4231172.97
# The Root Mean Squared Error is 2056.98
# R-squared Error is 0.8568827004582245

# %% [markdown]
# y_truth
# y_forecasted

# %%
 # decide on a cutoff limit
cutoff1 = 75000
cutoff2 = 10000
cutoff3 = 12500
cutoff4 = 15000
cutoff5 = 20000
#cutoff6 = 2000
y_truth_classes = np.zeros_like(y_truth)    # initialise a matrix full with zeros
#print(y_truth)
#print(y_forecasted)
y_truth_classes[(0 <= y_truth) & (y_truth<= cutoff1)] = 0#"Below 50"#1
y_truth_classes[(cutoff1 < y_truth) & (y_truth<= cutoff2)] = 1#"50-100"#2
y_truth_classes[(cutoff2 < y_truth) & (y_truth<= cutoff3)] = 2#"100-200"#3
y_truth_classes[(cutoff3 < y_truth) & (y_truth<= cutoff4)] = 3#"200-500"#3
y_truth_classes[(cutoff4 < y_truth) & (y_truth<= cutoff5)] =4#"200-500"#3
y_truth_classes[(cutoff5 < y_truth)] = 5#">1000"5
#y_truth_classes[cutoff6 < y_truth] = 6
#print(y_truth_classes)

###
y_forecasted_classes = np.zeros_like(y_forecasted)    # initialise a matrix full with zeros
y_forecasted_classes[(0 <= y_forecasted) & (y_forecasted<= cutoff1)] = 0#"Below 50"#1
y_forecasted_classes[(cutoff1 < y_forecasted) & (y_forecasted<= cutoff2)] = 1#"50-100"#2
y_forecasted_classes[(cutoff2 < y_forecasted) & (y_forecasted<= cutoff3)] = 2#"100-200"#3
y_forecasted_classes[(cutoff3 < y_forecasted) & (y_forecasted<= cutoff4)] = 3#"200-500"#3
y_forecasted_classes[(cutoff4 < y_forecasted) & (y_forecasted<= cutoff5)] = 4#"200-500"#3
y_forecasted_classes[(cutoff5 < y_forecasted) ] = 5#">1000"5
#y_forecasted_classes[cutoff6 < y_truth] = 6
#print(y_forecasted_classes)

import seaborn as sn
import matplotlib.pyplot as plt

# %%
# Constructing the confusion matrix.
from sklearn.metrics import confusion_matrix
confusion_matrix_tests=confusion_matrix(y_truth_classes, y_forecasted_classes)
#print(matrix)
plt.figure(figsize=(14,6))
#sn.heatmap(confusion_matrix, annot=True, vmin=0, vmax=10, cmap="YlGnBu", center=0)
#plt.show()

ax = sn.heatmap(confusion_matrix_tests, annot=True, vmin=0, vmax=10, cmap="YlGnBu", center=0) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_xlabel('Predicted Range of Tests');
ax.set_ylabel('Actual Range of Tests'); 
ax.set_title('Confusion Matrix for COVID-19 tests'); 
xlabels=['Below 75000' ,'75000-10000' ,'10000-12500' ,'12500-15000' ,'15000-20000' ,'>20000']
ylabels=['>20000','15000-20000','12500-15000','10000-12500','75000-10000','Below 75000']
#ax.xticks( rotation=45)
ax.set_xticklabels(xlabels, fontdict=None, minor=False,rotation=70)
ax.set_yticklabels(ylabels, fontdict=None, minor=False,rotation=0)

ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
 # decide on a cutoff limit
cutoff1 = 75000
cutoff2 = 10000
cutoff3 = 12500
cutoff4 = 15000
cutoff5 = 20000

# %%
#Confusion Matrix Classification Report
from sklearn.metrics import classification_report

print("classification report for the model for COVID-19 Tests is as Under :-")
print(classification_report(y_truth_classes, y_forecasted_classes))
# Out:
# classification report for the model for COVID-19 Tests is as Under :-
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.88      0.82         8
#          2.0       0.00      0.00      0.00         1
#          3.0       0.00      0.00      0.00         1
#          4.0       0.75      0.75      0.75         8
#          5.0       0.75      0.60      0.67         5
#
#     accuracy                           0.70        23
#    macro avg       0.46      0.45      0.45        23
# weighted avg       0.69      0.70      0.69        23

# %%
# Finding precision and recall
from sklearn.metrics import precision_score, recall_score,f1_score
print("Precision Score for thePrediction of COVID-19 Tests is :",precision_score(y_truth_classes, y_forecasted_classes, 
                                           #pos_label='positive',
                                           average='micro'))
print("Recall Score for thePrediction of COVID-19 Tests  is :",recall_score(y_truth_classes, y_forecasted_classes, 
                                           #pos_label='positive',
                                           average='micro'))
# To compute the F1 score, simply call the f1_score() function:
print("F1 Score for the Prediction of COVID-19 Tests  is :",f1_score(y_truth_classes, y_forecasted_classes, 
                                           #pos_label='positive',
                                           average='micro'))
# Out:
# Precision Score for thePrediction of COVID-19 Tests is : 0.6956521739130435
# Recall Score for thePrediction of COVID-19 Tests  is : 0.6956521739130435
# F1 Score for the Prediction of COVID-19 Tests  is : 0.6956521739130435

# %%
#Future Predict the results of new Tests for next 3 months

pred_uc = results.get_forecast(steps=13)
pred_ci = pred_uc.conf_int()
ax = ts_tests_adj.plot(label='observed', figsize=(14, 6))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Tests')
ax.set_title('Historic and next 3 months Future Predicted New Tests')
plt.legend()
plt.show()
#Since we are preicting weekly average the value is calcualted weekly . The gap in graph shows a period between 
# week 03-Jan-2021 to 09-Jan-2021 but there are NO missing values.

# %%
#Future Predict the results for next 3 months

ax = pred_ci.plot(label='Observed(Actual)', figsize=(14, 6))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Months (Listed in Weeks)')
ax.set_ylabel('New Tests')
ax.set_title('Weekly Average of 3 months Predicted New Tests')
plt.legend()

#ax.hlines(y=1000, xmin=pd.to_datetime('2020-01-02'), xmax=pd.to_datetime('2021-04-02'), linewidth=1, color='r')

plt.show()
#Since we are preicting weekly average the value is calcualted on every Sunday . The gap in graph shows aperiod between 
#on a gap of a week 03-Jan-2021 to 09-Jan-2021 but there is NO missing values.

# %%
#Use mean of Max and minimum values to calculate number of kits required for next 16 weeks
pred_ci['kits_required']=pred_ci.mean(axis=1)*7

kits_required=pred_ci['kits_required'].round()
pred_ci
# Out:
#             lower new_tests  upper new_tests  kits_required
# 2021-01-10            24255            31766         196070
# 2021-01-17            22668            32186         191990
# 2021-01-24            39096            50267         312770
# 2021-01-31            21674            34283         195849
# 2021-02-07            18368            32267         177222
# 2021-02-14            18907            33987         185127
# 2021-02-21            17074            33249         176130
# 2021-02-28            15008            32207         165251
# 2021-03-07            19195            37362         197950
# 2021-03-14            17206            36290         187235
# 2021-03-21            15163            35123         176000
# 2021-03-28            14671            35470         175495
# 2021-04-04            15201            36883         182295

# %% [markdown]
# ## Kits required for next 3 months (10th January 2021 to 4th April 2021)

# %%
import math
cumulative_sum=0

sum=kits_required[0:3].sum()
Kits = [sum]
cumulative_sum+=sum
print('Number of kits required for next month is {} '.format(sum))
sum=kits_required[4:7].sum()
Kits.append(sum)
cumulative_sum+=sum
print('Number of kits required for second month is {} '.format(sum))
sum=kits_required[8:11].sum()

Kits.append(sum)
cumulative_sum+=sum
Kits.append(cumulative_sum)
print('Number of kits required for third month is {} '.format(sum))

print('Cumulative test cases for next three months is {}'.format(cumulative_sum))
kits_df = pd.DataFrame(Kits,index=['10 Jan 2021 to 07 Feb 2021', 
                                 '14 Feb 2021 to 07 March 2021','14 March 2021 to 4 April 2021','CUMULATIVE'],columns = ['Required Test Kits'])
pd.options.display.float_format = '{:.0f}'.format

kits_df
# Out:
# Number of kits required for next month is 700830.0
# Number of kits required for second month is 538479.0
# Number of kits required for third month is 561185.0
# Cumulative test cases for next three months is 1800494.0
#                                Required Test Kits
# 10 Jan 2021 to 07 Feb 2021                 700830
# 14 Feb 2021 to 07 March 2021               538479
# 14 March 2021 to 4 April 2021              561185
# CUMULATIVE                                1800494
